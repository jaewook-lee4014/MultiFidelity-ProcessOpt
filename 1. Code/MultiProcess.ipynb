# %%
cd ~/MultiFidelity-ProcessOpt/1.\ Code
# Out:
# /users/k23070952/MultiFidelity-ProcessOpt/1. Code
# /users/k23070952/CODE/0. SSH files/jvenv/lib/python3.11/site-packages/IPython/core/magics/osm.py:393: UserWarning: This is now an optional IPython functionality, using bookmarks requires you to install the `pickleshare` library.
#   bkms = self.shell.db.get('bookmarks', {})
# /users/k23070952/CODE/0. SSH files/jvenv/lib/python3.11/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
from ShortCutDesign import ShortCutDesign 
from RigorousDesign import RigorousDesign 
import os
import numpy as np
import pandas as pd
import itertools
import multiprocessing
import time
from tqdm import tqdm

# %%
# Define the bounds as per the given function
bounds = [
    (10, 50),           # Number of stages in extractor
    (1e-4, 0.9999), (1e-4, 0.9999),  # Light key, heavy key for extract distiller
    (1e-4, 0.9999), (1e-4, 0.9999),  # Light key, heavy key for acetic_acid_purification
    (273, 350),         # Temperature for HX
    (1e-4, 0.9999), (1e-4, 0.9999)   # Light key, heavy key for raffinate distiller
]

# 각 파라미터를 10개의 그리드로 나누기
grid_points = [np.linspace(low, high, 10) for low, high in bounds]

# 가능한 모든 조합 생성 (그리드 서치)
param_combinations = list(itertools.product(*grid_points))

print(f"Total search space: {len(param_combinations)} combinations")
# Out:
# Total search space: 100000000 combinations

# %%
# Define the bounds as per the given function
bounds = [
    (10, 50),           # Number of stages in extractor
    (0.95, 0.9999), (0.95, 0.9999),  # Light key, heavy key for extract distiller
    (0.95, 0.9999), (0.95, 0.9999),  # Light key, heavy key for acetic_acid_purification
    (300, 350),         # Temperature for HX
    (0.95, 0.9999), (0.95, 0.9999)   # Light key, heavy key for raffinate distiller
]

# 각 파라미터를 10개의 그리드로 나누기
grid_points = [np.linspace(low, high, 3) for low, high in bounds]

# 가능한 모든 조합 생성 (그리드 서치)
param_combinations = list(itertools.product(*grid_points))

print(f"Total search space: {len(param_combinations)} combinations")
# Out:
# Total search space: 6561 combinations

# %%
# ✅ 파일 경로 설정
results_file = '../3. Data/results_250320.csv'
error_file = '../3. Data/errors_250320.csv'

# ✅ Shortcut 및 Rigorous 결과 계산 함수 
def calculate_shortcut(_init_params):
    shortcut_model = ShortCutDesign()
    shortcut_results = shortcut_model.shortcut_results(_init_params)
    return shortcut_results

def calculate_rigorous(_init_params):
    shortcut_results = calculate_shortcut(_init_params)
    if shortcut_results['CAPEX'] == 0:
        return (shortcut_results, [0, 0, 0])

    if shortcut_results['CAPEX'] is None or np.isnan(shortcut_results['CAPEX']):
        return (shortcut_results, [0, 0, 0])

    RigorousCal = RigorousDesign()
    Rigorous_results = RigorousCal.check_results(_init_params, shortcut_results)
    return (shortcut_results, Rigorous_results)

# ✅ 평가 함수 (병렬 실행용)
def evaluate(params):
    try:
        # 계산 수행
        shortcut_obj, rigorous_obj = calculate_rigorous(params)

        # 결과 데이터 정리
        record = list(params) + [
            shortcut_obj['CAPEX'], shortcut_obj['OPEX'], shortcut_obj['AceticAcidWt'], shortcut_obj['boilup_1'], 
            shortcut_obj['SplitRatio'], shortcut_obj['N_stages_1'], shortcut_obj['feed_stage_1'], shortcut_obj['shortcut_time'], 
            rigorous_obj[0], rigorous_obj[1], rigorous_obj[2], rigorous_obj[3]
        ]

        # 실시간 CSV 저장
        df = pd.DataFrame([record])
        df.to_csv(results_file, mode='a', header=not os.path.exists(results_file), index=False)

        return record

    except Exception as e:
        error_df = pd.DataFrame([[params, str(e)]], columns=['Params', 'Error'])
        error_df.to_csv(error_file, mode='a', header=not os.path.exists(error_file), index=False)
        return None

# %%
len(param_combinations)
# Out:
# 6561

# %%
# ✅ 병렬 실행
if __name__ == "__main__":
    # SLURM이 할당한 CPU 개수 가져오기 (없으면 기본값 4)
    num_cpus = int(os.getenv("SLURM_CPUS_ON_NODE", "4"))
    print(f"Using {num_cpus} CPUs for parallel processing.")

    # ✅ 실행 시작 시간 기록
    start_time = time.time()
    completed_tasks = 0

    # ✅ 멀티프로세싱 풀 생성 및 실행
    results = []
    with multiprocessing.Pool(processes=num_cpus) as pool:
        for result in pool.imap_unordered(evaluate, param_combinations[:]):  # 50만 개 실행
            if result:
                results.append(result)
                completed_tasks += 1

            # ✅ 100개 완료될 때마다 진행 상태 출력
            if completed_tasks % 100 == 0:
                elapsed = time.time() - start_time
                print(f"Completed {completed_tasks} tasks in {elapsed:.2f} seconds")

    # ✅ 실행 종료 시간 기록
    end_time = time.time()
    elapsed_time = end_time - start_time

    print(f"\nGrid search completed in {elapsed_time:.2f} seconds.")
# Out:
# Using 64 CPUs for parallel processing.
#  ##### An instance of the 'BlackBox' class  has been initialised!
# (10.0, 0.95, 0.95, 0.95, 0.95, 300.0, 0.97495, 0.95)
#  ##### An instance of the 'BlackBox' class  has been initialised! ##### An instance of the 'BlackBox' class  has been initialised! ##### An instance of the 'BlackBox' class  has been initialised!
#  ##### An instance of the 'BlackBox' class  has been initialised! ##### An instance of the 'BlackBox' class  has been initialised!
# (10.0, 0.95, 0.95, 0.95, 0.95, 325.0, 0.95, 0.95)
#
#
#  ##### An instance of the 'BlackBox' class  has been initialised!
#  ##### An instance of the 'BlackBox' class  has been initialised!(10.0, 0.95, 0.95, 0.95, 0.95, 300.0, 0.95, 0.95) ##### An instance of the 'BlackBox' class  has been initialised! ##### An instance of the 'BlackBox' class  has been initialised! ##### An instance of the 'BlackBox' class  has been initialised! ##### An instance of the 'BlackBox' class  has been initialised! ##### An instance of the 'BlackBox' class  has been initialised!(10.0, 0.95, 0.95, 0.95, 0.95, 300.0, 0.95, 0.9999) ##### An instance of the 'BlackBox' class  has been initialised!(10.0, 0.95, 0.95, 0.95, 0.95, 300.0, 0.97495, 0.9999) ##### An instance of the 'BlackBox' class  has been initialised! ##### An instance of the 'BlackBox' class  has been initialised!
#
#
#  ##### An instance of the 'BlackBox' class  has been initialised!
# (10.0, 0.95, 0.95, 0.95, 0.95, 325.0, 0.9999, 0.97495)
#
#  ##### An instance of the 'BlackBox' class  has been initialised!
#
#  ##### An instance of the 'BlackBox' class  has been initialised! ##### An instance of the 'BlackBox' class  has been initialised!
# (10.0, 0.95, 0.95, 0.95, 0.95, 300.0, 0.9999, 0.97495)
#
#  ##### An instance of the 'BlackBox' class  has been initialised!(10.0, 0.95, 0.95, 0.95, 0.95, 325.0, 0.97495, 0.95)(10.0, 0.95, 0.95, 0.95, 0.95, 350.0, 0.95, 0.97495) ##### An instance of the 'BlackBox' class  has been initialised!(10.0, 0.95, 0.95, 0.95, 0.95, 350.0, 0.95, 0.9999)
#
#
#
# (10.0, 0.95, 0.95, 0.95, 0.95, 325.0, 0.9999, 0.9999) ##### An instance of the 'BlackBox' class  has been initialised!(10.0, 0.95, 0.95, 0.95, 0.95, 300.0, 0.97495, 0.97495) ##### An instance of the 'BlackBox' class  has been initialised!
#
#
#
# (10.0, 0.95, 0.95, 0.95, 0.95, 325.0, 0.9999, 0.95)
#
#
#  ##### An instance of the 'BlackBox' class  has been initialised!
#
#  ##### An instance of the 'BlackBox' class  has been initialised!(10.0, 0.95, 0.95, 0.95, 0.95, 300.0, 0.9999, 0.9999)
#
#
# (10.0, 0.95, 0.95, 0.95, 0.95, 325.0, 0.97495, 0.9999) ##### An instance of the 'BlackBox' class  has been initialised!(10.0, 0.95, 0.95, 0.95, 0.97495, 300.0, 0.95, 0.95)(10.0, 0.95, 0.95, 0.95, 0.95, 350.0, 0.9999, 0.9999)
# (10.0, 0.95, 0.95, 0.95, 0.95, 350.0, 0.97495, 0.9999) ##### An instance of the 'BlackBox' class  has been initialised!(10.0, 0.95, 0.95, 0.95, 0.97495, 300.0, 0.9999, 0.97495)(10.0, 0.95, 0.95, 0.95, 0.95, 325.0, 0.97495, 0.97495)
#
#
#
#  ##### An instance of the 'BlackBox' class  has been initialised! ##### An instance of the 'BlackBox' class  has been initialised! ##### An instance of the 'BlackBox' class  has been initialised!
#  ##### An instance of the 'BlackBox' class  has been initialised!(10.0, 0.95, 0.95, 0.95, 0.97495, 300.0, 0.97495, 0.9999)
# (10.0, 0.95, 0.95, 0.95, 0.95, 325.0, 0.95, 0.9999)
#  ##### An instance of the 'BlackBox' class  has been initialised!
# (10.0, 0.95, 0.95, 0.95, 0.97495, 300.0, 0.9999, 0.9999)
#  ##### An instance of the 'BlackBox' class  has been initialised! ##### An instance of the 'BlackBox' class  has been initialised!(10.0, 0.95, 0.95, 0.95, 0.97495, 300.0, 0.97495, 0.97495)
#
#  ##### An instance of the 'BlackBox' class  has been initialised!(10.0, 0.95, 0.95, 0.95, 0.97495, 300.0, 0.95, 0.97495)
# (10.0, 0.95, 0.95, 0.95, 0.95, 350.0, 0.95, 0.95)(10.0, 0.95, 0.95, 0.95, 0.95, 325.0, 0.95, 0.97495)
#
#
#
#  ##### An instance of the 'BlackBox' class  has been initialised! ##### An instance of the 'BlackBox' class  has been initialised!
#
#
# (10.0, 0.95, 0.95, 0.95, 0.95, 300.0, 0.9999, 0.95)
#
#
#
#
#
#  ##### An instance of the 'BlackBox' class  has been initialised!
#
# (10.0, 0.95, 0.95, 0.95, 0.97495, 325.0, 0.97495, 0.9999) ##### An instance of the 'BlackBox' class  has been initialised!
#  ##### An instance of the 'BlackBox' class  has been initialised!(10.0, 0.95, 0.95, 0.95, 0.97495, 300.0, 0.95, 0.9999)(10.0, 0.95, 0.95, 0.95, 0.97495, 325.0, 0.9999, 0.95)(10.0, 0.95, 0.95, 0.95, 0.97495, 300.0, 0.9999, 0.95) ##### An instance of the 'BlackBox' class  has been initialised! ##### An instance of the 'BlackBox' class  has been initialised!(10.0, 0.95, 0.95, 0.95, 0.97495, 325.0, 0.97495, 0.97495) ##### An instance of the 'BlackBox' class  has been initialised! ##### An instance of the 'BlackBox' class  has been initialised! ##### An instance of the 'BlackBox' class  has been initialised! ##### An instance of the 'BlackBox' class  has been initialised!
# (10.0, 0.95, 0.95, 0.95, 0.95, 350.0, 0.97495, 0.97495)
# (10.0, 0.95, 0.95, 0.95, 0.95, 350.0, 0.97495, 0.95)
#
#
# (10.0, 0.95, 0.95, 0.95, 0.95, 300.0, 0.95, 0.97495)
# (10.0, 0.95, 0.95, 0.95, 0.97495, 325.0, 0.95, 0.97495)
#  ##### An instance of the 'BlackBox' class  has been initialised!(10.0, 0.95, 0.95, 0.95, 0.97495, 325.0, 0.97495, 0.95)
#
#
# (10.0, 0.95, 0.95, 0.95, 0.97495, 350.0, 0.97495, 0.97495)
#
#
#
# (10.0, 0.95, 0.95, 0.95, 0.97495, 350.0, 0.95, 0.95)(10.0, 0.95, 0.95, 0.95, 0.97495, 325.0, 0.95, 0.9999) ##### An instance of the 'BlackBox' class  has been initialised! ##### An instance of the 'BlackBox' class  has been initialised!
#
#  ##### An instance of the 'BlackBox' class  has been initialised! ##### An instance of the 'BlackBox' class  has been initialised!
#
#
#  ##### An instance of the 'BlackBox' class  has been initialised!
#
#
#
# (10.0, 0.95, 0.95, 0.95, 0.97495, 325.0, 0.95, 0.95)
#
#
# (10.0, 0.95, 0.95, 0.95, 0.97495, 325.0, 0.9999, 0.9999)
#  ##### An instance of the 'BlackBox' class  has been initialised! ##### An instance of the 'BlackBox' class  has been initialised! ##### An instance of the 'BlackBox' class  has been initialised!(10.0, 0.95, 0.95, 0.95, 0.97495, 350.0, 0.97495, 0.9999)(10.0, 0.95, 0.95, 0.95, 0.97495, 300.0, 0.97495, 0.95)
# (10.0, 0.95, 0.95, 0.95, 0.97495, 325.0, 0.9999, 0.97495) ##### An instance of the 'BlackBox' class  has been initialised!(10.0, 0.95, 0.95, 0.95, 0.97495, 350.0, 0.95, 0.97495)(10.0, 0.95, 0.95, 0.95, 0.95, 350.0, 0.9999, 0.95)
# (10.0, 0.95, 0.95, 0.95, 0.97495, 350.0, 0.95, 0.9999) ##### An instance of the 'BlackBox' class  has been initialised!
#  ##### An instance of the 'BlackBox' class  has been initialised!(10.0, 0.95, 0.95, 0.95, 0.97495, 350.0, 0.9999, 0.97495)
#
# (10.0, 0.95, 0.95, 0.95, 0.95, 350.0, 0.9999, 0.97495) ##### An instance of the 'BlackBox' class  has been initialised!(10.0, 0.95, 0.95, 0.95, 0.97495, 350.0, 0.97495, 0.95) ##### An instance of the 'BlackBox' class  has been initialised!
#
# (10.0, 0.95, 0.95, 0.95, 0.97495, 350.0, 0.9999, 0.95)
#
#
#
# (10.0, 0.95, 0.95, 0.95, 0.97495, 350.0, 0.9999, 0.9999)
# (10.0, 0.95, 0.95, 0.95, 0.9999, 300.0, 0.95, 0.97495)
#
#
# (10.0, 0.95, 0.95, 0.95, 0.9999, 300.0, 0.9999, 0.97495) ##### An instance of the 'BlackBox' class  has been initialised!(10.0, 0.95, 0.95, 0.95, 0.9999, 300.0, 0.97495, 0.95)
#
#  ##### An instance of the 'BlackBox' class  has been initialised!
#
#
#
#
#
#  ##### An instance of the 'BlackBox' class  has been initialised!
#
#
#
# (10.0, 0.95, 0.95, 0.95, 0.9999, 300.0, 0.95, 0.95)(10.0, 0.95, 0.95, 0.95, 0.9999, 300.0, 0.9999, 0.9999)
# (10.0, 0.95, 0.95, 0.95, 0.9999, 300.0, 0.9999, 0.95)
# (10.0, 0.95, 0.95, 0.95, 0.9999, 300.0, 0.97495, 0.97495)
# (10.0, 0.95, 0.95, 0.95, 0.9999, 300.0, 0.95, 0.9999)
#
# (10.0, 0.95, 0.95, 0.95, 0.9999, 300.0, 0.97495, 0.9999)
#
#
# (10.0, 0.95, 0.95, 0.95, 0.9999, 325.0, 0.95, 0.95)
#
# setting base model
# setting model:  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# 10000.0
# setting base model
# setting model:   ##### An instance of the 'RigorousDesign' class  has been initialised!{'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
#
# (10.0, 0.95, 0.95, 0.95, 0.95, 325.0, 0.97495, 0.9999)
# 10000.0setting model:
# {'CAPEX': 1.8949, 'OPEX': 0.769, 'AceticAcidWt': 0.7144468927899098, 'SplitRatio': 0.013806706114398421, 'boilup_1': 3.1660889575314175, 'N_stages_1': 22, 'feed_stage_1': 17, 'boilup_2': 6.521588774617311, 'N_stages_2': 12, 'feed_stage_2': 10, 'boilup_3': 0.19121931154979346, 'N_stages_3': 12, 'feed_stage_3': 4, 'shortcut_time': 4.974987268447876}
# setting base modelsetting base model
# setting model:
# setting base model
# setting base model setting model: 10000.0
# setting model:
#  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7} setting model: {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7} {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
#
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# setting base model
# setting base modelsetting model:
#  10000.0{'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
#
# (10.0, 0.95, 0.95, 0.95, 0.9999, 300.0, 0.9999, 0.9999)
#
# 10000.0setting model: 10000.0
#  setting model:
# {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7} 10000.0
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# {'CAPEX': 2.2325, 'OPEX': 0.8559, 'AceticAcidWt': 0.7001040160043155, 'SplitRatio': 0.013806706114398423, 'boilup_1': 2.85637951369998, 'N_stages_1': 22, 'feed_stage_1': 17, 'boilup_2': 7.354528471809813, 'N_stages_2': 23, 'feed_stage_2': 23, 'boilup_3': 0.17632627305052997, 'N_stages_3': 17, 'feed_stage_3': 1, 'shortcut_time': 4.93342137336731}10000.0(10.0, 0.95, 0.95, 0.95, 0.97495, 325.0, 0.95, 0.9999)
# setting base model
#
#  ##### An instance of the 'RigorousDesign' class  has been initialised!setting model:  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
#
#
# 10000.0setting model:
# (10.0, 0.95, 0.95, 0.95, 0.9999, 300.0, 0.95, 0.9999) ##### An instance of the 'RigorousDesign' class  has been initialised!
# setting base model 10000.010000.0{'CAPEX': 1.8837, 'OPEX': 0.7651, 'AceticAcidWt': 0.7166522617328874, 'SplitRatio': 0.013806706114398421, 'boilup_1': 3.1587437833670386, 'N_stages_1': 22, 'feed_stage_1': 17, 'boilup_2': 6.709901394572029, 'N_stages_2': 13, 'feed_stage_2': 11, 'boilup_3': 0.18525754843440237, 'N_stages_3': 11, 'feed_stage_3': 4, 'shortcut_time': 4.992961645126343}
#
# setting base modelsetting model:
#
#
#  ##### An instance of the 'RigorousDesign' class  has been initialised!(10.0, 0.95, 0.95, 0.95, 0.95, 350.0, 0.97495, 0.9999)
#
# {'CAPEX': 2.0701, 'OPEX': 0.8408, 'AceticAcidWt': 0.7001222998341984, 'SplitRatio': 0.01380670611439842, 'boilup_1': 2.8563674326571764, 'N_stages_1': 22, 'feed_stage_1': 17, 'boilup_2': 7.354066226684058, 'N_stages_2': 23, 'feed_stage_2': 23, 'boilup_3': 0.16592148891385008, 'N_stages_3': 11, 'feed_stage_3': 4, 'shortcut_time': 4.968151807785034}
# setting model:
#
# setting model: 10000.0 setting model:  ##### An instance of the 'RigorousDesign' class  has been initialised!setting base model(10.0, 0.95, 0.95, 0.95, 0.95, 300.0, 0.95, 0.9999)
#
#
#
#  setting model:  (10.0, 0.95, 0.95, 0.95, 0.97495, 350.0, 0.9999, 0.97495) {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7} ##### An instance of the 'RigorousDesign' class  has been initialised!
#
# setting model: {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}{'CAPEX': 1.4485, 'OPEX': 0.873, 'AceticAcidWt': 0.7372712147129206, 'SplitRatio': 0.2672225447738064, 'boilup_1': 4.809073772921802, 'N_stages_1': 10, 'feed_stage_1': 8, 'boilup_2': 6.015022507849526, 'N_stages_2': 12, 'feed_stage_2': 10, 'boilup_3': 0.21482460956419336, 'N_stages_3': 12, 'feed_stage_3': 4, 'shortcut_time': 5.050493955612183}{'CAPEX': 1.8572, 'OPEX': 0.8326, 'AceticAcidWt': 0.6943714593924367, 'SplitRatio': 0.01380670611439842, 'boilup_1': 2.865685986992556, 'N_stages_1': 22, 'feed_stage_1': 17, 'boilup_2': 6.9761357844981955, 'N_stages_2': 12, 'feed_stage_2': 10, 'boilup_3': 0.16646320552482755, 'N_stages_3': 11, 'feed_stage_3': 4, 'shortcut_time': 5.032694101333618}10000.0 ##### An instance of the 'RigorousDesign' class  has been initialised!setting model:
#   setting base model{'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
#
# setting base model
#
# (10.0, 0.95, 0.95, 0.95, 0.95, 325.0, 0.95, 0.95)(10.0, 0.95, 0.95, 0.95, 0.9999, 300.0, 0.97495, 0.97495)
# {'CAPEX': 1.4461, 'OPEX': 0.7495, 'AceticAcidWt': 0.7372568283824323, 'SplitRatio': 0.26731809301402465, 'boilup_1': 4.808687515624187, 'N_stages_1': 10, 'feed_stage_1': 8, 'boilup_2': 6.240685347448919, 'N_stages_2': 13, 'feed_stage_2': 11, 'boilup_3': 0.05674527290678751, 'N_stages_3': 13, 'feed_stage_3': 1, 'shortcut_time': 4.9738547801971436}setting base model
#
#
#
#
# setting base modelsetting model:
# setting model: setting model: setting model:
#
# setting model:  {'CAPEX': 2.4562, 'OPEX': 0.7478, 'AceticAcidWt': 0.7010725528282746, 'SplitRatio': 0.01380670611439842, 'boilup_1': 2.858053969983171, 'N_stages_1': 22, 'feed_stage_1': 17, 'boilup_2': 7.330227732422232, 'N_stages_2': 23, 'feed_stage_2': 23, 'boilup_3': 0.04520653406256736, 'N_stages_3': 17, 'feed_stage_3': 1, 'shortcut_time': 4.991750478744507} setting base model{'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}{'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# {'CAPEX': 2.0388, 'OPEX': 0.6775, 'AceticAcidWt': 0.7180388846787623, 'SplitRatio': 0.013806706114398423, 'boilup_1': 3.1748428614428765, 'N_stages_1': 22, 'feed_stage_1': 17, 'boilup_2': 6.438364269262295, 'N_stages_2': 12, 'feed_stage_2': 10, 'boilup_3': 0.07155477706187853, 'N_stages_3': 13, 'feed_stage_3': 1, 'shortcut_time': 5.089660882949829} 10000.010000.0setting model:
#
#
#
# {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}setting model: 10000.0
# 10000.0
#
#
# {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7} {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# 10000.010000.010000.0setting base model
#
#
# setting base model
#
#
# 10000.0
#
# setting model: setting model:   setting base model10000.010000.0{'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}setting model: {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
#  ##### An instance of the 'RigorousDesign' class  has been initialised!setting base model10000.010000.0
#  ##### An instance of the 'RigorousDesign' class  has been initialised!10000.0
#
#
#
# setting base modelsetting model: setting base model
# setting base model
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
#
# setting base model
# (10.0, 0.95, 0.95, 0.95, 0.97495, 300.0, 0.9999, 0.95){'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}setting model:
#
#
#  setting model: setting model:
#
#
#
# setting base model{'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}  ##### An instance of the 'RigorousDesign' class  has been initialised! setting model: (10.0, 0.95, 0.95, 0.95, 0.95, 300.0, 0.97495, 0.9999)10000.010000.0setting base model
# {'CAPEX': 2.5675, 'OPEX': 0.7837, 'AceticAcidWt': 0.700101162533936, 'SplitRatio': 0.01380670611439842, 'boilup_1': 2.865993818793879, 'N_stages_1': 22, 'feed_stage_1': 17, 'boilup_2': 7.093209625271348, 'N_stages_2': 13, 'feed_stage_2': 11, 'boilup_3': 0.07333925724323094, 'N_stages_3': 22, 'feed_stage_3': 1, 'shortcut_time': 5.05119776725769}
# {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7} ##### An instance of the 'RigorousDesign' class  has been initialised!(10.0, 0.95, 0.95, 0.95, 0.97495, 300.0, 0.97495, 0.9999)
# setting model: setting model: {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
#
# setting base model
#
#
#
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
#
# 10000.0(10.0, 0.95, 0.95, 0.95, 0.9999, 300.0, 0.95, 0.95)setting model: setting model: setting model:
#
# (10.0, 0.95, 0.95, 0.95, 0.97495, 325.0, 0.9999, 0.9999) {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
#
#  ##### An instance of the 'RigorousDesign' class  has been initialised! ##### An instance of the 'RigorousDesign' class  has been initialised!
#  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7} {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}(10.0, 0.95, 0.95, 0.95, 0.95, 325.0, 0.9999, 0.9999){'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
#  setting model:
# (10.0, 0.95, 0.95, 0.95, 0.95, 350.0, 0.97495, 0.97495)
#
#
#
# (10.0, 0.95, 0.95, 0.95, 0.97495, 325.0, 0.97495, 0.9999)
#
# setting model: 10000.010000.0
# {'CAPEX': 1.8822, 'OPEX': 0.8441, 'AceticAcidWt': 0.6975277932836518, 'SplitRatio': 0.013806706114398421, 'boilup_1': 2.8614622984001676, 'N_stages_1': 22, 'feed_stage_1': 17, 'boilup_2': 7.155730143187504, 'N_stages_2': 13, 'feed_stage_2': 11, 'boilup_3': 0.1713048964427674, 'N_stages_3': 12, 'feed_stage_3': 4, 'shortcut_time': 5.076121091842651}{'CAPEX': 1.8749, 'OPEX': 0.8401, 'AceticAcidWt': 0.6948844914863702, 'SplitRatio': 0.01380670611439842, 'boilup_1': 2.8665592941483222, 'N_stages_1': 22, 'feed_stage_1': 17, 'boilup_2': 6.964051483168884, 'N_stages_2': 12, 'feed_stage_2': 10, 'boilup_3': 0.1715626395019844, 'N_stages_3': 12, 'feed_stage_3': 4, 'shortcut_time': 5.112092971801758}setting model: {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}setting base model
#
#
#  setting model:
# setting model: setting base model
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# setting base model
# {'CAPEX': 2.0225, 'OPEX': 0.7807, 'AceticAcidWt': 0.7167071666893596, 'SplitRatio': 0.01380670611439842, 'boilup_1': 3.1596458462227694, 'N_stages_1': 22, 'feed_stage_1': 17, 'boilup_2': 6.708631922760493, 'N_stages_2': 13, 'feed_stage_2': 11, 'boilup_3': 0.19674560978632832, 'N_stages_3': 17, 'feed_stage_3': 1, 'shortcut_time': 5.076607942581177}setting base model 10000.0 ##### An instance of the 'RigorousDesign' class  has been initialised! 10000.0
#
#
#
# setting model:
# {'CAPEX': 2.2457, 'OPEX': 0.781, 'AceticAcidWt': 0.7045216632622763, 'SplitRatio': 0.013806706114398415, 'boilup_1': 2.8640897152050164, 'N_stages_1': 22, 'feed_stage_1': 17, 'boilup_2': 7.243847170433829, 'N_stages_2': 23, 'feed_stage_2': 23, 'boilup_3': 0.07249351004809078, 'N_stages_3': 13, 'feed_stage_3': 1, 'shortcut_time': 5.07527232170105}10000.0
# {'CAPEX': 1.9021, 'OPEX': 0.7728, 'AceticAcidWt': 0.7166797436107579, 'SplitRatio': 0.013806706114398423, 'boilup_1': 3.1591948385587645, 'N_stages_1': 22, 'feed_stage_1': 17, 'boilup_2': 6.709265945763861, 'N_stages_2': 13, 'feed_stage_2': 11, 'boilup_3': 0.19092707260108602, 'N_stages_3': 12, 'feed_stage_3': 4, 'shortcut_time': 5.088660478591919}setting model:
# (10.0, 0.95, 0.95, 0.95, 0.95, 300.0, 0.9999, 0.97495)10000.0setting model: {'CAPEX': 2.0154, 'OPEX': 0.7769, 'AceticAcidWt': 0.7144746998022706, 'SplitRatio': 0.01380670611439842, 'boilup_1': 3.1665427132283397, 'N_stages_1': 22, 'feed_stage_1': 17, 'boilup_2': 6.520965253562352, 'N_stages_2': 12, 'feed_stage_2': 10, 'boilup_3': 0.1970451960609025, 'N_stages_3': 17, 'feed_stage_3': 1, 'shortcut_time': 5.134362697601318}setting model:
#  10000.0
# 10000.0
#
#  ##### An instance of the 'RigorousDesign' class  has been initialised!setting model:  {'CAPEX': 1.3558, 'OPEX': 0.7404, 'AceticAcidWt': 0.7360392119925887, 'SplitRatio': 0.26707146654800124, 'boilup_1': 4.820087013602339, 'N_stages_1': 10, 'feed_stage_1': 8, 'boilup_2': 6.043869672913122, 'N_stages_2': 12, 'feed_stage_2': 10, 'boilup_3': 0.0536122367158425, 'N_stages_3': 8, 'feed_stage_3': 1, 'shortcut_time': 5.097825527191162}10000.0
# setting model:  ##### An instance of the 'RigorousDesign' class  has been initialised!(10.0, 0.95, 0.95, 0.95, 0.97495, 350.0, 0.97495, 0.97495)
#
#
# 10000.0setting base model
#
#  10000.0
#
# (10.0, 0.95, 0.95, 0.95, 0.97495, 300.0, 0.95, 0.97495){'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}{'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# 10000.0
#
#
#  setting base model{'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}setting model:
#
# setting model:
#  ##### An instance of the 'RigorousDesign' class  has been initialised! {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
#
# setting base modelsetting base model ##### An instance of the 'RigorousDesign' class  has been initialised!
#
# 10000.0{'CAPEX': 2.8696, 'OPEX': 0.7429, 'AceticAcidWt': 0.6951683797724764, 'SplitRatio': 0.013806706114398418, 'boilup_1': 2.8670662346406033, 'N_stages_1': 22, 'feed_stage_1': 17, 'boilup_2': 6.95736621911077, 'N_stages_2': 12, 'feed_stage_2': 10, 'boilup_3': 0.04567130308518086, 'N_stages_3': 26, 'feed_stage_3': 1, 'shortcut_time': 5.17535924911499}{'CAPEX': 2.0883, 'OPEX': 0.7401, 'AceticAcidWt': 0.6986601084121792, 'SplitRatio': 0.013806706114398418, 'boilup_1': 2.86341992377743, 'N_stages_1': 22, 'feed_stage_1': 17, 'boilup_2': 7.128201521128678, 'N_stages_2': 13, 'feed_stage_2': 11, 'boilup_3': 0.04473292776078905, 'N_stages_3': 15, 'feed_stage_3': 1, 'shortcut_time': 5.157106637954712}
# setting model: (10.0, 0.95, 0.95, 0.95, 0.97495, 325.0, 0.97495, 0.97495)
# setting model:
# 10000.0
#
#
#
# 10000.0setting base model(10.0, 0.95, 0.95, 0.95, 0.95, 325.0, 0.97495, 0.97495)(10.0, 0.95, 0.95, 0.95, 0.97495, 350.0, 0.97495, 0.9999)
#
# {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
#
#  ##### An instance of the 'RigorousDesign' class  has been initialised!setting model:  setting model: setting model: {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}10000.0
#   ##### An instance of the 'RigorousDesign' class  has been initialised!{'CAPEX': 1.3635, 'OPEX': 0.7432, 'AceticAcidWt': 0.7379269997572241, 'SplitRatio': 0.2672895128521119, 'boilup_1': 4.809753025542999, 'N_stages_1': 10, 'feed_stage_1': 8, 'boilup_2': 6.224769057271265, 'N_stages_2': 13, 'feed_stage_2': 11, 'boilup_3': 0.05338655554078144, 'N_stages_3': 8, 'feed_stage_3': 1, 'shortcut_time': 5.106750726699829} ##### An instance of the 'RigorousDesign' class  has been initialised!10000.010000.0 10000.0
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# setting base model
#
#  10000.0
#  ##### An instance of the 'RigorousDesign' class  has been initialised!setting model:
#
# {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
#
#
#
# 10000.0
# (10.0, 0.95, 0.95, 0.95, 0.95, 325.0, 0.9999, 0.97495)
# setting model:
#
# setting base model(10.0, 0.95, 0.95, 0.95, 0.95, 325.0, 0.95, 0.9999)
# setting base model (10.0, 0.95, 0.95, 0.95, 0.95, 300.0, 0.97495, 0.97495)
#
#
# 10000.0setting model: {'CAPEX': 2.1655, 'OPEX': 0.6511, 'AceticAcidWt': 0.7169106796574942, 'SplitRatio': 0.01380670611439842, 'boilup_1': 3.1609268682990606, 'N_stages_1': 22, 'feed_stage_1': 17, 'boilup_2': 6.703801473055319, 'N_stages_2': 13, 'feed_stage_2': 11, 'boilup_3': 0.04424110512099562, 'N_stages_3': 16, 'feed_stage_3': 1, 'shortcut_time': 5.1151323318481445}setting base model{'CAPEX': 2.193, 'OPEX': 0.647, 'AceticAcidWt': 0.7145809310497582, 'SplitRatio': 0.013806706114398421, 'boilup_1': 3.1675864170549057, 'N_stages_1': 22, 'feed_stage_1': 17, 'boilup_2': 6.518547249267016, 'N_stages_2': 12, 'feed_stage_2': 10, 'boilup_3': 0.044264579256539, 'N_stages_3': 17, 'feed_stage_3': 1, 'shortcut_time': 5.1828179359436035}{'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}{'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
#
#
# (10.0, 0.95, 0.95, 0.95, 0.95, 325.0, 0.9999, 0.95)setting base model(10.0, 0.95, 0.95, 0.95, 0.97495, 350.0, 0.95, 0.9999) ##### An instance of the 'RigorousDesign' class  has been initialised!setting base model
#  setting model:  ##### An instance of the 'RigorousDesign' class  has been initialised!setting model: 10000.0setting base modelsetting model:
#
#
#
#
# setting model: {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# (10.0, 0.95, 0.95, 0.95, 0.97495, 325.0, 0.9999, 0.95)
#
#
#
# setting model:  setting model:
#
#
#  setting model: setting model:
#
# (10.0, 0.95, 0.95, 0.95, 0.95, 300.0, 0.97495, 0.95)setting model: setting model:
# setting base model{'CAPEX': 1.8765, 'OPEX': 0.7613, 'AceticAcidWt': 0.7144190267514292, 'SplitRatio': 0.013806706114398421, 'boilup_1': 3.165635160213759, 'N_stages_1': 22, 'feed_stage_1': 17, 'boilup_2': 6.5222136811576705, 'N_stages_2': 12, 'feed_stage_2': 10, 'boilup_3': 0.1855424820824781, 'N_stages_3': 11, 'feed_stage_3': 4, 'shortcut_time': 5.166551351547241}setting model: setting base model10000.0setting model: {'CAPEX': 1.4558, 'OPEX': 0.8766, 'AceticAcidWt': 0.7392247801663661, 'SplitRatio': 0.26744546631711447, 'boilup_1': 4.798338418779595, 'N_stages_1': 10, 'feed_stage_1': 8, 'boilup_2': 6.193324294972895, 'N_stages_2': 13, 'feed_stage_2': 11, 'boilup_3': 0.21450248643126107, 'N_stages_3': 12, 'feed_stage_3': 4, 'shortcut_time': 5.110161066055298}
# setting base modelsetting model:  10000.0
#  {'CAPEX': 2.243, 'OPEX': 0.7394, 'AceticAcidWt': 0.6958942788316871, 'SplitRatio': 0.01380670611439842, 'boilup_1': 2.8683144070637394, 'N_stages_1': 22, 'feed_stage_1': 17, 'boilup_2': 6.940281280768918, 'N_stages_2': 12, 'feed_stage_2': 10, 'boilup_3': 0.0452523811793052, 'N_stages_3': 17, 'feed_stage_3': 1, 'shortcut_time': 5.177555799484253} 10000.010000.0  setting model:
#
#
#  ##### An instance of the 'RigorousDesign' class  has been initialised!{'CAPEX': 2.3886, 'OPEX': 0.6506, 'AceticAcidWt': 0.713874049196922, 'SplitRatio': 0.01380670611439842, 'boilup_1': 3.1664424433708924, 'N_stages_1': 22, 'feed_stage_1': 17, 'boilup_2': 6.534983887816693, 'N_stages_2': 12, 'feed_stage_2': 10, 'boilup_3': 0.04501405359144126, 'N_stages_3': 21, 'feed_stage_3': 1, 'shortcut_time': 5.198702812194824}
# 10000.0 ##### An instance of the 'RigorousDesign' class  has been initialised!{'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
#
#
# {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}{'CAPEX': 1.4366, 'OPEX': 0.8695, 'AceticAcidWt': 0.7391668685054537, 'SplitRatio': 0.26746806836325177, 'boilup_1': 4.796966783383737, 'N_stages_1': 10, 'feed_stage_1': 8, 'boilup_2': 6.194636541653028, 'N_stages_2': 13, 'feed_stage_2': 11, 'boilup_3': 0.20818514013745257, 'N_stages_3': 11, 'feed_stage_3': 4, 'shortcut_time': 5.138691186904907}setting model:  10000.0setting model: {'CAPEX': 2.5738, 'OPEX': 0.688, 'AceticAcidWt': 0.7187212141936492, 'SplitRatio': 0.013806706114398421, 'boilup_1': 3.1653159786549137, 'N_stages_1': 22, 'feed_stage_1': 17, 'boilup_2': 6.660429171579591, 'N_stages_2': 13, 'feed_stage_2': 11, 'boilup_3': 0.0723093203615778, 'N_stages_3': 22, 'feed_stage_3': 1, 'shortcut_time': 5.191089153289795}
# {'CAPEX': 2.5664, 'OPEX': 0.684, 'AceticAcidWt': 0.7163340858902979, 'SplitRatio': 0.013806706114398418, 'boilup_1': 3.1718691607882117, 'N_stages_1': 22, 'feed_stage_1': 17, 'boilup_2': 6.477902138778441, 'N_stages_2': 12, 'feed_stage_2': 10, 'boilup_3': 0.07233027355627325, 'N_stages_3': 22, 'feed_stage_3': 1, 'shortcut_time': 5.167996406555176}
#
# {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}10000.0{'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
#
#
#
#
#
# {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
#
# 10000.0{'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}setting model: {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
#
#
# 10000.0
#
# setting base modelsetting base modelsetting base modelsetting base model(10.0, 0.95, 0.95, 0.95, 0.97495, 325.0, 0.95, 0.95)10000.0
# 10000.0
# (10.0, 0.95, 0.95, 0.95, 0.95, 300.0, 0.95, 0.95)
# 10000.0
#
# {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
#  ##### An instance of the 'RigorousDesign' class  has been initialised!10000.0
# 10000.0 ##### An instance of the 'RigorousDesign' class  has been initialised!
#
#
#  ##### An instance of the 'RigorousDesign' class  has been initialised!setting base model
#
#
#
#
# {'CAPEX': 2.1085, 'OPEX': 0.7761, 'AceticAcidWt': 0.6989741335199894, 'SplitRatio': 0.013806706114398421, 'boilup_1': 2.8738600371197496, 'N_stages_1': 22, 'feed_stage_1': 17, 'boilup_2': 6.867914553624375, 'N_stages_2': 12, 'feed_stage_2': 10, 'boilup_3': 0.07303982725321777, 'N_stages_3': 14, 'feed_stage_3': 1, 'shortcut_time': 5.235409736633301}
# setting model:
#  {'CAPEX': 2.0454, 'OPEX': 0.6806, 'AceticAcidWt': 0.7157214949855191, 'SplitRatio': 0.013806706114398421, 'boilup_1': 3.167325090318263, 'N_stages_1': 22, 'feed_stage_1': 17, 'boilup_2': 6.732890291751667, 'N_stages_2': 13, 'feed_stage_2': 11, 'boilup_3': 0.07157408577053252, 'N_stages_3': 13, 'feed_stage_3': 1, 'shortcut_time': 5.170294523239136}(10.0, 0.95, 0.95, 0.95, 0.97495, 300.0, 0.97495, 0.97495)
#
# (10.0, 0.95, 0.95, 0.95, 0.97495, 325.0, 0.9999, 0.97495)10000.0(10.0, 0.95, 0.95, 0.95, 0.95, 325.0, 0.95, 0.97495)10000.0{'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}setting model:
#
# setting model:
# setting model:
#
# setting model:
#
#  10000.0 10000.0 ##### An instance of the 'RigorousDesign' class  has been initialised!
# setting model: {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# setting model:  ##### An instance of the 'RigorousDesign' class  has been initialised!setting base model10000.0
# setting model: 10000.0
# (10.0, 0.95, 0.95, 0.95, 0.95, 325.0, 0.97495, 0.95)
#
#
#
# 10000.0  ##### An instance of the 'RigorousDesign' class  has been initialised!{'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}setting model: {'CAPEX': 2.2504, 'OPEX': 0.7436, 'AceticAcidWt': 0.6984829660571438, 'SplitRatio': 0.013806706114398421, 'boilup_1': 2.863133579825492, 'N_stages_1': 22, 'feed_stage_1': 17, 'boilup_2': 7.132507615976414, 'N_stages_2': 13, 'feed_stage_2': 11, 'boilup_3': 0.04522922846236788, 'N_stages_3': 17, 'feed_stage_3': 1, 'shortcut_time': 5.209460020065308}setting model:
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
#  setting model: setting base model
# {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}{'CAPEX': 2.0324, 'OPEX': 0.7726, 'AceticAcidWt': 0.6992898285197866, 'SplitRatio': 0.01380670611439842, 'boilup_1': 2.8744052821223156, 'N_stages_1': 22, 'feed_stage_1': 17, 'boilup_2': 6.86050562764652, 'N_stages_2': 12, 'feed_stage_2': 10, 'boilup_3': 0.07253829037234696, 'N_stages_3': 13, 'feed_stage_3': 1, 'shortcut_time': 5.218963384628296}
#
#  10000.0
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# 10000.010000.010000.0{'CAPEX': 2.5833, 'OPEX': 0.6545, 'AceticAcidWt': 0.7162109164546506, 'SplitRatio': 0.013806706114398425, 'boilup_1': 3.1597479424801493, 'N_stages_1': 22, 'feed_stage_1': 17, 'boilup_2': 6.720614538158894, 'N_stages_2': 13, 'feed_stage_2': 11, 'boilup_3': 0.0448383419594159, 'N_stages_3': 23, 'feed_stage_3': 1, 'shortcut_time': 5.186626672744751}setting model: {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# (10.0, 0.95, 0.95, 0.95, 0.97495, 325.0, 0.95, 0.97495)10000.0
#
# {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# (10.0, 0.95, 0.95, 0.95, 0.95, 350.0, 0.95, 0.97495)  ##### An instance of the 'RigorousDesign' class  has been initialised!
#
# {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
#
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
#
# 10000.0setting model:
# (10.0, 0.95, 0.95, 0.95, 0.95, 300.0, 0.9999, 0.95)10000.0setting model:
#
# (10.0, 0.95, 0.95, 0.95, 0.95, 350.0, 0.9999, 0.95) ##### An instance of the 'RigorousDesign' class  has been initialised!10000.0
#
# {'CAPEX': 2.0793, 'OPEX': 0.6439, 'AceticAcidWt': 0.7147335664178186, 'SplitRatio': 0.013806706114398421, 'boilup_1': 3.1675043775418428, 'N_stages_1': 22, 'feed_stage_1': 17, 'boilup_2': 6.514980864485516, 'N_stages_2': 12, 'feed_stage_2': 10, 'boilup_3': 0.04379567976287086, 'N_stages_3': 15, 'feed_stage_3': 1, 'shortcut_time': 5.218219041824341}{'CAPEX': 2.1148, 'OPEX': 0.6808, 'AceticAcidWt': 0.7177638049110778, 'SplitRatio': 0.013806706114398423, 'boilup_1': 3.17465211774243, 'N_stages_1': 22, 'feed_stage_1': 17, 'boilup_2': 6.444756435298147, 'N_stages_2': 12, 'feed_stage_2': 10, 'boilup_3': 0.07202884101938513, 'N_stages_3': 14, 'feed_stage_3': 1, 'shortcut_time': 5.269608736038208}
#
#  ##### An instance of the 'RigorousDesign' class  has been initialised!   ##### An instance of the 'RigorousDesign' class  has been initialised!10000.0
# {'CAPEX': 2.0867, 'OPEX': 0.6479, 'AceticAcidWt': 0.7170609472392347, 'SplitRatio': 0.01380670611439842, 'boilup_1': 3.160839271821825, 'N_stages_1': 22, 'feed_stage_1': 17, 'boilup_2': 6.700171898947496, 'N_stages_2': 13, 'feed_stage_2': 11, 'boilup_3': 0.0437726704950123, 'N_stages_3': 15, 'feed_stage_3': 1, 'shortcut_time': 5.215277671813965}
#
#
#
# setting model:
#
#
#
#
# {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}setting model:
# (10.0, 0.95, 0.95, 0.95, 0.97495, 300.0, 0.95, 0.9999)
# 10000.0(10.0, 0.95, 0.95, 0.95, 0.97495, 325.0, 0.97495, 0.95)
#
#
# setting model: (10.0, 0.95, 0.95, 0.95, 0.97495, 350.0, 0.95, 0.95)
# setting model: (10.0, 0.95, 0.95, 0.95, 0.9999, 325.0, 0.95, 0.95)
# 10000.0
# 10000.0(10.0, 0.95, 0.95, 0.95, 0.95, 350.0, 0.9999, 0.9999){'CAPEX': 2.1046, 'OPEX': 0.7652, 'AceticAcidWt': 0.7379675165058612, 'SplitRatio': 0.2669162780006876, 'boilup_1': 4.8278381896035425, 'N_stages_1': 10, 'feed_stage_1': 8, 'boilup_2': 5.9998300447841775, 'N_stages_2': 12, 'feed_stage_2': 10, 'boilup_3': 0.07171030511451612, 'N_stages_3': 22, 'feed_stage_3': 1, 'shortcut_time': 5.188495874404907}{'CAPEX': 2.5601, 'OPEX': 0.7795, 'AceticAcidWt': 0.6974537739740994, 'SplitRatio': 0.013806706114398423, 'boilup_1': 2.8711531969521604, 'N_stages_1': 22, 'feed_stage_1': 17, 'boilup_2': 6.9036168975489165, 'N_stages_2': 12, 'feed_stage_2': 10, 'boilup_3': 0.07335958160931678, 'N_stages_3': 22, 'feed_stage_3': 1, 'shortcut_time': 5.245250463485718} 10000.0
# 10000.0{'CAPEX': 1.306, 'OPEX': 0.7335, 'AceticAcidWt': 0.7361625440121107, 'SplitRatio': 0.26708231399539584, 'boilup_1': 4.819250390480898, 'N_stages_1': 10, 'feed_stage_1': 8, 'boilup_2': 6.04099225926, 'N_stages_2': 12, 'feed_stage_2': 10, 'boilup_3': 0.05036586668915385, 'N_stages_3': 8, 'feed_stage_3': 1, 'shortcut_time': 5.234524488449097}setting model: setting model:
#
# setting model: {'CAPEX': 1.8645, 'OPEX': 0.8367, 'AceticAcidWt': 0.6975366844517931, 'SplitRatio': 0.013806706114398421, 'boilup_1': 2.8614558647669726, 'N_stages_1': 22, 'feed_stage_1': 17, 'boilup_2': 7.155512517575035, 'N_stages_2': 13, 'feed_stage_2': 11, 'boilup_3': 0.16617305730018572, 'N_stages_3': 11, 'feed_stage_3': 4, 'shortcut_time': 5.226491928100586}
# 10000.0 ##### An instance of the 'RigorousDesign' class  has been initialised!
# setting model:
#
#
#  {'CAPEX': 2.252, 'OPEX': 0.6858, 'AceticAcidWt': 0.7227900697839422, 'SplitRatio': 0.013806706114398421, 'boilup_1': 3.161701670555729, 'N_stages_1': 22, 'feed_stage_1': 17, 'boilup_2': 6.809317913950049, 'N_stages_2': 23, 'feed_stage_2': 23, 'boilup_3': 0.07150884576213974, 'N_stages_3': 13, 'feed_stage_3': 1, 'shortcut_time': 5.18438982963562}
#
#
# {'CAPEX': 1.5736, 'OPEX': 0.8814, 'AceticAcidWt': 0.7373298558295118, 'SplitRatio': 0.26719987125171424, 'boilup_1': 4.810454750081103, 'N_stages_1': 10, 'feed_stage_1': 8, 'boilup_2': 6.0137339629766275, 'N_stages_2': 12, 'feed_stage_2': 10, 'boilup_3': 0.22129763502863042, 'N_stages_3': 17, 'feed_stage_3': 1, 'shortcut_time': 5.251295566558838}(10.0, 0.95, 0.95, 0.95, 0.97495, 300.0, 0.97495, 0.95)
#
# 10000.010000.0  10000.0
#  ##### An instance of the 'RigorousDesign' class  has been initialised!setting base model
#
# {'CAPEX': 2.1222, 'OPEX': 0.6848, 'AceticAcidWt': 0.7201228930198337, 'SplitRatio': 0.013806706114398421, 'boilup_1': 3.1680221878234764, 'N_stages_1': 22, 'feed_stage_1': 17, 'boilup_2': 6.626850479712613, 'N_stages_2': 13, 'feed_stage_2': 11, 'boilup_3': 0.07200551628740204, 'N_stages_3': 14, 'feed_stage_3': 1, 'shortcut_time': 5.242865085601807}{'CAPEX': 1.5358, 'OPEX': 0.7629, 'AceticAcidWt': 0.7415972041324089, 'SplitRatio': 0.26706103468311354, 'boilup_1': 4.820167804615763, 'N_stages_1': 10, 'feed_stage_1': 8, 'boilup_2': 6.137963928155845, 'N_stages_2': 13, 'feed_stage_2': 11, 'boilup_3': 0.07093593548712478, 'N_stages_3': 12, 'feed_stage_3': 1, 'shortcut_time': 5.211746692657471}
# setting model:
#  (10.0, 0.95, 0.95, 0.95, 0.97495, 350.0, 0.95, 0.97495)10000.0
# setting model:
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
#
# {'CAPEX': 2.1159, 'OPEX': 0.7803, 'AceticAcidWt': 0.7015973095134683, 'SplitRatio': 0.013806706114398418, 'boilup_1': 2.8686916012170074, 'N_stages_1': 22, 'feed_stage_1': 17, 'boilup_2': 7.056921029570825, 'N_stages_2': 13, 'feed_stage_2': 11, 'boilup_3': 0.07301710332418523, 'N_stages_3': 14, 'feed_stage_3': 1, 'shortcut_time': 5.245014190673828}10000.0 ##### An instance of the 'RigorousDesign' class  has been initialised!
# setting model:
# (10.0, 0.95, 0.95, 0.95, 0.95, 350.0, 0.97495, 0.95)
#
#
# 10000.010000.0
#  ##### An instance of the 'RigorousDesign' class  has been initialised! ##### An instance of the 'RigorousDesign' class  has been initialised!
# {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# 10000.0
# 10000.0
#
#
# {'CAPEX': 1.3135, 'OPEX': 0.7372, 'AceticAcidWt': 0.7381762682950573, 'SplitRatio': 0.2673034500039144, 'boilup_1': 4.808546644784547, 'N_stages_1': 10, 'feed_stage_1': 8, 'boilup_2': 6.218774675026146, 'N_stages_2': 13, 'feed_stage_2': 11, 'boilup_3': 0.050168378826250526, 'N_stages_3': 8, 'feed_stage_3': 1, 'shortcut_time': 5.235131025314331}(10.0, 0.95, 0.95, 0.95, 0.95, 350.0, 0.95, 0.95)10000.0(10.0, 0.95, 0.95, 0.95, 0.97495, 300.0, 0.9999, 0.97495)
# 10000.0
#
# setting model:
#
# setting base model
# (10.0, 0.95, 0.95, 0.95, 0.95, 350.0, 0.9999, 0.97495)
# setting model: setting model:
#
#   ##### An instance of the 'RigorousDesign' class  has been initialised!setting model:
# (10.0, 0.95, 0.95, 0.95, 0.95, 300.0, 0.95, 0.97495)  setting model: {'CAPEX': 2.877, 'OPEX': 0.7471, 'AceticAcidWt': 0.6977677217655605, 'SplitRatio': 0.013806706114398423, 'boilup_1': 2.8619075505302334, 'N_stages_1': 22, 'feed_stage_1': 17, 'boilup_2': 7.149896082608153, 'N_stages_2': 13, 'feed_stage_2': 11, 'boilup_3': 0.04564849173224576, 'N_stages_3': 26, 'feed_stage_3': 1, 'shortcut_time': 5.317895174026489} {'CAPEX': 1.5283, 'OPEX': 0.759, 'AceticAcidWt': 0.7395664328901407, 'SplitRatio': 0.266841795553199, 'boilup_1': 4.830838215924146, 'N_stages_1': 10, 'feed_stage_1': 8, 'boilup_2': 5.963208957554605, 'N_stages_2': 12, 'feed_stage_2': 10, 'boilup_3': 0.07096040043558102, 'N_stages_3': 12, 'feed_stage_3': 1, 'shortcut_time': 5.280579328536987} ##### An instance of the 'RigorousDesign' class  has been initialised!
# {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
#  10000.0{'CAPEX': 1.6529, 'OPEX': 0.7621, 'AceticAcidWt': 0.7393303125764438, 'SplitRatio': 0.266838533386379, 'boilup_1': 4.831313092928074, 'N_stages_1': 10, 'feed_stage_1': 8, 'boilup_2': 5.968654242619577, 'N_stages_2': 12, 'feed_stage_2': 10, 'boilup_3': 0.07141846720524658, 'N_stages_3': 14, 'feed_stage_3': 1, 'shortcut_time': 5.265453577041626}(10.0, 0.95, 0.95, 0.95, 0.97495, 300.0, 0.9999, 0.9999)
#
#
#
# 10000.010000.0
# {'CAPEX': 1.4386, 'OPEX': 0.7459, 'AceticAcidWt': 0.7353505619178573, 'SplitRatio': 0.2671006176078304, 'boilup_1': 4.818996071575758, 'N_stages_1': 10, 'feed_stage_1': 8, 'boilup_2': 6.059686881657019, 'N_stages_2': 12, 'feed_stage_2': 10, 'boilup_3': 0.05698073039150374, 'N_stages_3': 13, 'feed_stage_3': 1, 'shortcut_time': 5.25266695022583}setting model:
#
# 10000.0
#
#
#  10000.0setting base model ##### An instance of the 'RigorousDesign' class  has been initialised!{'CAPEX': 2.0809, 'OPEX': 0.7359, 'AceticAcidWt': 0.6960739005957352, 'SplitRatio': 0.013806706114398421, 'boilup_1': 2.868605898965906, 'N_stages_1': 22, 'feed_stage_1': 17, 'boilup_2': 6.936054195891992, 'N_stages_2': 12, 'feed_stage_2': 10, 'boilup_3': 0.044755618099484584, 'N_stages_3': 15, 'feed_stage_3': 1, 'shortcut_time': 5.246281385421753}
# setting model:
#
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# setting model:  10000.0(10.0, 0.95, 0.95, 0.95, 0.97495, 300.0, 0.95, 0.95)10000.010000.0
#
#
#
# setting model: {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}{'CAPEX': 2.0269, 'OPEX': 0.8518, 'AceticAcidWt': 0.6975188474256945, 'SplitRatio': 0.01380670611439842, 'boilup_1': 2.8614686348541327, 'N_stages_1': 22, 'feed_stage_1': 17, 'boilup_2': 7.155949100455959, 'N_stages_2': 13, 'feed_stage_2': 11, 'boilup_3': 0.17659053157874147, 'N_stages_3': 17, 'feed_stage_3': 1, 'shortcut_time': 5.27537727355957}
# setting base model{'CAPEX': 2.0399, 'OPEX': 0.7768, 'AceticAcidWt': 0.7019076713753204, 'SplitRatio': 0.013806706114398421, 'boilup_1': 2.8692247573826335, 'N_stages_1': 22, 'feed_stage_1': 17, 'boilup_2': 7.049397446945919, 'N_stages_2': 13, 'feed_stage_2': 11, 'boilup_3': 0.07251569804884735, 'N_stages_3': 13, 'feed_stage_3': 1, 'shortcut_time': 5.3709001541137695}
# setting base model
# 10000.0(10.0, 0.95, 0.95, 0.95, 0.97495, 350.0, 0.9999, 0.9999)
#
# setting base model
#
# setting model: setting model:
#
# ...
# 10000.0
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# (10.0, 0.95, 0.95, 0.9999, 0.9999, 325.0, 0.9999, 0.97495)
# setting model:  {'CAPEX': 3.2501, 'OPEX': 0.666, 'AceticAcidWt': 0.9992179723056943, 'SplitRatio': 0.013806706114398421, 'boilup_1': 3.157254516463489, 'N_stages_1': 22, 'feed_stage_1': 17, 'boilup_2': 9.295025191607008, 'N_stages_2': 34, 'feed_stage_2': 28, 'boilup_3': 0.04475920743012651, 'N_stages_3': 23, 'feed_stage_3': 1, 'shortcut_time': 0.44890356063842773}
# 10000.0
# Error occurred: <System: AAsep> could not converge
# Highest convergence error among components in recycle
# streams {extract_distiller-2, acetic_acid_purification-0, splitter-1, settler-1} after 200 loops:
# - flow rate   7.62e-01 kmol/hr (2%)
# - temperature 5.54e-02 K (0.015%)
#  ##### An instance of the 'BlackBox' class  has been initialised!
# (10.0, 0.95, 0.95, 0.9999, 0.9999, 325.0, 0.9999, 0.9999)
# setting base model
# setting model:  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# 10000.0
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# (10.0, 0.95, 0.95, 0.9999, 0.9999, 325.0, 0.9999, 0.9999)
# setting model:  {'CAPEX': 2.6786, 'OPEX': 0.7922, 'AceticAcidWt': 0.999219850428837, 'SplitRatio': 0.013806706114398421, 'boilup_1': 3.15695199918481, 'N_stages_1': 22, 'feed_stage_1': 17, 'boilup_2': 9.274055966244086, 'N_stages_2': 34, 'feed_stage_2': 28, 'boilup_3': 0.1967090177460171, 'N_stages_3': 17, 'feed_stage_3': 1, 'shortcut_time': 0.34255552291870117}
# 10000.0
#  ##### An instance of the 'BlackBox' class  has been initialised!
# (10.0, 0.95, 0.95, 0.9999, 0.9999, 350.0, 0.95, 0.95)
# setting base model
# setting model:  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# 10000.0
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# (10.0, 0.95, 0.95, 0.9999, 0.9999, 350.0, 0.95, 0.95)
# setting model:  {'CAPEX': 2.2014, 'OPEX': 0.7733, 'AceticAcidWt': 0.9993128014931789, 'SplitRatio': 0.2670885789364599, 'boilup_1': 4.821348228254833, 'N_stages_1': 10, 'feed_stage_1': 8, 'boilup_2': 8.278599859591564, 'N_stages_2': 34, 'feed_stage_2': 27, 'boilup_3': 0.07090425055386165, 'N_stages_3': 12, 'feed_stage_3': 1, 'shortcut_time': 0.6847562789916992}
# 10000.0
#  ##### An instance of the 'BlackBox' class  has been initialised!
# (10.0, 0.95, 0.95, 0.9999, 0.9999, 350.0, 0.95, 0.97495)
# setting base model
# setting model:  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# 10000.0
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# (10.0, 0.95, 0.95, 0.9999, 0.9999, 350.0, 0.95, 0.97495)
# setting model:  {'CAPEX': 1.9792, 'OPEX': 0.7477, 'AceticAcidWt': 0.9993003313276533, 'SplitRatio': 0.2673316608883649, 'boilup_1': 4.809729583030272, 'N_stages_1': 10, 'feed_stage_1': 8, 'boilup_2': 8.417389605664827, 'N_stages_2': 34, 'feed_stage_2': 27, 'boilup_3': 0.050237400573064306, 'N_stages_3': 8, 'feed_stage_3': 1, 'shortcut_time': 0.44800400733947754}
# 10000.0
# Error occurred: <System: AAsep> could not converge
# Highest convergence error among components in recycle
# streams {extract_distiller-2, acetic_acid_purification-0, splitter-1, settler-1} after 200 loops:
# - flow rate   2.93e+00 kmol/hr (95%)
# - temperature 6.52e-02 K (0.018%)
#  ##### An instance of the 'BlackBox' class  has been initialised!
# (10.0, 0.95, 0.95, 0.9999, 0.9999, 350.0, 0.95, 0.9999)
# setting base model
# setting model:  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# 10000.0
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# (10.0, 0.95, 0.95, 0.9999, 0.9999, 350.0, 0.95, 0.9999)
# setting model:  {'CAPEX': 2.1023, 'OPEX': 0.8807, 'AceticAcidWt': 0.999304039898984, 'SplitRatio': 0.2674993141073157, 'boilup_1': 4.7978905002169885, 'N_stages_1': 10, 'feed_stage_1': 8, 'boilup_2': 8.374861860736111, 'N_stages_2': 34, 'feed_stage_2': 27, 'boilup_3': 0.20836976864412948, 'N_stages_3': 11, 'feed_stage_3': 4, 'shortcut_time': 0.30893778800964355}
# 10000.0
#  ##### An instance of the 'BlackBox' class  has been initialised!
# (10.0, 0.95, 0.95, 0.9999, 0.9999, 350.0, 0.97495, 0.95)
# setting base model
# setting model:  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# 10000.0
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# (10.0, 0.95, 0.95, 0.9999, 0.9999, 350.0, 0.97495, 0.95)
# setting model:  {'CAPEX': 2.3261, 'OPEX': 0.7764, 'AceticAcidWt': 0.9993119901151253, 'SplitRatio': 0.26708457916711054, 'boilup_1': 4.821863549181621, 'N_stages_1': 10, 'feed_stage_1': 8, 'boilup_2': 8.287734666814954, 'N_stages_2': 34, 'feed_stage_2': 27, 'boilup_3': 0.07136175130748337, 'N_stages_3': 14, 'feed_stage_3': 1, 'shortcut_time': 0.5934264659881592}
# 10000.0
# Error occurred: <System: AAsep> could not converge
# Highest convergence error among components in recycle
# streams {extract_distiller-2, acetic_acid_purification-0, splitter-1, settler-1} after 200 loops:
# - flow rate   1.59e+00 kmol/hr (4%)
# - temperature 1.44e-01 K (0.04%)
#  ##### An instance of the 'BlackBox' class  has been initialised!
# (10.0, 0.95, 0.95, 0.9999, 0.9999, 350.0, 0.97495, 0.97495)
# setting base model
# setting model:  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# 10000.0
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# (10.0, 0.95, 0.95, 0.9999, 0.9999, 350.0, 0.97495, 0.97495)
# setting model:  {'CAPEX': 2.0289, 'OPEX': 0.7546, 'AceticAcidWt': 0.9992999001404279, 'SplitRatio': 0.26732055862006526, 'boilup_1': 4.810577856940945, 'N_stages_1': 10, 'feed_stage_1': 8, 'boilup_2': 8.422291164183193, 'N_stages_2': 34, 'feed_stage_2': 27, 'boilup_3': 0.05347818284475465, 'N_stages_3': 8, 'feed_stage_3': 1, 'shortcut_time': 0.6143190860748291}
# 10000.0
#  ##### An instance of the 'BlackBox' class  has been initialised!
# (10.0, 0.95, 0.95, 0.9999, 0.9999, 350.0, 0.97495, 0.9999)
# setting base model
# setting model:  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# 10000.0
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# (10.0, 0.95, 0.95, 0.9999, 0.9999, 350.0, 0.97495, 0.9999)
# setting model:  {'CAPEX': 2.1215, 'OPEX': 0.8872, 'AceticAcidWt': 0.999304247894305, 'SplitRatio': 0.2674768104467475, 'boilup_1': 4.799257191903103, 'N_stages_1': 10, 'feed_stage_1': 8, 'boilup_2': 8.372643551811661, 'N_stages_2': 34, 'feed_stage_2': 27, 'boilup_3': 0.21469223207462976, 'N_stages_3': 12, 'feed_stage_3': 4, 'shortcut_time': 0.2951972484588623}
# 10000.0
# Error occurred: <System: AAsep> could not converge
# Highest convergence error among components in recycle
# streams {extract_distiller-2, acetic_acid_purification-0, splitter-1, settler-1} after 200 loops:
# - flow rate   6.83e-01 kmol/hr (14%)
# - temperature 8.03e-02 K (0.022%)
#  ##### An instance of the 'BlackBox' class  has been initialised!
# (10.0, 0.95, 0.95, 0.9999, 0.9999, 350.0, 0.9999, 0.95)
# setting base model
# setting model:  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# 10000.0
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# (10.0, 0.95, 0.95, 0.9999, 0.9999, 350.0, 0.9999, 0.95)
# setting model:  {'CAPEX': 2.7473, 'OPEX': 0.7795, 'AceticAcidWt': 0.9993072894796216, 'SplitRatio': 0.2671577586419712, 'boilup_1': 4.818655367826704, 'N_stages_1': 10, 'feed_stage_1': 8, 'boilup_2': 8.340151597161785, 'N_stages_2': 34, 'feed_stage_2': 27, 'boilup_3': 0.07165809860786153, 'N_stages_3': 21, 'feed_stage_3': 1, 'shortcut_time': 0.8710567951202393}
# 10000.0
#  ##### An instance of the 'BlackBox' class  has been initialised!
# (10.0, 0.95, 0.95, 0.9999, 0.9999, 350.0, 0.9999, 0.97495)
# setting base model
# setting model:  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# 10000.0
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# (10.0, 0.95, 0.95, 0.9999, 0.9999, 350.0, 0.9999, 0.97495)
# setting model:  {'CAPEX': 2.1118, 'OPEX': 0.7601, 'AceticAcidWt': 0.9992974787346249, 'SplitRatio': 0.26734831918243374, 'boilup_1': 4.809569213253415, 'N_stages_1': 10, 'feed_stage_1': 8, 'boilup_2': 8.449340107874884, 'N_stages_2': 34, 'feed_stage_2': 27, 'boilup_3': 0.05684159941394785, 'N_stages_3': 13, 'feed_stage_3': 1, 'shortcut_time': 0.4756491184234619}
# 10000.0
#  ##### An instance of the 'BlackBox' class  has been initialised!
# (10.0, 0.95, 0.95, 0.9999, 0.9999, 350.0, 0.9999, 0.9999)
# setting base model
# setting model:  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# 10000.0
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# (10.0, 0.95, 0.95, 0.9999, 0.9999, 350.0, 0.9999, 0.9999)
# setting model:  {'CAPEX': 2.1999, 'OPEX': 0.8956, 'AceticAcidWt': 0.9993044556750003, 'SplitRatio': 0.26745430971826417, 'boilup_1': 4.800624378220032, 'N_stages_1': 10, 'feed_stage_1': 8, 'boilup_2': 8.37042764117598, 'N_stages_2': 34, 'feed_stage_2': 27, 'boilup_3': 0.2211619849085833, 'N_stages_3': 16, 'feed_stage_3': 1, 'shortcut_time': 0.3199934959411621}
# 10000.0
#  ##### An instance of the 'BlackBox' class  has been initialised!
# (10.0, 0.95, 0.97495, 0.95, 0.95, 300.0, 0.95, 0.95)
# setting base model
# setting model:  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# 10000.0
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# (10.0, 0.95, 0.97495, 0.95, 0.95, 300.0, 0.95, 0.95)
# setting model:  {'CAPEX': 2.2034, 'OPEX': 0.7779, 'AceticAcidWt': 0.6653344067958316, 'SplitRatio': 0.013806706114398423, 'boilup_1': 2.346336154776523, 'N_stages_1': 24, 'feed_stage_1': 20, 'boilup_2': 7.657400408429941, 'N_stages_2': 12, 'feed_stage_2': 10, 'boilup_3': 0.07251577360071307, 'N_stages_3': 13, 'feed_stage_3': 1, 'shortcut_time': 0.42278194427490234}
# 10000.0
#  ##### An instance of the 'BlackBox' class  has been initialised!
# (10.0, 0.95, 0.97495, 0.95, 0.95, 300.0, 0.95, 0.97495)
# setting base model
# setting model:  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# 10000.0
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# (10.0, 0.95, 0.97495, 0.95, 0.95, 300.0, 0.95, 0.97495)
# setting model:  {'CAPEX': 2.2517, 'OPEX': 0.7413, 'AceticAcidWt': 0.6619474425730227, 'SplitRatio': 0.013806706114398418, 'boilup_1': 2.3412345919485156, 'N_stages_1': 24, 'feed_stage_1': 20, 'boilup_2': 7.73917217528476, 'N_stages_2': 12, 'feed_stage_2': 10, 'boilup_3': 0.04473299740248452, 'N_stages_3': 15, 'feed_stage_3': 1, 'shortcut_time': 0.3340141773223877}
# 10000.0
#  ##### An instance of the 'BlackBox' class  has been initialised!
# (10.0, 0.95, 0.97495, 0.95, 0.95, 300.0, 0.95, 0.9999)
# setting base model
# setting model:  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# 10000.0
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# (10.0, 0.95, 0.97495, 0.95, 0.95, 300.0, 0.95, 0.9999)
# setting model:  {'CAPEX': 2.0279, 'OPEX': 0.8378, 'AceticAcidWt': 0.6607747100003933, 'SplitRatio': 0.01380670611439842, 'boilup_1': 2.3394869228753086, 'N_stages_1': 24, 'feed_stage_1': 20, 'boilup_2': 7.767542635536721, 'N_stages_2': 12, 'feed_stage_2': 10, 'boilup_3': 0.16616890620328806, 'N_stages_3': 11, 'feed_stage_3': 4, 'shortcut_time': 0.3189058303833008}
# 10000.0
# Error occurred: <System: AAsep> could not converge
# Highest convergence error among components in recycle
# streams {extract_distiller-2, acetic_acid_purification-0, splitter-1, settler-1} after 200 loops:
# - flow rate   3.08e+01 kmol/hr (48%)
# - temperature 5.57e+00 K (1.5%)
#  ##### An instance of the 'BlackBox' class  has been initialised!
# (10.0, 0.95, 0.97495, 0.95, 0.95, 300.0, 0.97495, 0.95)
# setting base model
# setting model:  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# 10000.0
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# (10.0, 0.95, 0.97495, 0.95, 0.95, 300.0, 0.97495, 0.95)
# setting model:  {'CAPEX': 2.2794, 'OPEX': 0.7814, 'AceticAcidWt': 0.6650104250881863, 'SplitRatio': 0.013806706114398421, 'boilup_1': 2.345866090331301, 'N_stages_1': 24, 'feed_stage_1': 20, 'boilup_2': 7.665213271817456, 'N_stages_2': 12, 'feed_stage_2': 10, 'boilup_3': 0.07301718272264436, 'N_stages_3': 14, 'feed_stage_3': 1, 'shortcut_time': 0.40505266189575195}
# 10000.0
# Error occurred: <MixerSettler: settler> too many values to unpack (expected 2)
#  ##### An instance of the 'BlackBox' class  has been initialised!
# (10.0, 0.95, 0.97495, 0.95, 0.95, 300.0, 0.97495, 0.97495)
# setting base model
# setting model:  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# 10000.0
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# (10.0, 0.95, 0.97495, 0.95, 0.95, 300.0, 0.97495, 0.97495)
# setting model:  {'CAPEX': 2.4138, 'OPEX': 0.7447, 'AceticAcidWt': 0.6617624853257313, 'SplitRatio': 0.013806706114398423, 'boilup_1': 2.340979468049205, 'N_stages_1': 24, 'feed_stage_1': 20, 'boilup_2': 7.7436458768969665, 'N_stages_2': 12, 'feed_stage_2': 10, 'boilup_3': 0.045229300766141387, 'N_stages_3': 17, 'feed_stage_3': 1, 'shortcut_time': 0.30100131034851074}
# 10000.0
# Error occurred: <System: AAsep> could not converge
# Highest convergence error among components in recycle
# streams {extract_distiller-2, acetic_acid_purification-0, splitter-1, settler-1} after 200 loops:
# - flow rate   2.15e+00 kmol/hr (33%)
# - temperature 1.68e+00 K (0.47%)
#  ##### An instance of the 'BlackBox' class  has been initialised!
# (10.0, 0.95, 0.97495, 0.95, 0.95, 300.0, 0.97495, 0.9999)
# setting base model
# setting model:  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# 10000.0
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# (10.0, 0.95, 0.97495, 0.95, 0.95, 300.0, 0.97495, 0.9999)
# setting model:  {'CAPEX': 2.0456, 'OPEX': 0.8453, 'AceticAcidWt': 0.6607654644075892, 'SplitRatio': 0.013806706114398418, 'boilup_1': 2.339492758047127, 'N_stages_1': 24, 'feed_stage_1': 20, 'boilup_2': 7.767767643747989, 'N_stages_2': 12, 'feed_stage_2': 10, 'boilup_3': 0.17130063635367263, 'N_stages_3': 12, 'feed_stage_3': 4, 'shortcut_time': 0.4153251647949219}
# 10000.0
