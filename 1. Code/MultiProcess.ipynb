# %%
cd ~/MultiFidelity-ProcessOpt/1.\ Code
# Out:
# /users/k23070952/MultiFidelity-ProcessOpt/1. Code
# /users/k23070952/CODE/0. SSH files/jvenv/lib/python3.11/site-packages/IPython/core/magics/osm.py:393: UserWarning: This is now an optional IPython functionality, using bookmarks requires you to install the `pickleshare` library.
#   bkms = self.shell.db.get('bookmarks', {})
# /users/k23070952/CODE/0. SSH files/jvenv/lib/python3.11/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
from ShortCutDesign import ShortCutDesign 
from RigorousDesign import RigorousDesign 
import os
import numpy as np
import pandas as pd
import numpy as np
import random

import itertools
import multiprocessing
import time
from tqdm import tqdm

# %%
# Define the bounds as per the given function
bounds = [
    (1, 50),           # Number of stages in extractor
    (1e-4, 0.9999), (1e-4, 0.9999),  # Light key, heavy key for extract distiller
    (1e-4, 0.9999), (1e-4, 0.9999),  # Light key, heavy key for acetic_acid_purification
    (273, 350),         # Temperature for HX
    (1e-4, 0.9999), (1e-4, 0.9999)   # Light key, heavy key for raffinate distiller
]

# 각 파라미터를 10개의 그리드로 나누기
grid_points = [np.linspace(low, high, 10) for low, high in bounds]

# 가능한 모든 조합 생성 (그리드 서치)
param_combinations = list(itertools.product(*grid_points))

print(f"Total search space: {len(param_combinations)} combinations")
# Out:
# Total search space: 100000000 combinations

# %%
# Define the bounds as per the given function
bounds = [
    (10, 50),           # Number of stages in extractor
    (0.95, 0.9999), (0.95, 0.9999),  # Light key, heavy key for extract distiller
    (0.95, 0.9999), (0.95, 0.9999),  # Light key, heavy key for acetic_acid_purification
    (300, 350),         # Temperature for HX
    (0.95, 0.9999), (0.95, 0.9999)   # Light key, heavy key for raffinate distiller
]

# 각 파라미터를 10개의 그리드로 나누기
grid_points = [np.linspace(low, high, 3) for low, high in bounds]

# 가능한 모든 조합 생성 (그리드 서치)
param_combinations = list(itertools.product(*grid_points))

print(f"Total search space: {len(param_combinations)} combinations")
# Out:
# Total search space: 6561 combinations

# %%
# Define the bounds
bounds = [
    (1, 50),           # Number of stages in extractor
    (1e-4, 0.9999), (1e-4, 0.9999),  # Light key, heavy key for extract distiller
    (1e-4, 0.9999), (1e-4, 0.9999),  # Light key, heavy key for acetic_acid_purification
    (273, 350),         # Temperature for HX
    (1e-4, 0.9999), (1e-4, 0.9999)   # Light key, heavy key for raffinate distiller
]

# Number of random samples you want to generate
n_samples = 1000000

# Generate random samples
param_combinations = [
    [random.uniform(low, high) for (low, high) in bounds]
    for _ in range(n_samples)
]

print(f"Total random search space: {len(param_combinations)} combinations")
# Out:
# Total random search space: 1000000 combinations

# %%
# ✅ 파일 경로 설정
results_file = '../3. Data/results_250327.csv'
error_file = '../3. Data/errors_250327.csv'

# ✅ Shortcut 및 Rigorous 결과 계산 함수 
def calculate_shortcut(_init_params):
    shortcut_model = ShortCutDesign()
    shortcut_results = shortcut_model.shortcut_results(_init_params)
    return shortcut_results

def calculate_rigorous(_init_params):
    shortcut_results = calculate_shortcut(_init_params)
    if shortcut_results['CAPEX'] == 0:
        return (shortcut_results, [0, 0, 0])

    if shortcut_results['CAPEX'] is None or np.isnan(shortcut_results['CAPEX']):
        return (shortcut_results, [0, 0, 0])

    RigorousCal = RigorousDesign()
    Rigorous_results = RigorousCal.check_results(_init_params, shortcut_results)
    return (shortcut_results, Rigorous_results)

# ✅ 평가 함수 (병렬 실행용)
def evaluate(params):
    try:
        # 계산 수행
        shortcut_obj, rigorous_obj = calculate_rigorous(params)

        # 결과 데이터 정리
        record = list(params) + [
            shortcut_obj['CAPEX'], shortcut_obj['OPEX'], shortcut_obj['AceticAcidWt'], shortcut_obj['SplitRatio'], 
            shortcut_obj['boilup_1'], shortcut_obj['N_stages_1'], shortcut_obj['feed_stage_1'], shortcut_obj['boilup_2'],
            shortcut_obj['N_stages_2'],shortcut_obj['feed_stage_2'],shortcut_obj['boilup_3'],shortcut_obj['N_stages_3'],shortcut_obj['feed_stage_3'],shortcut_obj['shortcut_time'],
            rigorous_obj[0], rigorous_obj[1], rigorous_obj[2], rigorous_obj[3]
        ]

        # 실시간 CSV 저장
        df = pd.DataFrame([record])
        df.to_csv(results_file, mode='a', header=not os.path.exists(results_file), index=False)

        return record

    except Exception as e:
        error_df = pd.DataFrame([[params, str(e)]], columns=['Params', 'Error'])
        error_df.to_csv(error_file, mode='a', header=not os.path.exists(error_file), index=False)
        return None

# %%
len(param_combinations)
# Out:
# 1000000

# %%
# ✅ 병렬 실행
if __name__ == "__main__":
    # SLURM이 할당한 CPU 개수 가져오기 (없으면 기본값 4)
    num_cpus = int(os.getenv("SLURM_CPUS_ON_NODE", "4"))
    print(f"Using {num_cpus} CPUs for parallel processing.")

    # ✅ 실행 시작 시간 기록
    start_time = time.time()
    completed_tasks = 0

    # ✅ 멀티프로세싱 풀 생성 및 실행
    results = []
    with multiprocessing.Pool(processes=num_cpus) as pool:
        for result in pool.imap_unordered(evaluate, param_combinations[:]):  # 50만 개 실행
            if result:
                results.append(result)
                completed_tasks += 1

            # ✅ 100개 완료될 때마다 진행 상태 출력
            if completed_tasks % 100 == 0:
                elapsed = time.time() - start_time
                print(f"Completed {completed_tasks} tasks in {elapsed:.2f} seconds")

    # ✅ 실행 종료 시간 기록
    end_time = time.time()
    elapsed_time = end_time - start_time

    print(f"\nGrid search completed in {elapsed_time:.2f} seconds.")
# Out:
# Using 64 CPUs for parallel processing.
#  ##### An instance of the 'BlackBox' class  has been initialised! ##### An instance of the 'BlackBox' class  has been initialised! ##### An instance of the 'BlackBox' class  has been initialised!
#
# [12.804357399533684, 0.4894746323095321, 0.2530777508048174, 0.6674638736123134, 0.8194959369261224, 298.1859138021376, 0.46487710302692936, 0.19981100360534407] ##### An instance of the 'BlackBox' class  has been initialised!
#
#
#  ##### An instance of the 'BlackBox' class  has been initialised! ##### An instance of the 'BlackBox' class  has been initialised! ##### An instance of the 'BlackBox' class  has been initialised! ##### An instance of the 'BlackBox' class  has been initialised! ##### An instance of the 'BlackBox' class  has been initialised! ##### An instance of the 'BlackBox' class  has been initialised![32.952068029399165, 0.8010902185516515, 0.26631021858411713, 0.6802457465872188, 0.5903101226356887, 294.77336117373005, 0.08794017696199026, 0.31180204269097295] ##### An instance of the 'BlackBox' class  has been initialised! ##### An instance of the 'BlackBox' class  has been initialised! ##### An instance of the 'BlackBox' class  has been initialised! ##### An instance of the 'BlackBox' class  has been initialised![1.5784548479662321, 0.4795775647157654, 0.4333964947035792, 0.8115493491457283, 0.8861989690480886, 329.2792452431938, 0.020587812564056222, 0.8558595023756704] ##### An instance of the 'BlackBox' class  has been initialised!
#
# [19.97053020811197, 0.5897179572063512, 0.7658434656740597, 0.1040085378732664, 0.45655911198445887, 343.16539718887026, 0.3504017851042813, 0.30672387123717415] ##### An instance of the 'BlackBox' class  has been initialised! ##### An instance of the 'BlackBox' class  has been initialised!
#
#
#
#  ##### An instance of the 'BlackBox' class  has been initialised!
#
#
#  ##### An instance of the 'BlackBox' class  has been initialised!
#  ##### An instance of the 'BlackBox' class  has been initialised!
#
#  ##### An instance of the 'BlackBox' class  has been initialised!
#
# [8.268539764231619, 0.9144550470266758, 0.08589826170462335, 0.10173804260116479, 0.488792794363564, 314.10600433348674, 0.3903922313852293, 0.6899029931650287]
# [15.406556120002062, 0.6328958301508549, 0.34046561059882174, 0.45856939263517765, 0.31077127121121484, 287.0532058850974, 0.03829767088954439, 0.0997354190994701]
#
#
# [2.6217598158808295, 0.27399586286973265, 0.5797087981130583, 0.6213422489902118, 0.0685593458593719, 347.23249997582633, 0.17721586152077087, 0.8322022204394478]
#
# [13.057226106422652, 0.6495849881863289, 0.023465712164484363, 0.4170380622103513, 0.7779127640443592, 342.0406504790218, 0.887906480865927, 0.483410079209429][20.720936212817097, 0.6524983395999552, 0.6585341929376428, 0.17443445405013197, 0.2094393270483663, 327.7075985735731, 0.01252508097277347, 0.4078236733648823]
# [10.108005869736798, 0.5512141303514467, 0.9487110337426957, 0.4089120210383408, 0.8500364177764327, 330.1990948237954, 0.9638622121414251, 0.08468853097572002]
#
# [15.250988799727846, 0.7231409350667526, 0.929240687151626, 0.9740581169530588, 0.023149560302119176, 318.85349730250186, 0.6973972940970811, 0.30454669820726776]
#
#
#
#
#
#
#
#
# Error occurred: <System: AAsep> could not converge
# Highest convergence error among components in recycle
# stream H2-0 after 200 loops:
# - flow rate   2.69e+02 kmol/hr (11%)
# - temperature 0.00e+00 K (0%)
#  ##### An instance of the 'BlackBox' class  has been initialised!
# [7.162130280892315, 0.03792777224296278, 0.5971131681808197, 0.1052063156023117, 0.1921737757529229, 318.97240632480975, 0.5272516628771539, 0.40981838705168333]
# Completed 0 tasks in 48.73 seconds
# setting base model
# setting model:  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# setting base model
# 10000.0setting model:
#  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}setting base model
#
# setting model:  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# capex_error10000.0setting base model
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
#
#
# setting model: [32.84948702731751, 0.5484295916423481, 0.29025991322628963, 0.5284320966888296, 0.864654702236055, 277.70233542344226, 0.6864543759071144, 0.10607896942215542]
# {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}setting model: setting base model
#
# {'CAPEX': 3.2285, 'OPEX': 12.4391, 'AceticAcidWt': 0.05676766088771091, 'SplitRatio': 0.01380670611439842, 'boilup_1': 1.505120022214073, 'N_stages_1': 3, 'feed_stage_1': 2, 'boilup_2': 1.2336878706389156, 'N_stages_2': 11, 'feed_stage_2': 11, 'boilup_3': 8.132792447013848, 'N_stages_3': 3, 'feed_stage_3': 1, 'shortcut_time': 48.161999225616455}setting model:
#  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}setting base model
#
# setting model: setting base model capex_error
# {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7} ##### An instance of the 'RigorousDesign' class  has been initialised!10000.0setting model:
# 10000.0
#
#
# 10000.0
# [12.804357399533684, 0.4894746323095321, 0.2530777508048174, 0.6674638736123134, 0.8194959369261224, 298.1859138021376, 0.46487710302692936, 0.19981100360534407]
# {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
#
# setting model:  {'CAPEX': 2.2398, 'OPEX': 5.8738, 'AceticAcidWt': 0.06598706007962656, 'SplitRatio': 0.013806706114398418, 'boilup_1': 1.3228468476037891, 'N_stages_1': 2, 'feed_stage_1': 2, 'boilup_2': 2.1964027390928997, 'N_stages_2': 14, 'feed_stage_2': 13, 'boilup_3': 3.8907840836318672, 'N_stages_3': 3, 'feed_stage_3': 1, 'shortcut_time': 48.20353436470032}setting base model
# setting base model
# 10000.0
# setting model: setting base model
# setting model:
# {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}{'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}setting model: 10000.0
#
#
# capex_error ##### An instance of the 'BlackBox' class  has been initialised!{'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}10000.0setting base model
#
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
#
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# [24.296020260004845, 0.06334644819906472, 0.4120971614917561, 0.24898899033582653, 0.02704448190972643, 329.7961644340677, 0.023691721592432182, 0.552520338304724]
#
# setting model:
# [10.108005869736798, 0.5512141303514467, 0.9487110337426957, 0.4089120210383408, 0.8500364177764327, 330.1990948237954, 0.9638622121414251, 0.08468853097572002][16.947471559914888, 0.9694397213532749, 0.8171450323255106, 0.481530452943014, 0.4918257027624197, 314.5396286821211, 0.7229689029540852, 0.2214631513066702]
#
# 10000.0{'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}setting model: setting model:
#
# 10000.0  capex_error
#  ##### An instance of the 'RigorousDesign' class  has been initialised!{'CAPEX': 2.1687, 'OPEX': 4.7222, 'AceticAcidWt': 0.28360109351312457, 'SplitRatio': 0.07949153464199306, 'boilup_1': 7.361851357737641, 'N_stages_1': 10, 'feed_stage_1': 6, 'boilup_2': 0.9780688082682127, 'N_stages_2': 4, 'feed_stage_2': 3, 'boilup_3': 3.545162613735524, 'N_stages_3': 4, 'feed_stage_3': 1, 'shortcut_time': 48.18311667442322}{'CAPEX': 3.8528, 'OPEX': 12.373, 'AceticAcidWt': 0.08337715997801766, 'SplitRatio': 0.17207917859103902, 'boilup_1': 0.7190594113904438, 'N_stages_1': 7, 'feed_stage_1': 6, 'boilup_2': 0.7049703213952588, 'N_stages_2': 11, 'feed_stage_2': 10, 'boilup_3': 11.104742607283045, 'N_stages_3': 5, 'feed_stage_3': 1, 'shortcut_time': 48.14976644515991}
#
# setting base model
#
# [2.0729401233185207, 0.20498568278540424, 0.33364326905588576, 0.3662619209944061, 0.42334383750444093, 277.3374555132891, 0.9231807061614157, 0.5088680511402758]
#
# setting model: setting model:    ##### An instance of the 'RigorousDesign' class  has been initialised!10000.0{'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}setting base model{'CAPEX': 1.1795, 'OPEX': 1.9845, 'AceticAcidWt': 0.01577877953640366, 'SplitRatio': 0.013806706114398421, 'boilup_1': 0.4881301372752393, 'N_stages_1': -1, 'feed_stage_1': 0, 'boilup_2': 0.5642697987440588, 'N_stages_2': 1, 'feed_stage_2': 1, 'boilup_3': 1.023969984345975, 'N_stages_3': 7, 'feed_stage_3': 1, 'shortcut_time': 48.17117118835449}10000.0
#
#
#
#
# [35.42310677314718, 0.10067258297187949, 0.5128660768751959, 0.2703309154523946, 0.9042552856505475, 297.50411060158297, 0.45433880034758334, 0.7284570526220109]
#  ##### An instance of the 'BlackBox' class  has been initialised!10000.0setting model:
#
# 10000.0
# setting model:
# {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}[26.566187983537745, 0.21668504806537064, 0.684375965053495, 0.5213985175359006, 0.1725076685514428, 299.04279333706575, 0.958433553421934, 0.8589117811185315] setting base model
# 10000.0
#
#  ##### An instance of the 'RigorousDesign' class  has been initialised!{'CAPEX': 1.1019, 'OPEX': 0.8721, 'AceticAcidWt': 0.03128806635000486, 'SplitRatio': 0.013806706114398421, 'boilup_1': 0.22291615096082584, 'N_stages_1': -1, 'feed_stage_1': 0, 'boilup_2': 0.40172513359287704, 'N_stages_2': 10, 'feed_stage_2': 10, 'boilup_3': 0.38586247506958726, 'N_stages_3': 5, 'feed_stage_3': 1, 'shortcut_time': 48.1856689453125}
#
# setting model:
# capex_error10000.0 ##### An instance of the 'RigorousDesign' class  has been initialised![44.75707652011562, 0.16663000118938495, 0.6099165996946015, 0.8095205960133282, 0.07562074167421555, 284.19998059424216, 0.7675353752056161, 0.17269421283047207]
#
#
#
# {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}[33.67556268974161, 0.7672437011844541, 0.36501222336591904, 0.817600169391759, 0.9299310176737999, 327.0291394726344, 0.7393230470657436, 0.7695761848401791]10000.0setting model:
#
#
# Error occurred:setting model:     ##### An instance of the 'RigorousDesign' class  has been initialised!setting base modelnegative dimensions are not allowed{'CAPEX': 2.299, 'OPEX': 7.3408, 'AceticAcidWt': 0.015476149208780036, 'SplitRatio': 0.01380670611439842, 'boilup_1': 0.28924082163088366, 'N_stages_1': 1, 'feed_stage_1': 1, 'boilup_2': 4.134654723438534, 'N_stages_2': 1, 'feed_stage_2': 1, 'boilup_3': 4.814061228481392, 'N_stages_3': 4, 'feed_stage_3': 1, 'shortcut_time': 48.21416354179382}
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# 10000.0
# [32.255295377168096, 0.5231591760997197, 0.2507710333834408, 0.782237723294486, 0.31744671052116946, 303.5891662631681, 0.3249287999407775, 0.4647062852802553]
# 10000.0setting base model
#
#
# setting model:  ##### An instance of the 'BlackBox' class  has been initialised!{'CAPEX': 1.3879, 'OPEX': 0.9602, 'AceticAcidWt': 0.2666140247520258, 'SplitRatio': 0.013806706114398423, 'boilup_1': 2.822350947952372, 'N_stages_1': 7, 'feed_stage_1': 5, 'boilup_2': 4.735061683794861, 'N_stages_2': 9, 'feed_stage_2': 8, 'boilup_3': 0.3215030424193025, 'N_stages_3': 7, 'feed_stage_3': 1, 'shortcut_time': 48.1945436000824}
# [36.09528735513143, 0.20399736118518788, 0.39925784837871825, 0.5371774957054537, 0.8115736851360223, 344.31147678186505, 0.8633608518616414, 0.9812940630479]
# setting model:  ##### An instance of the 'RigorousDesign' class  has been initialised!
# capex_error
#  ##### An instance of the 'BlackBox' class  has been initialised!setting base modelsetting model:
#  [18.383166812490035, 0.41684896656207365, 0.16498765304408142, 0.7677848933739296, 0.8663032733146309, 299.88500307392655, 0.39808073228325447, 0.3120823726842101]10000.0{'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}setting base model
#
#
#
# setting model:  {'CAPEX': 1.4418, 'OPEX': 2.1308, 'AceticAcidWt': 0.04559318684717064, 'SplitRatio': 0.013806706114398423, 'boilup_1': 1.454217879393486, 'N_stages_1': 2, 'feed_stage_1': 2, 'boilup_2': 3.6941269321377788, 'N_stages_2': 7, 'feed_stage_2': 6, 'boilup_3': 1.1474605724526237, 'N_stages_3': 3, 'feed_stage_3': 1, 'shortcut_time': 48.21008348464966}10000.0
#
#
# setting base modelsetting model:  ##### An instance of the 'RigorousDesign' class  has been initialised! [6.774916574865061, 0.8055700111216416, 0.4102657095732837, 0.8485989907882627, 0.12668274560775186, 277.9954767459657, 0.414670139902268, 0.5385568349981013]
# {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}setting base model
#  ##### An instance of the 'BlackBox' class  has been initialised!
#
# [32.289409453784934, 0.24927415795034977, 0.8020366045652206, 0.9563784959113145, 0.1449827447788627, 329.0507124099071, 0.7954801488536013, 0.6129486289658059] capex_error{'CAPEX': 0.9787, 'OPEX': 0.502, 'AceticAcidWt': 0.04398254917884575, 'SplitRatio': 0.01380670611439842, 'boilup_1': 0.4183305996076856, 'N_stages_1': 0, 'feed_stage_1': 0, 'boilup_2': 1.2642712998504726, 'N_stages_2': 11, 'feed_stage_2': 11, 'boilup_3': 0.053358085180147646, 'N_stages_3': 6, 'feed_stage_3': 1, 'shortcut_time': 48.21768569946289}
#
#
# setting model:
#
# setting model:
# [11.941507377076713, 0.43731852735332577, 0.8452591433630904, 0.9821216143739621, 0.4340033945008016, 300.09096624314094, 0.7458474842361107, 0.11153694998746595]
# {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# 10000.0setting model:  setting model: [10.987863023830199, 0.6357026951436549, 0.6045117750188224, 0.3309931184900437, 0.6038346271393309, 341.45300404344397, 0.5402210297571507, 0.03798879416777772]
#
#
#  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
#  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}10000.0setting model: setting base model{'CAPEX': 1.4644, 'OPEX': 2.0286, 'AceticAcidWt': 0.06861084735609578, 'SplitRatio': 0.013806706114398421, 'boilup_1': 3.035533936102956, 'N_stages_1': 8, 'feed_stage_1': 5, 'boilup_2': 5.728784765432208, 'N_stages_2': 4, 'feed_stage_2': 3, 'boilup_3': 0.8656562960301544, 'N_stages_3': 4, 'feed_stage_3': 1, 'shortcut_time': 48.2125563621521}
# {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
#  ##### An instance of the 'BlackBox' class  has been initialised!
#
#
# Error occurred:
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# setting model: {'CAPEX': 3.3731, 'OPEX': 10.3621, 'AceticAcidWt': 0.6084975857394669, 'SplitRatio': 0.013806706114398427, 'boilup_1': 0.5394932369606275, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 20.3555004241286, 'N_stages_2': 19, 'feed_stage_2': 13, 'boilup_3': 7.853121895554803, 'N_stages_3': 3, 'feed_stage_3': 1, 'shortcut_time': 48.19860219955444}10000.0[16.46776627718229, 0.4229116441391334, 0.9025885422966109, 0.8316857960436312, 0.8792664523226721, 278.90380605810356, 0.8084588882797573, 0.8133631259407456]
# Error occurred:
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
#
# [9.33790079194206, 0.4282964663497374, 0.5271352191721139, 0.8383975130224144, 0.2471241387945984, 346.3481926596849, 0.5374489310656043, 0.4546714943750587]  ##### An instance of the 'BlackBox' class  has been initialised!negative dimensions are not allowed10000.0
# {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
#
# list index out of range
#
# 10000.0[44.152460149640255, 0.767594458161488, 0.5984267480104256, 0.31624211900377486, 0.40472386894189893, 315.05770322941896, 0.09818298087907147, 0.6659287327897614]
# setting model:
# [6.576612995681508, 0.5647427426592584, 0.9992783265880946, 0.650576913628063, 0.6207700254992087, 282.82603360243695, 0.965240881398713, 0.9894600571515068]
#
# 10000.0 10000.010000.0setting base model10000.0
# setting base modelsetting model: setting base model
# {'CAPEX': 1.5088, 'OPEX': 1.9123, 'AceticAcidWt': 0.0755102699202601, 'SplitRatio': 0.01380670611439842, 'boilup_1': 0.7928233836150255, 'N_stages_1': 4, 'feed_stage_1': 3, 'boilup_2': 5.236260972647973, 'N_stages_2': 7, 'feed_stage_2': 6, 'boilup_3': 1.2165690498147086, 'N_stages_3': 4, 'feed_stage_3': 1, 'shortcut_time': 48.20015358924866}
#
# setting base model
#
# 10000.0
#
# 10000.0
# Error occurred: ##### An instance of the 'BlackBox' class  has been initialised!
#
# setting model: setting model: {'CAPEX': 1.2085, 'OPEX': 1.0909, 'AceticAcidWt': 0.051074943642803815, 'SplitRatio': 0.013806706114398423, 'boilup_1': 2.132122078350634, 'N_stages_1': 10, 'feed_stage_1': 7, 'boilup_2': 0.5070289725725688, 'N_stages_2': 0, 'feed_stage_2': 0, 'boilup_3': 0.4973449629823904, 'N_stages_3': 3, 'feed_stage_3': 1, 'shortcut_time': 48.222843170166016}setting model:
#  setting base model
#
#  setting model: list index out of range
# [7.350142556876192, 0.308851967859244, 0.19279596300572657, 0.884616764226311, 0.8564215882848094, 298.1918221190458, 0.4502761602296304, 0.1327775387512274]{'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}10000.0
#
# {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}{'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}setting model:
#
#  ##### An instance of the 'RigorousDesign' class  has been initialised!{'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7} ##### An instance of the 'RigorousDesign' class  has been initialised!10000.0
#
#
#
#
#
# [24.573549016993134, 0.7790108766991347, 0.3942606906523179, 0.2751059199153796, 0.3581072303352165, 313.61350873113804, 0.32924720784836536, 0.2971444748936992] ##### An instance of the 'BlackBox' class  has been initialised!capex_error ##### An instance of the 'RigorousDesign' class  has been initialised!
# 10000.0
#
# setting base model
# setting model:
# capex_error[28.462966231238926, 0.9714317358783228, 0.5285251944254374, 0.6839956572032397, 0.6560571113641216, 278.8219415613411, 0.3549202816868984, 0.5483508411274807][42.710244384679214, 0.7267373001964892, 0.3991569791959472, 0.04825984147845375, 0.45734651888134625, 336.58653484355654, 0.1034949524444904, 0.48357798426568066] ##### An instance of the 'RigorousDesign' class  has been initialised!
# [8.009013206026182, 0.9014566004671395, 0.2120288960545229, 0.8982468791012389, 0.17429134264274146, 314.4021655040577, 0.15513903430631984, 0.39817364093743973]setting base model{'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
#  ##### An instance of the 'RigorousDesign' class  has been initialised!setting base model
# capex_error
# {'CAPEX': 1.5968, 'OPEX': 3.3734, 'AceticAcidWt': 0.03554340026094749, 'SplitRatio': 0.013806706114398423, 'boilup_1': 2.828346309610824, 'N_stages_1': 7, 'feed_stage_1': 5, 'boilup_2': 0.4160779581514443, 'N_stages_2': -2, 'feed_stage_2': -1, 'boilup_3': 2.313621060850651, 'N_stages_3': 3, 'feed_stage_3': 1, 'shortcut_time': 48.216689586639404}setting model:
#
#
#
#
# setting model:
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
#  setting model:
# setting model: [1.5784548479662321, 0.4795775647157654, 0.4333964947035792, 0.8115493491457283, 0.8861989690480886, 329.2792452431938, 0.020587812564056222, 0.8558595023756704][7.151194597446223, 0.41401521601431773, 0.1570541768541504, 0.8910286209842634, 0.38130401506899353, 330.77488613656647, 0.7360887902675807, 0.25037136522362596] ##### An instance of the 'BlackBox' class  has been initialised!
#  10000.0setting model:  capex_error{'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7} ##### An instance of the 'RigorousDesign' class  has been initialised!
#
# 10000.0
#
#  ##### An instance of the 'BlackBox' class  has been initialised!capex_error[22.496099351439668, 0.9497908417646844, 0.21368942684965886, 0.39168625795403395, 0.39424787034407643, 293.58929386223855, 0.6095250704189216, 0.792392827045557]{'CAPEX': 1.6725, 'OPEX': 1.9496, 'AceticAcidWt': 0.41116152272916134, 'SplitRatio': 0.01380670611439842, 'boilup_1': 9.86962853082881, 'N_stages_1': 16, 'feed_stage_1': 8, 'boilup_2': 1.403486985806357, 'N_stages_2': 10, 'feed_stage_2': 7, 'boilup_3': 0.8283908860501645, 'N_stages_3': 4, 'feed_stage_3': 1, 'shortcut_time': 48.214502811431885} {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
#
#
# setting model: {'CAPEX': 1.5588, 'OPEX': 2.3951, 'AceticAcidWt': 0.14102433251094926, 'SplitRatio': 0.013806706114398421, 'boilup_1': 7.164893455841718, 'N_stages_1': 8, 'feed_stage_1': 5, 'boilup_2': 8.485816916359797, 'N_stages_2': 7, 'feed_stage_2': 5, 'boilup_3': 1.473860607590219, 'N_stages_3': 2, 'feed_stage_3': 1, 'shortcut_time': 48.25690841674805}[40.77685180050939, 0.06729052601388771, 0.7078186363907494, 0.37827433022894913, 0.21405260023295195, 282.1184249865774, 0.5556325987645663, 0.8466948468575607]
# setting model:
# 10000.0
# setting base model
# setting base model
# {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# Error occurred:
# [19.616253530180426, 0.16719155595561613, 0.22013084486028472, 0.3848943793651217, 0.5795631504460855, 273.03287233320697, 0.7718502035310504, 0.4178407225119661] 10000.0
#
# [23.67837900836538, 0.0624963787640085, 0.8050336434154575, 0.5254059873719727, 0.6079114618334377, 317.33926239802526, 0.4669181542167703, 0.5389784208046509]10000.0capex_errorsetting base model
#
#
# setting model:
# {'CAPEX': 1.9211, 'OPEX': 4.0863, 'AceticAcidWt': 0.06575892970708054, 'SplitRatio': 0.013806706114398423, 'boilup_1': 1.1609738236636133, 'N_stages_1': -1, 'feed_stage_1': 0, 'boilup_2': 8.663031745940025, 'N_stages_2': 11, 'feed_stage_2': 10, 'boilup_3': 3.0343280205676235, 'N_stages_3': 4, 'feed_stage_3': 1, 'shortcut_time': 48.25613331794739}{'CAPEX': 1.2189, 'OPEX': 0.7386, 'AceticAcidWt': 0.161667100875751, 'SplitRatio': 0.01380670611439842, 'boilup_1': 1.022370831739802, 'N_stages_1': 4, 'feed_stage_1': 3, 'boilup_2': 5.047621990142084, 'N_stages_2': 9, 'feed_stage_2': 9, 'boilup_3': 0.16712452426311297, 'N_stages_3': 2, 'feed_stage_3': 1, 'shortcut_time': 48.25936269760132}10000.0
#
#
#
# list index out of rangesetting model:
#
#
# setting model:  ##### An instance of the 'BlackBox' class  has been initialised!setting model:  setting model:  ##### An instance of the 'BlackBox' class  has been initialised!10000.0
#
#
#
#
# setting base model{'CAPEX': 1.2747, 'OPEX': 1.0233, 'AceticAcidWt': 0.09049768223927553, 'SplitRatio': 0.013806706114398416, 'boilup_1': 11.382413406188707, 'N_stages_1': 10, 'feed_stage_1': 5, 'boilup_2': 0.7333836692464333, 'N_stages_2': 1, 'feed_stage_2': 1, 'boilup_3': 0.2803972947968984, 'N_stages_3': 6, 'feed_stage_3': 1, 'shortcut_time': 48.25329899787903}{'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}[13.001213354820646, 0.02247162774498623, 0.6897712952000993, 0.09428477155039933, 0.14550114418122273, 329.7573341513789, 0.7152078908586904, 0.36460770543432386] ##### An instance of the 'RigorousDesign' class  has been initialised!setting base model ##### An instance of the 'RigorousDesign' class  has been initialised![35.68845809494461, 0.29075555038090506, 0.7636949761838457, 0.5896524845038859, 0.07047344460697504, 273.4513873715176, 0.27743283417921855, 0.41240453590327913]
# 10000.0
#
# {'CAPEX': 1.2781, 'OPEX': 2.5956, 'AceticAcidWt': 0.01417508907779924, 'SplitRatio': 0.01380670611439842, 'boilup_1': 0.4948205911870749, 'N_stages_1': -3, 'feed_stage_1': -1, 'boilup_2': 0.6288871078737125, 'N_stages_2': 4, 'feed_stage_2': 4, 'boilup_3': 1.4427878540395531, 'N_stages_3': 5, 'feed_stage_3': 1, 'shortcut_time': 48.23979878425598}10000.0 10000.0{'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
#
#
# [20.237312368206418, 0.634572536523254, 0.27386219541002677, 0.3897048414321266, 0.2189140146388381, 294.3418112672642, 0.5306410533168123, 0.3894789616916844] ##### An instance of the 'BlackBox' class  has been initialised! ##### An instance of the 'BlackBox' class  has been initialised!
# 10000.0
#
#
# [15.250988799727846, 0.7231409350667526, 0.929240687151626, 0.9740581169530588, 0.023149560302119176, 318.85349730250186, 0.6973972940970811, 0.30454669820726776]{'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
#
#
# setting model: setting base model10000.0
#
# 10000.0
# Error occurred: ##### An instance of the 'BlackBox' class  has been initialised!setting model: [18.85292168285139, 0.03327205484442613, 0.6199349887578663, 0.541152621966999, 0.0008018189861223965, 343.1590692565588, 0.5419392060051273, 0.9629844266537236]setting model:
#
#
# [15.493524537613455, 0.6396969588354159, 0.4414217013498089, 0.8780919308606663, 0.2693660356559329, 349.3723913578519, 0.35314751022900437, 0.7330705004945073]Error occurred:
# setting model:
#
#  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7} ##### An instance of the 'RigorousDesign' class  has been initialised! setting base model
#
#  setting model:  ##### An instance of the 'RigorousDesign' class  has been initialised!
# setting base modelnegative dimensions are not allowed[32.815185809978644, 0.9897923691181139, 0.7872430203014898, 0.8138777265439862, 0.5875616428940998, 302.0553286007178, 0.4208566548476974, 0.15423396076033294] setting base model{'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# {'CAPEX': 1.4134, 'OPEX': 2.639, 'AceticAcidWt': 0.01462185104821, 'SplitRatio': 0.013806706114398418, 'boilup_1': 1.979609409557453, 'N_stages_1': 4, 'feed_stage_1': 3, 'boilup_2': 0.6268531315540358, 'N_stages_2': -2, 'feed_stage_2': -1, 'boilup_3': 1.578861261895481, 'N_stages_3': 4, 'feed_stage_3': 1, 'shortcut_time': 48.244431257247925} ##### An instance of the 'BlackBox' class  has been initialised!
#
# negative dimensions are not allowed
# {'CAPEX': 1.9069, 'OPEX': 3.4528, 'AceticAcidWt': 0.0936890776910368, 'SplitRatio': 0.17782713047767953, 'boilup_1': 1.3269270494911043, 'N_stages_1': 7, 'feed_stage_1': 6, 'boilup_2': 38.41480422462398, 'N_stages_2': 4, 'feed_stage_2': 3, 'boilup_3': 2.3182853817279354, 'N_stages_3': 4, 'feed_stage_3': 1, 'shortcut_time': 48.22936415672302}
#
#
#
#
# 10000.0 ##### An instance of the 'RigorousDesign' class  has been initialised!
# {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# setting model: setting base modelsetting model: setting base model ##### An instance of the 'RigorousDesign' class  has been initialised!
#
# [40.01476297444553, 0.42263851566839916, 0.7738423147250816, 0.1343192483441527, 0.778885930463079, 289.5524857962336, 0.2382434136061909, 0.21813601754715295]10000.0 ##### An instance of the 'RigorousDesign' class  has been initialised!10000.0 ##### An instance of the 'BlackBox' class  has been initialised![27.679537736112714, 0.9089470682235101, 0.684570811185883, 0.9289604935977621, 0.305522924579786, 316.3704977801619, 0.15772573234313067, 0.5825653683588851]setting model:
#
#
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
#
#
#
#
# 10000.0
# [14.581519187087153, 0.9884918688471545, 0.20859683603119986, 0.06221113427140424, 0.2367721474090869, 343.3577768234115, 0.7002370567269877, 0.22382410381183174]
#
#  setting model:
# {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}setting model:
# [48.01438933548801, 0.9513694284157274, 0.36919302293538137, 0.8325687123969612, 0.26866309374354075, 330.01518007445844, 0.22320037772602477, 0.5257399220168064][35.826671480752495, 0.6752605372865081, 0.3311721493538635, 0.42082111828925245, 0.9554109285313365, 315.6830738851829, 0.3960018107785925, 0.8645153829972485]10000.010000.0 capex_error{'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
#
#
# setting base model[42.26023538937867, 0.6793103991853193, 0.8269761785316392, 0.6677310817799323, 0.5740335278869518, 346.26132938134936, 0.7256678130884152, 0.8739299763836554]10000.0setting model:
# [35.84875384292665, 0.46687545588636714, 0.35046372996742975, 0.899877145632374, 0.7466822837453572, 282.0547264486322, 0.6764840910966284, 0.999045830861636]10000.0setting model:
#  [15.406556120002062, 0.6328958301508549, 0.34046561059882174, 0.45856939263517765, 0.31077127121121484, 287.0532058850974, 0.03829767088954439, 0.0997354190994701]
# 10000.0
#
#
# setting model:
# {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# Error occurred:
#
#  ##### An instance of the 'BlackBox' class  has been initialised!setting model: setting model: {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
#
#
# setting base modelcapex_error {'CAPEX': 1.7511, 'OPEX': 4.9208, 'AceticAcidWt': 0.038607277793079806, 'SplitRatio': 0.013806706114398421, 'boilup_1': 0.5753228216809496, 'N_stages_1': 8, 'feed_stage_1': 6, 'boilup_2': 0.1576255088483029, 'N_stages_2': 2, 'feed_stage_2': 2, 'boilup_3': 3.406347086166876, 'N_stages_3': 2, 'feed_stage_3': 1, 'shortcut_time': 48.257954597473145}{'CAPEX': 1.6527, 'OPEX': 1.4365, 'AceticAcidWt': 0.45217759827778786, 'SplitRatio': 0.01380670611439842, 'boilup_1': 4.010469567428694, 'N_stages_1': 14, 'feed_stage_1': 9, 'boilup_2': 7.672555501455628, 'N_stages_2': 12, 'feed_stage_2': 7, 'boilup_3': 0.7107132445923151, 'N_stages_3': 3, 'feed_stage_3': 1, 'shortcut_time': 48.27286624908447}
# setting model: {'CAPEX': 1.5315, 'OPEX': 1.631, 'AceticAcidWt': 0.28491796555164944, 'SplitRatio': 0.01380670611439842, 'boilup_1': 9.525481271326191, 'N_stages_1': 12, 'feed_stage_1': 7, 'boilup_2': 4.320604424404303, 'N_stages_2': 7, 'feed_stage_2': 5, 'boilup_3': 0.8961352356736904, 'N_stages_3': 3, 'feed_stage_3': 1, 'shortcut_time': 48.23820996284485}
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
#  {'CAPEX': 1.2624, 'OPEX': 0.7159, 'AceticAcidWt': 0.07314401637116155, 'SplitRatio': 0.013806706114398421, 'boilup_1': 2.0919841504999375, 'N_stages_1': 5, 'feed_stage_1': 4, 'boilup_2': 1.0257557001581008, 'N_stages_2': 7, 'feed_stage_2': 7, 'boilup_3': 0.1662140005991024, 'N_stages_3': 6, 'feed_stage_3': 1, 'shortcut_time': 48.26236438751221}setting base model
# 10000.0
#  ##### An instance of the 'BlackBox' class  has been initialised!
#
#  setting model:  ##### An instance of the 'RigorousDesign' class  has been initialised!setting model:
# {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# negative dimensions are not allowed
#
# [35.69962017411322, 0.3693734428741904, 0.9919978310831615, 0.9770869583715915, 0.2687458185368499, 324.2885093365627, 0.256652383158421, 0.6671248890958916]
# Error occurred:10000.0
# setting base model[17.64456878948772, 0.8492372604158125, 0.1341170263359068, 0.47175176301615956, 0.9111281264158644, 277.5479497075529, 0.5010684033365412, 0.9293938912494775]
#
# {'CAPEX': 1.591, 'OPEX': 13.4109, 'AceticAcidWt': 0.020220278492589814, 'SplitRatio': 0.013806706114398421, 'boilup_1': 1.8071360230665898, 'N_stages_1': 5, 'feed_stage_1': 4, 'boilup_2': 0.8350683836258429, 'N_stages_2': 1, 'feed_stage_2': 1, 'boilup_3': 7.549477552674314, 'N_stages_3': -3, 'feed_stage_3': 0, 'shortcut_time': 48.24994945526123}
#  [12.312111159285811, 0.4438666272494935, 0.19084327369038998, 0.764012468567403, 0.7117929560192819, 301.9471173816868, 0.693973953494074, 0.12029569214698184]{'CAPEX': 1.3864, 'OPEX': 0.673, 'AceticAcidWt': 0.12380406690998642, 'SplitRatio': 0.01380670611439842, 'boilup_1': 1.226795074536333, 'N_stages_1': 12, 'feed_stage_1': 10, 'boilup_2': 1.943119667723627, 'N_stages_2': 9, 'feed_stage_2': 8, 'boilup_3': 0.1614205586751823, 'N_stages_3': 8, 'feed_stage_3': 1, 'shortcut_time': 48.26887011528015}negative dimensions are not allowed ##### An instance of the 'RigorousDesign' class  has been initialised!
#
#
# {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}10000.0
# [17.845486549294627, 0.5634111130134462, 0.6848799190211508, 0.800214354438531, 0.8422693534215092, 312.4410342808524, 0.8470269304119872, 0.6849618544628544] ##### An instance of the 'RigorousDesign' class  has been initialised!setting model: 10000.0
#
# capex_error
#
#
#  ##### An instance of the 'RigorousDesign' class  has been initialised!setting model: setting model: 10000.0
# 10000.0
#
# 10000.0
# ...
# [20.670617560317687, 0.08550247502067918, 0.4396053418706266, 0.3997440795945281, 0.48812275219659396, 321.64062160338386, 0.6823616725160522, 0.9991956818089288]
# setting base model
# setting model:  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# 10000.0
# capex_error
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
#  ##### An instance of the 'BlackBox' class  has been initialised![20.670617560317687, 0.08550247502067918, 0.4396053418706266, 0.3997440795945281, 0.48812275219659396, 321.64062160338386, 0.6823616725160522, 0.9991956818089288]
#
# [42.380733170587305, 0.18349961607373497, 0.5284173354305781, 0.9615633382020595, 0.5546308985262622, 298.1511908990872, 0.6417828148235215, 0.7764785811566288]setting model:
#  {'CAPEX': 0.8657, 'OPEX': 0.4963, 'AceticAcidWt': 0.020420553447393925, 'SplitRatio': 0.013806706114398421, 'boilup_1': 0.21174106137586166, 'N_stages_1': -3, 'feed_stage_1': -1, 'boilup_2': 0.6621483035822461, 'N_stages_2': 3, 'feed_stage_2': 3, 'boilup_3': 0.12216222207979435, 'N_stages_3': 8, 'feed_stage_3': 3, 'shortcut_time': 0.1942462921142578}
# 10000.0
# Error occurred: negative dimensions are not allowed
#  ##### An instance of the 'BlackBox' class  has been initialised!
# [46.201773937922844, 0.4457954671461621, 0.07827521090820261, 0.23250955206168955, 0.3972831703538536, 335.3413156005872, 0.8902288177936879, 0.0069516131232961655]
#  ##### An instance of the 'BlackBox' class  has been initialised!
# [12.518174434474407, 0.23504475475141737, 0.8919959718970576, 0.9840106147326687, 0.6599179900883084, 281.8994035583526, 0.7512978793386368, 0.5805430989438435]
# setting base model
# setting model:  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# 10000.0
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# [42.380733170587305, 0.18349961607373497, 0.5284173354305781, 0.9615633382020595, 0.5546308985262622, 298.1511908990872, 0.6417828148235215, 0.7764785811566288]
# setting model:  {'CAPEX': 1.5092, 'OPEX': 1.0448, 'AceticAcidWt': 0.3403827620878426, 'SplitRatio': 0.01380670611439842, 'boilup_1': 0.3437400269608144, 'N_stages_1': 1, 'feed_stage_1': 1, 'boilup_2': 17.389938305248354, 'N_stages_2': 18, 'feed_stage_2': 15, 'boilup_3': 0.30727068472866276, 'N_stages_3': 6, 'feed_stage_3': 1, 'shortcut_time': 0.6016292572021484}
# 10000.0
# Error occurred: list index out of range
#  ##### An instance of the 'BlackBox' class  has been initialised!
# [15.675762142712859, 0.23720001305668445, 0.3223300875042779, 0.12032836729985077, 0.7160241694197891, 331.13071999211337, 0.2259204873868615, 0.16999131801324632]
# setting base model
# setting model:  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# 10000.0
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
#
# setting base model
# setting model:  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# 10000.0
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# [21.143643193720614, 0.8152322082192375, 0.6220248517375518, 0.7698067186368193, 0.45709653697319474, 312.9466285309728, 0.7409444629986743, 0.12350767836096205]
# setting model:  {'CAPEX': 3.0827, 'OPEX': 8.8026, 'AceticAcidWt': 0.18294423061943357, 'SplitRatio': 0.013806706114398418, 'boilup_1': 2.5242363283683655, 'N_stages_1': 11, 'feed_stage_1': 8, 'boilup_2': 3.0194076356578634, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 7.026930319339185, 'N_stages_3': 3, 'feed_stage_3': 1, 'shortcut_time': 1.958888292312622}
# 10000.0
#  ##### An instance of the 'BlackBox' class  has been initialised!
# [46.7233725871742, 0.9796748588594935, 0.9080355870781132, 0.5908695833044563, 0.5399992659247511, 320.31695936466, 0.9186262456709631, 0.3290383830834303]
# setting base model
# setting model:  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# 10000.0
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# [46.7233725871742, 0.9796748588594935, 0.9080355870781132, 0.5908695833044563, 0.5399992659247511, 320.31695936466, 0.9186262456709631, 0.3290383830834303]
# setting model:  {'CAPEX': 1.9116, 'OPEX': 3.2011, 'AceticAcidWt': 0.4485913310333918, 'SplitRatio': 0.21738506669921231, 'boilup_1': 9.837821178864063, 'N_stages_1': 11, 'feed_stage_1': 7, 'boilup_2': 1.1488041643871052, 'N_stages_2': 7, 'feed_stage_2': 4, 'boilup_3': 2.119424723068693, 'N_stages_3': 6, 'feed_stage_3': 1, 'shortcut_time': 0.6317248344421387}
# 10000.0
#  ##### An instance of the 'BlackBox' class  has been initialised!
# [17.620126546313916, 0.3870215712552559, 0.3063054311940063, 0.6235371376078382, 0.4185625269693294, 299.968695029767, 0.8798744252596121, 0.5327666286526185]
# setting base model
# setting model:  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# 10000.0
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# [46.201773937922844, 0.4457954671461621, 0.07827521090820261, 0.23250955206168955, 0.3972831703538536, 335.3413156005872, 0.8902288177936879, 0.0069516131232961655]
# setting model:  {'CAPEX': 13.63, 'OPEX': 73.2605, 'AceticAcidWt': 0.004506510240045187, 'SplitRatio': 0.01380670611439842, 'boilup_1': 1.57978033353877, 'N_stages_1': -3, 'feed_stage_1': -1, 'boilup_2': 0.2786635450847609, 'N_stages_2': -2, 'feed_stage_2': -1, 'boilup_3': 112.73756809282112, 'N_stages_3': 0, 'feed_stage_3': 0, 'shortcut_time': 6.607171535491943}
# 10000.0
# Error occurred: negative dimensions are not allowed
#  ##### An instance of the 'BlackBox' class  has been initialised!
# [45.25250879816923, 0.058285335885901166, 0.4856584479648216, 0.5840509924752658, 0.2812499524914126, 319.4227321572217, 0.7399643081844, 0.7117273015544566]
# capex_error
#  ##### An instance of the 'BlackBox' class  has been initialised!
# [40.1352087483524, 0.5442287349703374, 0.2892327242039091, 0.8129174428564384, 0.21133718004593263, 334.1680167207111, 0.2710824423599626, 0.6763798607810161]
# setting base model
# setting model:  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# 10000.0
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# [17.620126546313916, 0.3870215712552559, 0.3063054311940063, 0.6235371376078382, 0.4185625269693294, 299.968695029767, 0.8798744252596121, 0.5327666286526185]
# setting model:  {'CAPEX': 1.3847, 'OPEX': 1.788, 'AceticAcidWt': 0.03405104206100585, 'SplitRatio': 0.013806706114398423, 'boilup_1': 0.9112981242232948, 'N_stages_1': 1, 'feed_stage_1': 1, 'boilup_2': 1.689730196597763, 'N_stages_2': 6, 'feed_stage_2': 6, 'boilup_3': 0.9249974696276717, 'N_stages_3': 6, 'feed_stage_3': 1, 'shortcut_time': 0.609431266784668}
# 10000.0
# Error occurred: list index out of range
#  ##### An instance of the 'BlackBox' class  has been initialised!
# [31.18611968800428, 0.40979051565119284, 0.8381496673615497, 0.497956238218419, 0.7046990551484626, 331.1520246210298, 0.2742859771362494, 0.0804196713925243]
# setting base model
# setting model:  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# 10000.0
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# [40.1352087483524, 0.5442287349703374, 0.2892327242039091, 0.8129174428564384, 0.21133718004593263, 334.1680167207111, 0.2710824423599626, 0.6763798607810161]
# setting model:  {'CAPEX': 1.2565, 'OPEX': 1.1021, 'AceticAcidWt': 0.04357086059690767, 'SplitRatio': 0.013806706114398421, 'boilup_1': 1.4422690666265094, 'N_stages_1': 3, 'feed_stage_1': 2, 'boilup_2': 4.418594863984655, 'N_stages_2': 5, 'feed_stage_2': 5, 'boilup_3': 0.483124568426318, 'N_stages_3': 4, 'feed_stage_3': 1, 'shortcut_time': 0.5559039115905762}
# 10000.0
# setting base model
# setting model:  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# 10000.0
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# [31.18611968800428, 0.40979051565119284, 0.8381496673615497, 0.497956238218419, 0.7046990551484626, 331.1520246210298, 0.2742859771362494, 0.0804196713925243]
# setting model:  {'CAPEX': 2.8516, 'OPEX': 12.7042, 'AceticAcidWt': 0.062127535772492366, 'SplitRatio': 0.013806706114398421, 'boilup_1': 0.5038437288193878, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 1.0187833795435353, 'N_stages_2': 9, 'feed_stage_2': 8, 'boilup_3': 10.024486879565856, 'N_stages_3': 0, 'feed_stage_3': 0, 'shortcut_time': 1.4756085872650146}
# 10000.0
#  ##### An instance of the 'BlackBox' class  has been initialised!
# [48.927551816378525, 0.6600718955281597, 0.5821299357358695, 0.015846495173148928, 0.35829923180442286, 313.1827140921647, 0.24275884054527896, 0.008798780597752487]
#  ##### An instance of the 'BlackBox' class  has been initialised!
# [33.07576110659168, 0.2406741845011452, 0.2453195491707805, 0.313064724557182, 0.48611137406063454, 292.3313185889901, 0.4629651656278853, 0.4775994015283211]
# setting base model
# setting model:  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# 10000.0
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# [33.07576110659168, 0.2406741845011452, 0.2453195491707805, 0.313064724557182, 0.48611137406063454, 292.3313185889901, 0.4629651656278853, 0.4775994015283211]
# setting model:  {'CAPEX': 1.1156, 'OPEX': 1.9176, 'AceticAcidWt': 0.013059880914162105, 'SplitRatio': 0.01380670611439842, 'boilup_1': 0.624554639317756, 'N_stages_1': -2, 'feed_stage_1': -1, 'boilup_2': 0.4427380538236203, 'N_stages_2': 1, 'feed_stage_2': 1, 'boilup_3': 1.1041277348909042, 'N_stages_3': 4, 'feed_stage_3': 1, 'shortcut_time': 0.7408602237701416}
# 10000.0
# Error occurred: negative dimensions are not allowed
#  ##### An instance of the 'BlackBox' class  has been initialised!
# [44.52460791456718, 0.8620129942138512, 0.8958508184942561, 0.6048142129791749, 0.6824371724562132, 337.43163032223634, 0.6225107987150044, 0.4331706072930026]
# setting base model
# setting model:  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# 10000.0
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# [44.52460791456718, 0.8620129942138512, 0.8958508184942561, 0.6048142129791749, 0.6824371724562132, 337.43163032223634, 0.6225107987150044, 0.4331706072930026]
# setting model:  {'CAPEX': 1.6156, 'OPEX': 2.0867, 'AceticAcidWt': 0.18063736528813099, 'SplitRatio': 0.16097263785104352, 'boilup_1': 2.521619699345622, 'N_stages_1': 8, 'feed_stage_1': 6, 'boilup_2': 1.3617794827455225, 'N_stages_2': 10, 'feed_stage_2': 8, 'boilup_3': 1.333999485864572, 'N_stages_3': 4, 'feed_stage_3': 1, 'shortcut_time': 0.48415422439575195}
# 10000.0
