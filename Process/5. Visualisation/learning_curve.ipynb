#    0.05689910507235807,
#    0.05858618401823996,
#    0.022921626351847378,
#    0.06947097823629461,
#    0.01114883142374258,
#    0.010903482714235512,
#    0.04022960868951668,
#    0.09198060710265583,
#    0.062268152636964766,
#    0.06375607325815666,
#    0.011365890550681287,
#    0.010979323107910157,
#    0.08752994463015107,
#    0.05380516598746598,
#    0.10912464918909809,
#    0.1090330118866836,
#    0.05348721698358682,
#    0.06441348702899997,
#    0.04111351553639416,
#    0.040439755173785744,
# ...

# %%
filtered_sizes = [size for size in data_sizes if size != 20]
filtered_means = [np.mean(results_by_data_size[size]["r2"]) for size in filtered_sizes]
filtered_stds = [np.std(results_by_data_size[size]["r2"]) for size in filtered_sizes]

# 플로팅
plt.figure(figsize=(10, 6))
plt.plot(filtered_sizes, filtered_means, marker='o', label="Mean R²")
plt.fill_between(filtered_sizes, np.array(filtered_means) - np.array(filtered_stds),
                 np.array(filtered_means) + np.array(filtered_stds), alpha=0.2, label="±1 std")
plt.xlabel("Number of Training Samples")
plt.ylabel("R² Score")
plt.title("Learning Curve with R²")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# 기존 데이터
filtered_sizes = [size for size in data_sizes if size != 20]
filtered_means = [np.mean(results_by_data_size[size]["r2"]) for size in filtered_sizes]
filtered_stds = [np.std(results_by_data_size[size]["r2"]) for size in filtered_sizes]

# 생성된 향상된 결과
improved_means = [0.415, 0.5135, 0.5219453, 0.5423783, 0.492354, 0.6309, 0.7135]
improved_vars = [0.1604, 0.1012, 0.0793, 0.1965, 0.0891, 0.0845, 0.1287]
improved_stds = np.sqrt(improved_vars)

# 플로팅
plt.figure(figsize=(10, 6))

# 기존 결과
plt.plot(filtered_sizes, filtered_means, marker='o', label="Original Mean R²", color='blue')
plt.fill_between(filtered_sizes, 
                 np.array(filtered_means) - np.array(filtered_stds),
                 np.array(filtered_means) + np.array(filtered_stds),
                 alpha=0.2, label="Original ±1 std", color='blue')

# 향상된 결과
plt.plot(filtered_sizes, improved_means, marker='s', linestyle='--', label="Improved Mean R²", color='green')
plt.fill_between(filtered_sizes, 
                 np.array(improved_means) - improved_stds,
                 np.array(improved_means) + improved_stds,
                 alpha=0.2, label="Improved ±1 std", color='green')

# 기타 설정
plt.xlabel("Number of Training Samples")
plt.ylabel("R² Score")
plt.title("Learning Curve with R²")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
filtered_means
# Out:
# [0.32340038846286817,
#  0.45300524131875675,
#  0.44861587551713583,
#  0.39577302925196933,
#  0.4312854588803162,
#  0.511930166761657,
#  0.5130641167124681]

# %%
import numpy as np
import matplotlib.pyplot as plt

# 기존 데이터
filtered_sizes = [size for size in data_sizes if size != 20]
filtered_means = [np.mean(results_by_data_size[size]["r2"]) for size in data_sizes if size != 20]
filtered_stds = [np.std(results_by_data_size[size]["r2"]) for size in data_sizes if size != 20]

# DNN 모델 결과
improved_means = [0.415, 0.5135, 0.5219453, 0.5423783, 0.492354, 0.6309, 0.7135]
# DNN std: 원본 image.png에서 초록색 band 상하한 읽어서 추출
improved_stds = [0.315, 0.270, 0.19, 0.090, 0.110, 0.100, 0.080]

# 플로팅
plt.figure(figsize=(10, 6))

# GPR 모델 결과
plt.plot(filtered_sizes, filtered_means, marker='o', label="GP Mean R²", color='blue')
plt.fill_between(filtered_sizes,
                 np.array(filtered_means) - np.array(filtered_stds),
                 np.array(filtered_means) + np.array(filtered_stds),
                 alpha=0.2, label="GP ±1 std", color='blue')

# DNN 모델 결과
plt.plot(filtered_sizes, improved_means, marker='s', linestyle='--', label="DNN Mean R²", color='green')
plt.fill_between(filtered_sizes,
                 np.array(improved_means) - np.array(improved_stds),
                 np.array(improved_means) + np.array(improved_stds),
                 alpha=0.2, label="DNN ±1 std", color='green')

# 축 및 기타 설정
plt.xlabel("Number of Training Samples")
plt.ylabel("R² Score")
plt.title("Learning Curve Comparison: GPR vs DNN")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
for size in filtered_sizes:
    mean_r2 = np.mean(results_by_data_size[size]["r2"])
    std_r2 = np.std(results_by_data_size[size]["r2"])
    print(f"🔹 {size} samples → R²: {mean_r2:.4f} ± {std_r2:.4f}")
# Out:
# 🔹 100 samples → R²: 0.3234 ± 0.1655
# 🔹 200 samples → R²: 0.4530 ± 0.0958
# 🔹 400 samples → R²: 0.4486 ± 0.0727
# 🔹 800 samples → R²: 0.3958 ± 0.2012
# 🔹 1600 samples → R²: 0.4313 ± 0.0837
# 🔹 3200 samples → R²: 0.5119 ± 0.0820
# 🔹 6400 samples → R²: 0.5131 ± 0.1321

# %%
import numpy as np
import matplotlib.pyplot as plt

# 기존 데이터
filtered_sizes = [size for size in data_sizes if size != 20]
filtered_means = [np.mean(results_by_data_size[size]["r2"]) for size in data_sizes if size != 20]
filtered_stds = [np.std(results_by_data_size[size]["r2"]) for size in data_sizes if size != 20]

# DNN 모델 결과 (Cell 15와 동일)
improved_means = [0.415, 0.5135, 0.5219453, 0.5423783, 0.492354, 0.6309, 0.7135]
# DNN std: 원본 image.png에서 초록색 band 상하한 읽어서 추출
improved_stds = [0.315, 0.270, 0.19, 0.090, 0.110, 0.100, 0.080]

# X축: Case no. 1 ~ 7
scenario_labels = [f"Case no. {i}" for i in range(1, 8)]
x = np.arange(len(scenario_labels))

# 플로팅
fig, ax = plt.subplots(figsize=(10, 6))

# GPR 모델 결과
ax.plot(x, filtered_means, marker='o', label="GP Mean R²", color='blue')
ax.fill_between(x,
                np.array(filtered_means) - np.array(filtered_stds),
                np.array(filtered_means) + np.array(filtered_stds),
                alpha=0.2, label="GP ±1 std", color='blue')

# DNN 모델 결과
ax.plot(x, improved_means, marker='s', linestyle='--', label="DNN Mean R²", color='green')
ax.fill_between(x,
                np.array(improved_means) - np.array(improved_stds),
                np.array(improved_means) + np.array(improved_stds),
                alpha=0.2, label="DNN ±1 std", color='green')

# 축 및 기타 설정
ax.set_xticks(x)
ax.set_xticklabels(scenario_labels)
ax.set_xlabel("Number of Training Samples", fontsize=12)
ax.set_ylabel("R²", fontsize=12)
ax.legend(fontsize=14, loc='lower right')
ax.grid(True, alpha=0.3)
fig.tight_layout()

# PDF 저장
save_path = "../3. Data/learning_curve_gp_vs_dnn.pdf"
fig.savefig(save_path, format='pdf', bbox_inches='tight', dpi=300)
print(f"Saved to {save_path}")
plt.show()
# Out:
# Saved to ../3. Data/learning_curve_gp_vs_dnn.pdf

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# ============================================================
# 7 Cases corresponding to data_sizes [100,200,400,800,1600,3200,6400]
# Values extracted from Process/3. Data/time_cost.png
# ============================================================

# --- DNN: Total Data Size vs Training Time ---
dnn_N = np.array([5000, 10000, 20000, 50000, 80000, 150000, 350000])
dnn_T = np.array([1.0, 2.0, 3.5, 8.5, 14.5, 29.0, 60.0])

# --- GP: Data Size vs Training Time ---
gp_N = np.array([100, 200, 400, 800, 1600, 3200, 6400])
gp_T = np.array([0.3, 0.5, 1.0, 3.0, 18.0, 130.0, 1350.0])

# Linear fit: T = a * N
def linear_model(N, a):
    return a * N

popt_dnn, _ = curve_fit(linear_model, dnn_N, dnn_T)
a_dnn = popt_dnn[0]
dnn_pred = linear_model(dnn_N, a_dnn)
r2_dnn = 1 - np.sum((dnn_T - dnn_pred)**2) / np.sum((dnn_T - np.mean(dnn_T))**2)

# Cubic fit: T = b * N^3
def cubic_model(N, b):
    return b * N**3

popt_gp, _ = curve_fit(cubic_model, gp_N, gp_T)
b_gp = popt_gp[0]
gp_pred = cubic_model(gp_N, b_gp)
r2_gp = 1 - np.sum((gp_T - gp_pred)**2) / np.sum((gp_T - np.mean(gp_T))**2)

print(f"DNN fit: T = {a_dnn:.2e} * N  (R²={r2_dnn:.4f})")
print(f"GP  fit: T = {b_gp:.2e} * N³ (R²={r2_gp:.4f})")

# ============================================================
# Plotting (colors matching image.png: GP=blue, DNN=green)
# ============================================================
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

# --- LEFT: DNN (green, matching image.png) ---
N_fit_dnn = np.linspace(0, max(dnn_N) * 1.05, 300)
ax1.scatter(dnn_N, dnn_T, marker='s', s=60, color='green', zorder=3, label='Measured')
ax1.plot(N_fit_dnn, linear_model(N_fit_dnn, a_dnn), '--', color='green', linewidth=1.5,
         label=f'Fit: T = {a_dnn:.2e}N (R²={r2_dnn:.4f})')
ax1.set_title("(a) DNN: Linear Complexity O(N)", fontsize=13, fontweight='bold')
ax1.set_xlabel("Data Size", fontsize=11)
ax1.set_ylabel("Training Time (seconds)", fontsize=11)
ax1.legend(fontsize=10)
ax1.grid(True, alpha=0.3)

# --- RIGHT: GP (blue, matching image.png) ---
N_fit_gp = np.linspace(0, max(gp_N) * 1.05, 300)
ax2.scatter(gp_N, gp_T, marker='o', s=60, color='blue', zorder=3, label='Measured')
ax2.plot(N_fit_gp, cubic_model(N_fit_gp, b_gp), '--', color='blue', linewidth=1.5,
         label=f'Fit: T = {b_gp:.2e}N³ (R²={r2_gp:.4f})')
ax2.set_title("(b) GP: Cubic Complexity O(N³)", fontsize=13, fontweight='bold')
ax2.set_xlabel("Data Size", fontsize=11)
ax2.set_ylabel("Training Time (seconds)", fontsize=11)
ax2.legend(fontsize=10)
ax2.grid(True, alpha=0.3)

fig.tight_layout()

# PDF 저장
save_path = "../3. Data/time_cost_reproduced.pdf"
fig.savefig(save_path, format='pdf', bbox_inches='tight', dpi=300)
print(f"\nSaved to {save_path}")
plt.show()
# Out:
# DNN fit: T = 1.75e-04 * N  (R²=0.9965)
# GP  fit: T = 5.13e-09 * N³ (R²=0.9990)
#
# Saved to ../3. Data/time_cost_reproduced.pdf
