# %%
cd ~/MultiFidelity-ProcessOpt/1.\ Code
# Out:
# /Users/k23070952/MultiFidelity-ProcessOpt/1. Code

# %%
from ShortCutDesign import ShortCutDesign 
from RigorousDesign import RigorousDesign 
from skopt import gp_minimize
from skopt.space import Real, Integer
from skopt.utils import use_named_args
from sklearn.metrics import mean_squared_error, r2_score
import pandas as pd
import numpy as np
import os

# %%
# ✅ 파일 경로 설정
results_file = '../3. Data/gp_bo_data_250403.csv'
error_file = '../3. Data/gp_bo_errors_250403.csv'


# ✅ Shortcut 및 Rigorous 결과 계산 함수 
def calculate_shortcut(_init_params):
    shortcut_model = ShortCutDesign()
    shortcut_results = shortcut_model.shortcut_results(_init_params)
    return shortcut_results

def calculate_rigorous(_init_params):
    shortcut_results = calculate_shortcut(_init_params)
    if shortcut_results['CAPEX'] == 0:
        return (shortcut_results, [0, 0, 0])

    if shortcut_results['CAPEX'] is None or np.isnan(shortcut_results['CAPEX']):
        return (shortcut_results, [0, 0, 0])

    RigorousCal = RigorousDesign()
    Rigorous_results = RigorousCal.func(_init_params, shortcut_results)
    return (shortcut_results, Rigorous_results)

# %%
# ✅ 평가 함수 (병렬 실행용)

bounds = [
    Integer(1, 50, name="n1"),  # Extractor stages
    Real(0, 0.9999, name="Lr1"),
    Real(0, 0.9999, name="Hr1"),
    Real(0, 0.9999, name="Lr2"),
    Real(0, 0.9999, name="Hr2"),
    Real(273, 350, name="T_hex"),
    Real(0, 0.9999, name="Lr3"),
    Real(0, 0.9999, name="Hr3")
]

opt_history = []

@use_named_args(bounds)
def objective(**params):
    X = [params[key] for key in ["n1", "Lr1", "Hr1", "Lr2", "Hr2", "T_hex", "Lr3", "Hr3"]]
    try:
        # 계산 수행
        shortcut_obj, rigorous_obj = calculate_rigosrous(X)

        msp = rigorous_obj[-1]
        
        # 결과 데이터 정리
        record = list(X) + [
            shortcut_obj['CAPEX'], shortcut_obj['OPEX'], shortcut_obj['AceticAcidWt'], shortcut_obj['SplitRatio'], 
            shortcut_obj['boilup_1'], shortcut_obj['N_stages_1'], shortcut_obj['feed_stage_1'], 
            shortcut_obj['boilup_2'],shortcut_obj['N_stages_2'],shortcut_obj['feed_stage_2'],
            shortcut_obj['boilup_3'],shortcut_obj['N_stages_3'],shortcut_obj['feed_stage_3'],shortcut_obj['shortcut_time'],
            rigorous_obj[0], rigorous_obj[1], rigorous_obj[2], rigorous_obj[3], msp, None
        ]

        # rigorous_result = (CAPEX, OPEX, AceticAcid_wt, time)
          # 예: CAPEX + OPEX

        # 실시간 CSV 저장
        df = pd.DataFrame([record])
        df.to_csv(results_file, mode='a', header=not os.path.exists(results_file), index=False)

        return msp

    except Exception as e:
        # 실패한 경우에는 파라미터와 에러 메시지만 저장
        record = list(X) + [None]*21 + [str(e)]  # 앞에 8개 + 21개 + error
        df = pd.DataFrame([record])
        df.to_csv(results_file, mode='a', header=not os.path.exists(results_file), index=False)
        
        return 10000

# %%
# Run Bayesian Optimization with GPR
res = gp_minimize(
    func=objective,
    dimensions=bounds,
    n_calls=2000,
    n_initial_points=100,
    random_state=42,
    verbose=True
)
# Out:
# Iteration No: 1 started. Evaluating function at random point.
#  ##### An instance of the 'BlackBox' class  has been initialised!
# [40, 0.18341644638717722, 0.7796130311727423, 0.5967904729306924, 0.4457881695783059, 280.6980685179862, 0.4592029670766707, 0.333675240277908]
# setting base model
# setting model:  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# 10000.0
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# [40, 0.18341644638717722, 0.7796130311727423, 0.5967904729306924, 0.4457881695783059, 280.6980685179862, 0.4592029670766707, 0.333675240277908]
# setting model:  {'CAPEX': 1.6629, 'OPEX': 3.4506, 'AceticAcidWt': 0.04454200357104111, 'SplitRatio': 0.01380670611439842, 'boilup_1': 0.2437120001482147, 'N_stages_1': 4, 'feed_stage_1': 3, 'boilup_2': 1.5059112289316585, 'N_stages_2': 6, 'feed_stage_2': 6, 'boilup_3': 1.9836798236929767, 'N_stages_3': 3, 'feed_stage_3': 1, 'shortcut_time': 1.2310330867767334}
# 10000.0
# Error occurred: <MESHDistillation: acetic_acid_purification> division by zero
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 1.3877
# Function value obtained: 10000.0000
# Current minimum: 10000.0000
# Iteration No: 2 started. Evaluating function at random point.
#  ##### An instance of the 'BlackBox' class  has been initialised!
# [8, 0.6508233841015582, 0.05640593786919756, 0.7219265723895982, 0.9384588537448488, 273.0599649697581, 0.9921123381352887, 0.6174197614767539]
# setting base model
# setting model:  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# 10000.0
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# [8, 0.6508233841015582, 0.05640593786919756, 0.7219265723895982, 0.9384588537448488, 273.0599649697581, 0.9921123381352887, 0.6174197614767539]
# setting model:  {'CAPEX': 1.3049, 'OPEX': 1.8129, 'AceticAcidWt': 0.04686314857840835, 'SplitRatio': 0.013806706114398418, 'boilup_1': 3.296966613119456, 'N_stages_1': -2, 'feed_stage_1': -1, 'boilup_2': 4.10721633613955, 'N_stages_2': 9, 'feed_stage_2': 9, 'boilup_3': 0.6741190393945351, 'N_stages_3': 10, 'feed_stage_3': 1, 'shortcut_time': 0.08659219741821289}
# 10000.0
# Error occurred: negative dimensions are not allowed
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 0.0996
# Function value obtained: 10000.0000
# Current minimum: 10000.0000
# Iteration No: 3 started. Evaluating function at random point.
#  ##### An instance of the 'BlackBox' class  has been initialised!
# [31, 0.007065598589195436, 0.02306011879891162, 0.5247221827923634, 0.39982098561808405, 276.5932560674484, 0.9736581432895752, 0.23274806329626127]
# capex_error
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 0.1324
# Function value obtained: 10000.0000
# Current minimum: 10000.0000
# Iteration No: 4 started. Evaluating function at random point.
#  ##### An instance of the 'BlackBox' class  has been initialised!
# [5, 0.6183241707321541, 0.3824237450680361, 0.9831325627182077, 0.46671621695865523, 339.2154113186967, 0.6802395078339211, 0.45045420204434616]
# setting base model
# setting model:  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# 10000.0
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# [5, 0.6183241707321541, 0.3824237450680361, 0.9831325627182077, 0.46671621695865523, 339.2154113186967, 0.6802395078339211, 0.45045420204434616]
# setting model:  {'CAPEX': 2.0017, 'OPEX': 2.0103, 'AceticAcidWt': 0.6163974311621201, 'SplitRatio': 0.013806706114398421, 'boilup_1': 1.6414569061404214, 'N_stages_1': 5, 'feed_stage_1': 4, 'boilup_2': 21.738684770091293, 'N_stages_2': 20, 'feed_stage_2': 14, 'boilup_3': 1.2520286152616846, 'N_stages_3': 5, 'feed_stage_3': 1, 'shortcut_time': 0.08980703353881836}
# 10000.0
# Error occurred: <MESHDistillation: acetic_acid_purification> division by zero
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 0.2276
# Function value obtained: 10000.0000
# Current minimum: 10000.0000
# Iteration No: 5 started. Evaluating function at random point.
#  ##### An instance of the 'BlackBox' class  has been initialised!
# [2, 0.9421075355092845, 0.5632318890237549, 0.38537796088966225, 0.015964655594992178, 290.7788245729055, 0.24100136347940918, 0.6831951924735757]
# capex_error
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 0.0663
# Function value obtained: 10000.0000
# Current minimum: 10000.0000
# Iteration No: 6 started. Evaluating function at random point.
#  ##### An instance of the 'BlackBox' class  has been initialised!
# [31, 0.833111592244991, 0.17334731704242134, 0.3910215015124836, 0.18221786417928354, 331.16282859445926, 0.4251133589037957, 0.20792086870190207]
# setting base model
# setting model:  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# 10000.0
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# [31, 0.833111592244991, 0.17334731704242134, 0.3910215015124836, 0.18221786417928354, 331.16282859445926, 0.4251133589037957, 0.20792086870190207]
# setting model:  {'CAPEX': 1.692, 'OPEX': 5.0021, 'AceticAcidWt': 0.016275895972876285, 'SplitRatio': 0.013806706114398423, 'boilup_1': 5.0029357091402575, 'N_stages_1': 5, 'feed_stage_1': 3, 'boilup_2': 0.648819004244147, 'N_stages_2': -3, 'feed_stage_2': -2, 'boilup_3': 3.6977523102021697, 'N_stages_3': 2, 'feed_stage_3': 1, 'shortcut_time': 0.147413969039917}
# 10000.0
# Error occurred: negative dimensions are not allowed
# Iteration No: 6 ended. Evaluation done at random point.
# Time taken: 0.1606
# Function value obtained: 10000.0000
# Current minimum: 10000.0000
# Iteration No: 7 started. Evaluating function at random point.
#  ##### An instance of the 'BlackBox' class  has been initialised!
# [29, 0.03131016112631303, 0.8422005461175393, 0.4497091579564288, 0.39511072097821437, 344.35273266612217, 0.7271992686568354, 0.32650811472895486]
# setting base model
# setting model:  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# 10000.0
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# [29, 0.03131016112631303, 0.8422005461175393, 0.4497091579564288, 0.39511072097821437, 344.35273266612217, 0.7271992686568354, 0.32650811472895486]
# setting model:  {'CAPEX': 1.3646, 'OPEX': 2.6802, 'AceticAcidWt': 0.027978025840441723, 'SplitRatio': 0.01380670611439842, 'boilup_1': 0.05594302529445876, 'N_stages_1': 0, 'feed_stage_1': 0, 'boilup_2': 0.8167800245843542, 'N_stages_2': 2, 'feed_stage_2': 2, 'boilup_3': 2.10436420480924, 'N_stages_3': 4, 'feed_stage_3': 1, 'shortcut_time': 0.10533285140991211}
# 10000.0
# Error occurred: list index out of range
# Iteration No: 7 ended. Evaluation done at random point.
# Time taken: 0.1175
# Function value obtained: 10000.0000
# Current minimum: 10000.0000
# Iteration No: 8 started. Evaluating function at random point.
#  ##### An instance of the 'BlackBox' class  has been initialised!
# [29, 0.5207821765998212, 0.9610759071469144, 0.8444493952932838, 0.7472453781263673, 314.55629419395916, 0.5866924905472819, 0.9651587817334119]
# setting base model
# setting model:  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# 10000.0
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# [29, 0.5207821765998212, 0.9610759071469144, 0.8444493952932838, 0.7472453781263673, 314.55629419395916, 0.5866924905472819, 0.9651587817334119]
# setting model:  {'CAPEX': 1.506, 'OPEX': 0.6079, 'AceticAcidWt': 0.20348624588428071, 'SplitRatio': 0.19949711523472197, 'boilup_1': 0.632258436195606, 'N_stages_1': 7, 'feed_stage_1': 6, 'boilup_2': 4.637631023307636, 'N_stages_2': 17, 'feed_stage_2': 15, 'boilup_3': 0.047787373873417194, 'N_stages_3': 9, 'feed_stage_3': 2, 'shortcut_time': 0.048433780670166016}
# 10000.0
# Error occurred: <MESHDistillation: acetic_acid_purification> division by zero
# Iteration No: 8 ended. Evaluation done at random point.
# Time taken: 0.3798
# Function value obtained: 10000.0000
# Current minimum: 10000.0000
# Iteration No: 9 started. Evaluating function at random point.
#  ##### An instance of the 'BlackBox' class  has been initialised!
# [31, 0.2759715821043412, 0.29624387835351207, 0.1652504123690962, 0.015634843100519817, 305.60191401439045, 0.3948420300237523, 0.2934588259005664]
# capex_error
# Iteration No: 9 ended. Evaluation done at random point.
# Time taken: 0.1136
# Function value obtained: 10000.0000
# Current minimum: 10000.0000
# Iteration No: 10 started. Evaluating function at random point.
#  ##### An instance of the 'BlackBox' class  has been initialised!
# [2, 0.19882251984839633, 0.7112708185533753, 0.7900965229771527, 0.6058993787835334, 344.32516764552787, 0.6510119177993944, 0.9148681795762266]
# setting base model
# setting model:  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# 10000.0
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# [2, 0.19882251984839633, 0.7112708185533753, 0.7900965229771527, 0.6058993787835334, 344.32516764552787, 0.6510119177993944, 0.9148681795762266]
# setting model:  {'CAPEX': 1.2861, 'OPEX': 0.603, 'AceticAcidWt': 0.10782364767941488, 'SplitRatio': 0.01380670611439842, 'boilup_1': 0.28510941397572176, 'N_stages_1': 3, 'feed_stage_1': 3, 'boilup_2': 3.7938305538871764, 'N_stages_2': 12, 'feed_stage_2': 11, 'boilup_3': 0.10725414197209322, 'N_stages_3': 8, 'feed_stage_3': 1, 'shortcut_time': 0.06221795082092285}
# 10000.0
# Error occurred: <MESHDistillation: acetic_acid_purification> division by zero
# Iteration No: 10 ended. Evaluation done at random point.
# Time taken: 0.1471
# Function value obtained: 10000.0000
# Current minimum: 10000.0000
# Iteration No: 11 started. Evaluating function at random point.
#  ##### An instance of the 'BlackBox' class  has been initialised!
# [43, 0.4494057290707897, 0.0954005754787623, 0.3707811703730466, 0.668774368538341, 324.2760214595472, 0.5912386579289565, 0.2746943208107652]
# setting base model
# setting model:  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# 10000.0
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# [43, 0.4494057290707897, 0.0954005754787623, 0.3707811703730466, 0.668774368538341, 324.2760214595472, 0.5912386579289565, 0.2746943208107652]
# setting model:  {'CAPEX': 1.6771, 'OPEX': 3.5844, 'AceticAcidWt': 0.013208957898152908, 'SplitRatio': 0.01380670611439842, 'boilup_1': 1.4904762959390883, 'N_stages_1': -2, 'feed_stage_1': -1, 'boilup_2': 0.6032106074400457, 'N_stages_2': 6, 'feed_stage_2': 6, 'boilup_3': 2.642205468749887, 'N_stages_3': 4, 'feed_stage_3': 1, 'shortcut_time': 0.12270116806030273}
# 10000.0
# Error occurred: negative dimensions are not allowed
# Iteration No: 11 ended. Evaluation done at random point.
# Time taken: 0.1355
# Function value obtained: 10000.0000
# Current minimum: 10000.0000
# Iteration No: 12 started. Evaluating function at random point.
#  ##### An instance of the 'BlackBox' class  has been initialised!
# [29, 0.3828885820663146, 0.9716149241795651, 0.8488289328836575, 0.7216573482127568, 291.1708388206696, 0.25604271592904787, 0.04042954617947751]
# Error occurred: <System: AAsep> could not converge
# Highest convergence error among components in recycle
# stream H2-0 after 200 loops:
# - flow rate   1.70e+02 kmol/hr (3.7%)
# - temperature 0.00e+00 K (0%)
# Iteration No: 12 ended. Evaluation done at random point.
# Time taken: 1.4616
# Function value obtained: 10000.0000
# Current minimum: 10000.0000
# Iteration No: 13 started. Evaluating function at random point.
#  ##### An instance of the 'BlackBox' class  has been initialised!
# [36, 0.11087973172975017, 0.43929256821558366, 0.2016990304151627, 0.8956740193139523, 309.60350718502264, 0.5632192444191861, 0.695446534817485]
# setting base model
# setting model:  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# 10000.0
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# [36, 0.11087973172975017, 0.43929256821558366, 0.2016990304151627, 0.8956740193139523, 309.60350718502264, 0.5632192444191861, 0.695446534817485]
# setting model:  {'CAPEX': 1.0498, 'OPEX': 0.9109, 'AceticAcidWt': 0.025750132023562272, 'SplitRatio': 0.01380670611439842, 'boilup_1': 0.26027376056289125, 'N_stages_1': -2, 'feed_stage_1': -1, 'boilup_2': 0.26720304470686634, 'N_stages_2': 8, 'feed_stage_2': 8, 'boilup_3': 0.4561013225270939, 'N_stages_3': 5, 'feed_stage_3': 1, 'shortcut_time': 0.0645761489868164}
# 10000.0
# Error occurred: negative dimensions are not allowed
# Iteration No: 13 ended. Evaluation done at random point.
# Time taken: 0.0772
# Function value obtained: 10000.0000
# Current minimum: 10000.0000
# Iteration No: 14 started. Evaluating function at random point.
#  ##### An instance of the 'BlackBox' class  has been initialised!
# [8, 0.6043569375398896, 0.5397871071925431, 0.20304091861229598, 0.9427592852009254, 319.11264091961726, 0.6947154545464007, 0.8803797922313564]
# setting base model
# setting model:  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# 10000.0
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# [8, 0.6043569375398896, 0.5397871071925431, 0.20304091861229598, 0.9427592852009254, 319.11264091961726, 0.6947154545464007, 0.8803797922313564]
# setting model:  {'CAPEX': 1.3098, 'OPEX': 0.6234, 'AceticAcidWt': 0.05861178378752329, 'SplitRatio': 0.013806706114398421, 'boilup_1': 1.3213220199483773, 'N_stages_1': 7, 'feed_stage_1': 5, 'boilup_2': 0.27027654468548407, 'N_stages_2': 11, 'feed_stage_2': 11, 'boilup_3': 0.15257745699656022, 'N_stages_3': 7, 'feed_stage_3': 1, 'shortcut_time': 0.03955817222595215}
# 10000.0
# Error occurred: <MESHDistillation: acetic_acid_purification> division by zero
# Iteration No: 14 ended. Evaluation done at random point.
# Time taken: 0.1867
# Function value obtained: 10000.0000
# Current minimum: 10000.0000
# Iteration No: 15 started. Evaluating function at random point.
#  ##### An instance of the 'BlackBox' class  has been initialised!
# [32, 0.29560412246913026, 0.10548371040428761, 0.4564889170258621, 0.21841859317311196, 305.0712659860182, 0.8831919308929767, 0.3243125865031735]
# capex_error
# Iteration No: 15 ended. Evaluation done at random point.
# Time taken: 0.1193
# Function value obtained: 10000.0000
# Current minimum: 10000.0000
# Iteration No: 16 started. Evaluating function at random point.
#  ##### An instance of the 'BlackBox' class  has been initialised!
# [7, 0.3562622082931673, 0.9067377587015997, 0.2721050361596969, 0.6476253515293083, 273.0400690286393, 0.35253359944853563, 0.3047507800322133]
# setting base model
# setting model:  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# 10000.0
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# [7, 0.3562622082931673, 0.9067377587015997, 0.2721050361596969, 0.6476253515293083, 273.0400690286393, 0.35253359944853563, 0.3047507800322133]
# setting model:  {'CAPEX': 1.6912, 'OPEX': 3.7785, 'AceticAcidWt': 0.039185661924670885, 'SplitRatio': 0.013806706114398421, 'boilup_1': 0.36004790103763057, 'N_stages_1': 10, 'feed_stage_1': 8, 'boilup_2': 0.37830473011839294, 'N_stages_2': 3, 'feed_stage_2': 3, 'boilup_3': 2.229516761555035, 'N_stages_3': 3, 'feed_stage_3': 1, 'shortcut_time': 0.08591818809509277}
# 10000.0
# Error occurred: <MESHDistillation: acetic_acid_purification> division by zero
# Iteration No: 16 ended. Evaluation done at random point.
# Time taken: 0.6787
# Function value obtained: 10000.0000
# Current minimum: 10000.0000
# Iteration No: 17 started. Evaluating function at random point.
#  ##### An instance of the 'BlackBox' class  has been initialised!
# [9, 0.5340360104335046, 0.4847814883618474, 0.6923667892869815, 0.26938539256514166, 291.79766521307863, 0.1682742130687133, 0.218742343151113]
# setting base model
# setting model:  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# 10000.0
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# [9, 0.5340360104335046, 0.4847814883618474, 0.6923667892869815, 0.26938539256514166, 291.79766521307863, 0.1682742130687133, 0.218742343151113]
# setting model:  {'CAPEX': 1.8066, 'OPEX': 5.2282, 'AceticAcidWt': 0.040391759960669696, 'SplitRatio': 0.013806706114398421, 'boilup_1': 1.137472694817143, 'N_stages_1': 5, 'feed_stage_1': 4, 'boilup_2': 2.275929942516801, 'N_stages_2': 4, 'feed_stage_2': 4, 'boilup_3': 3.3583388950784347, 'N_stages_3': 1, 'feed_stage_3': 1, 'shortcut_time': 0.09609818458557129}
# 10000.0
# Error occurred: <MESHDistillation: acetic_acid_purification> division by zero
# Iteration No: 17 ended. Evaluation done at random point.
# Time taken: 0.1925
# Function value obtained: 10000.0000
# Current minimum: 10000.0000
# Iteration No: 18 started. Evaluating function at random point.
#  ##### An instance of the 'BlackBox' class  has been initialised!
# [28, 0.40379578744093514, 0.06488575788427067, 0.25389002239295133, 0.2468513752323174, 326.6154290086637, 0.7121993628654497, 0.1480721212604046]
# capex_error
# Iteration No: 18 ended. Evaluation done at random point.
# Time taken: 0.1679
# Function value obtained: 10000.0000
# Current minimum: 10000.0000
# Iteration No: 19 started. Evaluating function at random point.
#  ##### An instance of the 'BlackBox' class  has been initialised!
# [50, 0.2667543361738575, 0.9765172943370699, 0.4109959096168996, 0.033047427827258335, 299.5704860980546, 0.6342879095668937, 0.6806373810096115]
# capex_error
# Iteration No: 19 ended. Evaluation done at random point.
# Time taken: 0.0751
# Function value obtained: 10000.0000
# Current minimum: 10000.0000
# Iteration No: 20 started. Evaluating function at random point.
#  ##### An instance of the 'BlackBox' class  has been initialised!
# [27, 0.4477383862566344, 0.552837799762421, 0.5926374542070058, 0.08084524100008199, 301.4633931167281, 0.2421357222835982, 0.8030594424042581]
# setting base model
# setting model:  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# 10000.0
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# [27, 0.4477383862566344, 0.552837799762421, 0.5926374542070058, 0.08084524100008199, 301.4633931167281, 0.2421357222835982, 0.8030594424042581]
# setting model:  {'CAPEX': 0.9891, 'OPEX': 0.8687, 'AceticAcidWt': 0.01072052454155554, 'SplitRatio': 0.01380670611439842, 'boilup_1': 0.82155820567213, 'N_stages_1': 5, 'feed_stage_1': 4, 'boilup_2': 1.4074559832319307, 'N_stages_2': -3, 'feed_stage_2': -2, 'boilup_3': 0.2505239288432843, 'N_stages_3': 5, 'feed_stage_3': 1, 'shortcut_time': 0.07033610343933105}
# 10000.0
# Error occurred: negative dimensions are not allowed
# Iteration No: 20 ended. Evaluation done at random point.
# Time taken: 0.0846
# Function value obtained: 10000.0000
# Current minimum: 10000.0000
# Iteration No: 21 started. Evaluating function at random point.
#  ##### An instance of the 'BlackBox' class  has been initialised!
# [24, 0.9833247985807537, 0.3987845600003087, 0.8163502300320622, 0.7982652904720529, 284.6052508853381, 0.5081479568630447, 0.6957432255102028]
# setting base model
# setting model:  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# 10000.0
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# [24, 0.9833247985807537, 0.3987845600003087, 0.8163502300320622, 0.7982652904720529, 284.6052508853381, 0.5081479568630447, 0.6957432255102028]
# setting model:  {'CAPEX': 1.78, 'OPEX': 1.3634, 'AceticAcidWt': 0.6784836193436253, 'SplitRatio': 0.013806706114398421, 'boilup_1': 16.703555743044326, 'N_stages_1': 16, 'feed_stage_1': 7, 'boilup_2': 1.3701413134464262, 'N_stages_2': 16, 'feed_stage_2': 9, 'boilup_3': 0.4535572607372216, 'N_stages_3': 5, 'feed_stage_3': 1, 'shortcut_time': 0.06777787208557129}
# 10000.0
# Error occurred: <MESHDistillation: acetic_acid_purification> division by zero
# Iteration No: 21 ended. Evaluation done at random point.
# Time taken: 2.2183
# Function value obtained: 10000.0000
# Current minimum: 10000.0000
# Iteration No: 22 started. Evaluating function at random point.
#  ##### An instance of the 'BlackBox' class  has been initialised!
# [43, 0.3259263093113646, 0.2202190234607918, 0.7110784174847742, 0.8094200960351017, 299.8472810214632, 0.09616693343631165, 0.9404292121631552]
# setting base model
# setting model:  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# 10000.0
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# [43, 0.3259263093113646, 0.2202190234607918, 0.7110784174847742, 0.8094200960351017, 299.8472810214632, 0.09616693343631165, 0.9404292121631552]
# setting model:  {'CAPEX': 1.1586, 'OPEX': 0.6593, 'AceticAcidWt': 0.053550884319478, 'SplitRatio': 0.013806706114398423, 'boilup_1': 0.8544604463421238, 'N_stages_1': -1, 'feed_stage_1': 0, 'boilup_2': 2.76724654819915, 'N_stages_2': 15, 'feed_stage_2': 14, 'boilup_3': 0.06519623765653604, 'N_stages_3': 5, 'feed_stage_3': 1, 'shortcut_time': 0.048069000244140625}
# 10000.0
# Error occurred: negative dimensions are not allowed
# Iteration No: 22 ended. Evaluation done at random point.
# Time taken: 0.0610
# Function value obtained: 10000.0000
# Current minimum: 10000.0000
# Iteration No: 23 started. Evaluating function at random point.
#  ##### An instance of the 'BlackBox' class  has been initialised!
# [20, 0.5176995753924275, 0.8376263348967374, 0.6756225480275769, 0.7351425976288481, 289.09851479680395, 0.5413938290301832, 0.6957148209051478]
# setting base model
# setting model:  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# 10000.0
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# [20, 0.5176995753924275, 0.8376263348967374, 0.6756225480275769, 0.7351425976288481, 289.09851479680395, 0.5413938290301832, 0.6957148209051478]
# setting model:  {'CAPEX': 1.4305, 'OPEX': 1.1825, 'AceticAcidWt': 0.11701156080686584, 'SplitRatio': 0.01380670611439842, 'boilup_1': 0.6801533799818348, 'N_stages_1': 10, 'feed_stage_1': 8, 'boilup_2': 2.0361558972054383, 'N_stages_2': 12, 'feed_stage_2': 11, 'boilup_3': 0.45459602172701774, 'N_stages_3': 5, 'feed_stage_3': 1, 'shortcut_time': 0.059623003005981445}
# 10000.0
# Error occurred: <MESHDistillation: acetic_acid_purification> division by zero
# Iteration No: 23 ended. Evaluation done at random point.
# Time taken: 0.2809
# Function value obtained: 10000.0000
# Current minimum: 10000.0000
# Iteration No: 24 started. Evaluating function at random point.
#  ##### An instance of the 'BlackBox' class  has been initialised!
# [12, 0.1749374316032266, 0.9820701264951028, 0.5165842276818873, 0.26080309191292605, 349.7115348813602, 0.965322809353665, 0.558237624261737]
# setting base model
# setting model:  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# 10000.0
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# [12, 0.1749374316032266, 0.9820701264951028, 0.5165842276818873, 0.26080309191292605, 349.7115348813602, 0.965322809353665, 0.558237624261737]
# setting model:  {'CAPEX': 1.2937, 'OPEX': 1.3718, 'AceticAcidWt': 0.03025934350452018, 'SplitRatio': 0.13782361190944128, 'boilup_1': 0.15576681870250855, 'N_stages_1': 6, 'feed_stage_1': 6, 'boilup_2': 1.0794987855028504, 'N_stages_2': 1, 'feed_stage_2': 1, 'boilup_3': 0.8426618511662376, 'N_stages_3': 8, 'feed_stage_3': 1, 'shortcut_time': 0.07345724105834961}
# 10000.0
# acetic_acid:  0.09418581426508463
# lower
# Iteration No: 24 ended. Evaluation done at random point.
# Time taken: 1.6323
# Function value obtained: 7.8900
# Current minimum: 7.8900
# Iteration No: 25 started. Evaluating function at random point.
#  ##### An instance of the 'BlackBox' class  has been initialised!
# [44, 0.1886882376305453, 0.27884346545692273, 0.7002877941897742, 0.8465764761240823, 338.93697047461313, 0.404467676309478, 0.8876813217510839]
# setting base model
# setting model:  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# 10000.0
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# [44, 0.1886882376305453, 0.27884346545692273, 0.7002877941897742, 0.8465764761240823, 338.93697047461313, 0.404467676309478, 0.8876813217510839]
# setting model:  {'CAPEX': 1.0102, 'OPEX': 0.6426, 'AceticAcidWt': 0.05540406949849813, 'SplitRatio': 0.013806706114398418, 'boilup_1': 0.4503738835574692, 'N_stages_1': -2, 'feed_stage_1': -1, 'boilup_2': 2.7830836477623873, 'N_stages_2': 8, 'feed_stage_2': 8, 'boilup_3': 0.13586822366164547, 'N_stages_3': 6, 'feed_stage_3': 1, 'shortcut_time': 0.20267915725708008}
# 10000.0
# Error occurred: negative dimensions are not allowed
# Iteration No: 25 ended. Evaluation done at random point.
# Time taken: 0.2170
# Function value obtained: 10000.0000
# Current minimum: 7.8900
# Iteration No: 26 started. Evaluating function at random point.
#  ##### An instance of the 'BlackBox' class  has been initialised!
# [43, 0.9355414307215256, 0.7852621170488324, 0.6689213558887573, 0.5806285527743111, 301.6657730252542, 0.9400394291135329, 0.973566470371642]
# setting base model
# setting model:  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# 10000.0
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# [43, 0.9355414307215256, 0.7852621170488324, 0.6689213558887573, 0.5806285527743111, 301.6657730252542, 0.9400394291135329, 0.973566470371642]
# setting model:  {'CAPEX': 1.7788, 'OPEX': 0.6897, 'AceticAcidWt': 0.23752185737609866, 'SplitRatio': 0.01380670611439842, 'boilup_1': 4.129176525453153, 'N_stages_1': 16, 'feed_stage_1': 11, 'boilup_2': 1.690515026077776, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 0.04649268388386424, 'N_stages_3': 15, 'feed_stage_3': 1, 'shortcut_time': 0.048322200775146484}
# 10000.0
# Error occurred: <MESHDistillation: acetic_acid_purification> division by zero
# Iteration No: 26 ended. Evaluation done at random point.
# Time taken: 0.3255
# Function value obtained: 10000.0000
# Current minimum: 7.8900
# Iteration No: 27 started. Evaluating function at random point.
#  ##### An instance of the 'BlackBox' class  has been initialised!
# [15, 0.30533332395835905, 0.4855651922108681, 0.4483793005719488, 0.9943580168645598, 286.5462444561556, 0.01807355607915932, 0.4938443258119164]
# setting base model
# setting model:  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# 10000.0
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# [15, 0.30533332395835905, 0.4855651922108681, 0.4483793005719488, 0.9943580168645598, 286.5462444561556, 0.01807355607915932, 0.4938443258119164]
# setting model:  {'CAPEX': 1.2146, 'OPEX': 2.1069, 'AceticAcidWt': 0.053855392305355805, 'SplitRatio': 0.01380670611439842, 'boilup_1': 0.577615516468119, 'N_stages_1': 2, 'feed_stage_1': 2, 'boilup_2': 1.4789715589786074, 'N_stages_2': 11, 'feed_stage_2': 11, 'boilup_3': 0.9940251633671967, 'N_stages_3': 0, 'feed_stage_3': 0, 'shortcut_time': 0.06406998634338379}
# 10000.0
# Error occurred: <MESHDistillation: acetic_acid_purification> division by zero
# Iteration No: 27 ended. Evaluation done at random point.
# Time taken: 0.1270
# Function value obtained: 10000.0000
# Current minimum: 7.8900
# Iteration No: 28 started. Evaluating function at random point.
#  ##### An instance of the 'BlackBox' class  has been initialised!
# [10, 0.3664321377044017, 0.7440961060042568, 0.7208678302597041, 0.30802998577320406, 314.77559775272726, 0.5087631954310763, 0.6362689849240769]
# setting base model
# setting model:  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# 10000.0
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# [10, 0.3664321377044017, 0.7440961060042568, 0.7208678302597041, 0.30802998577320406, 314.77559775272726, 0.5087631954310763, 0.6362689849240769]
# setting model:  {'CAPEX': 1.3676, 'OPEX': 1.2235, 'AceticAcidWt': 0.05981360297494849, 'SplitRatio': 0.01380670611439842, 'boilup_1': 0.5118229737916482, 'N_stages_1': 6, 'feed_stage_1': 5, 'boilup_2': 2.617547336059657, 'N_stages_2': 5, 'feed_stage_2': 4, 'boilup_3': 0.5880123277066562, 'N_stages_3': 5, 'feed_stage_3': 1, 'shortcut_time': 0.06775188446044922}
# 10000.0
# Error occurred: <MESHDistillation: acetic_acid_purification> division by zero
# Iteration No: 28 ended. Evaluation done at random point.
# Time taken: 0.1996
# Function value obtained: 10000.0000
# Current minimum: 7.8900
# Iteration No: 29 started. Evaluating function at random point.
#  ##### An instance of the 'BlackBox' class  has been initialised!
# [13, 0.5898118604757879, 0.9787949689891818, 0.4866934787441593, 0.9060081778397824, 306.448366144303, 0.35004339985390626, 0.6450388516943619]
# setting base model
# setting model:  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# 10000.0
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# [13, 0.5898118604757879, 0.9787949689891818, 0.4866934787441593, 0.9060081778397824, 306.448366144303, 0.35004339985390626, 0.6450388516943619]
# setting model:  {'CAPEX': 1.3183, 'OPEX': 1.2615, 'AceticAcidWt': 0.0887492214884833, 'SplitRatio': 0.26071842738242823, 'boilup_1': 0.7306486339034989, 'N_stages_1': 7, 'feed_stage_1': 7, 'boilup_2': 1.146874500995611, 'N_stages_2': 7, 'feed_stage_2': 7, 'boilup_3': 0.5583108189187072, 'N_stages_3': 4, 'feed_stage_3': 1, 'shortcut_time': 0.05855894088745117}
# 10000.0
# Error occurred: <MESHDistillation: acetic_acid_purification> division by zero
# Iteration No: 29 ended. Evaluation done at random point.
# Time taken: 0.2020
# Function value obtained: 10000.0000
# Current minimum: 7.8900
# Iteration No: 30 started. Evaluating function at random point.
#  ##### An instance of the 'BlackBox' class  has been initialised!
# [34, 0.8640811483153961, 0.23016224971473118, 0.49914346054676395, 0.5719469987892623, 332.1786591015858, 0.04359941137725831, 0.9944510557462615]
# setting base model
# setting model:  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# 10000.0
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# [34, 0.8640811483153961, 0.23016224971473118, 0.49914346054676395, 0.5719469987892623, 332.1786591015858, 0.04359941137725831, 0.9944510557462615]
# setting model:  {'CAPEX': 1.0934, 'OPEX': 0.5188, 'AceticAcidWt': 0.07932123578253322, 'SplitRatio': 0.013806706114398421, 'boilup_1': 5.433731510487559, 'N_stages_1': 7, 'feed_stage_1': 5, 'boilup_2': 1.0036711709603698, 'N_stages_2': 6, 'feed_stage_2': 5, 'boilup_3': 0.00640909527029252, 'N_stages_3': 7, 'feed_stage_3': 2, 'shortcut_time': 0.04204273223876953}
# 10000.0
# Error occurred: <MESHDistillation: acetic_acid_purification> division by zero
# Iteration No: 30 ended. Evaluation done at random point.
# Time taken: 0.1892
# Function value obtained: 10000.0000
# Current minimum: 7.8900
# Iteration No: 31 started. Evaluating function at random point.
#  ##### An instance of the 'BlackBox' class  has been initialised!
# [24, 0.279532385762579, 0.8834056728640326, 0.7476440020200243, 0.952976539839251, 298.46777345962954, 0.5527096903388065, 0.5722352399239213]
# setting base model
# setting model:  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# 10000.0
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# [24, 0.279532385762579, 0.8834056728640326, 0.7476440020200243, 0.952976539839251, 298.46777345962954, 0.5527096903388065, 0.5722352399239213]
# setting model:  {'CAPEX': 1.5151, 'OPEX': 1.6449, 'AceticAcidWt': 0.14746458858894335, 'SplitRatio': 0.013806706114398421, 'boilup_1': 0.2960848296901831, 'N_stages_1': 8, 'feed_stage_1': 7, 'boilup_2': 4.060120047582418, 'N_stages_2': 9, 'feed_stage_2': 9, 'boilup_3': 0.7666246789495494, 'N_stages_3': 5, 'feed_stage_3': 1, 'shortcut_time': 0.06271886825561523}
# 10000.0
# Error occurred: <MESHDistillation: acetic_acid_purification> division by zero
# Iteration No: 31 ended. Evaluation done at random point.
# Time taken: 0.1924
# Function value obtained: 10000.0000
# Current minimum: 7.8900
# Iteration No: 32 started. Evaluating function at random point.
#  ##### An instance of the 'BlackBox' class  has been initialised!
# [49, 0.0753387213805276, 0.3056664495852532, 0.19089194004723103, 0.2684480094044679, 310.3665503192763, 0.37264959840733997, 0.39465199766279135]
# capex_error
# Iteration No: 32 ended. Evaluation done at random point.
# Time taken: 0.0728
# Function value obtained: 10000.0000
# Current minimum: 7.8900
# Iteration No: 33 started. Evaluating function at random point.
#  ##### An instance of the 'BlackBox' class  has been initialised!
# [42, 0.929923833127351, 0.07040908923645896, 0.2088978257435987, 0.6710764024723683, 300.6158021598046, 0.2541382327048318, 0.2952610593600969]
# setting base model
# setting model:  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# 10000.0
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# [42, 0.929923833127351, 0.07040908923645896, 0.2088978257435987, 0.6710764024723683, 300.6158021598046, 0.2541382327048318, 0.2952610593600969]
# setting model:  {'CAPEX': 1.6191, 'OPEX': 3.808, 'AceticAcidWt': 0.04249516325094705, 'SplitRatio': 0.01380670611439842, 'boilup_1': 13.436950653388775, 'N_stages_1': 5, 'feed_stage_1': 3, 'boilup_2': 0.269032802970171, 'N_stages_2': 2, 'feed_stage_2': 2, 'boilup_3': 2.3121115387379167, 'N_stages_3': 2, 'feed_stage_3': 1, 'shortcut_time': 0.1265869140625}
# 10000.0
# acetic_acid:  0.6504821675676197
# lower
# Iteration No: 33 ended. Evaluation done at random point.
# Time taken: 2.5129
# Function value obtained: 1.8833
# Current minimum: 1.8833
# Iteration No: 34 started. Evaluating function at random point.
#  ##### An instance of the 'BlackBox' class  has been initialised!
# [17, 0.8485849279451821, 0.13660766930888465, 0.7088401058104277, 0.5527646949102171, 295.8312810608805, 0.419738878360632, 0.25618132290009865]
# setting base model
# setting model:  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# 10000.0
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# [17, 0.8485849279451821, 0.13660766930888465, 0.7088401058104277, 0.5527646949102171, 295.8312810608805, 0.419738878360632, 0.25618132290009865]
# setting model:  {'CAPEX': 1.919, 'OPEX': 4.4995, 'AceticAcidWt': 0.08508799072080624, 'SplitRatio': 0.013806706114398421, 'boilup_1': 5.875793821055788, 'N_stages_1': 5, 'feed_stage_1': 3, 'boilup_2': 2.4654079248783836, 'N_stages_2': 9, 'feed_stage_2': 8, 'boilup_3': 2.839784641120308, 'N_stages_3': 3, 'feed_stage_3': 1, 'shortcut_time': 0.1024026870727539}
# 10000.0
# Error occurred: <MESHDistillation: acetic_acid_purification> division by zero
# Iteration No: 34 ended. Evaluation done at random point.
# Time taken: 0.2213
# Function value obtained: 10000.0000
# Current minimum: 1.8833
# Iteration No: 35 started. Evaluating function at random point.
#  ##### An instance of the 'BlackBox' class  has been initialised!
# [31, 0.08158602098220034, 0.0051843442877093785, 0.6278316255071413, 0.19425452611669108, 278.46245060899446, 0.3967441488311671, 0.05076345418629301]
# capex_error
# Iteration No: 35 ended. Evaluation done at random point.
# Time taken: 0.3510
# Function value obtained: 10000.0000
# Current minimum: 1.8833
# Iteration No: 36 started. Evaluating function at random point.
#  ##### An instance of the 'BlackBox' class  has been initialised!
# [44, 0.027614010196517342, 0.5788070090180081, 0.4384302756057853, 0.67195893268167, 298.2677553955544, 0.15502611256607143, 0.9817427042217003]
# capex_error
# Iteration No: 36 ended. Evaluation done at random point.
# Time taken: 0.0616
# Function value obtained: 10000.0000
# Current minimum: 1.8833
# Iteration No: 37 started. Evaluating function at random point.
#  ##### An instance of the 'BlackBox' class  has been initialised!
# [42, 0.8603185778498443, 0.25022633537981254, 0.03883085095598027, 0.30323518812175554, 314.3553468941425, 0.32661857667186134, 0.8277862168872101]
# capex_error
# Iteration No: 37 ended. Evaluation done at random point.
# Time taken: 0.0687
# Function value obtained: 10000.0000
# Current minimum: 1.8833
# Iteration No: 38 started. Evaluating function at random point.
#  ##### An instance of the 'BlackBox' class  has been initialised!
# [14, 0.965155305207731, 0.4572194350975673, 0.8419388727044804, 0.1943605959914736, 304.67425068936427, 0.6994422595461173, 0.1383392571085596]
# setting base model
# setting model:  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# 10000.0
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# [14, 0.965155305207731, 0.4572194350975673, 0.8419388727044804, 0.1943605959914736, 304.67425068936427, 0.6994422595461173, 0.1383392571085596]
# setting model:  {'CAPEX': 2.8612, 'OPEX': 8.5836, 'AceticAcidWt': 0.29477091717742887, 'SplitRatio': 0.01380670611439842, 'boilup_1': 10.041567710054414, 'N_stages_1': 14, 'feed_stage_1': 7, 'boilup_2': 4.9901677909768525, 'N_stages_2': 6, 'feed_stage_2': 4, 'boilup_3': 6.144912490111463, 'N_stages_3': 3, 'feed_stage_3': 1, 'shortcut_time': 0.1618790626525879}
# 10000.0
# Error occurred: <MESHDistillation: acetic_acid_purification> division by zero
# Iteration No: 38 ended. Evaluation done at random point.
# Time taken: 0.4532
# Function value obtained: 10000.0000
# Current minimum: 1.8833
# Iteration No: 39 started. Evaluating function at random point.
#  ##### An instance of the 'BlackBox' class  has been initialised!
# [8, 0.9694399134274478, 0.7145236446695342, 0.04106341001619901, 0.39878101935465016, 306.3810967937171, 0.7439682387348155, 0.2508354412939266]
# capex_error
# Iteration No: 39 ended. Evaluation done at random point.
# Time taken: 0.1226
# Function value obtained: 10000.0000
# Current minimum: 1.8833
# Iteration No: 40 started. Evaluating function at random point.
#  ##### An instance of the 'BlackBox' class  has been initialised!
# [10, 0.08086487932053597, 0.4282716434926139, 0.68843105077529, 0.05818777614889278, 343.471457027239, 0.44230799450813146, 0.23976338042148757]
# setting base model
# setting model:  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# 10000.0
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# [10, 0.08086487932053597, 0.4282716434926139, 0.68843105077529, 0.05818777614889278, 343.471457027239, 0.44230799450813146, 0.23976338042148757]
# setting model:  {'CAPEX': 1.4232, 'OPEX': 3.9337, 'AceticAcidWt': 0.004806388064694946, 'SplitRatio': 0.01380670611439842, 'boilup_1': 0.197466462180189, 'N_stages_1': -3, 'feed_stage_1': -1, 'boilup_2': 2.0248313393342188, 'N_stages_2': -3, 'feed_stage_2': -2, 'boilup_3': 3.1047745655665704, 'N_stages_3': 3, 'feed_stage_3': 1, 'shortcut_time': 0.16657090187072754}
# 10000.0
# Error occurred: negative dimensions are not allowed
# Iteration No: 40 ended. Evaluation done at random point.
# Time taken: 0.1795
# Function value obtained: 10000.0000
# Current minimum: 1.8833
# Iteration No: 41 started. Evaluating function at random point.
#  ##### An instance of the 'BlackBox' class  has been initialised!
# [6, 0.18284771050759663, 0.934520535939976, 0.6382067667839662, 0.5166445878008241, 323.5975722945129, 0.4356293313880234, 0.7299663126301624]
# setting base model
# setting model:  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# 10000.0
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# [6, 0.18284771050759663, 0.934520535939976, 0.6382067667839662, 0.5166445878008241, 323.5975722945129, 0.4356293313880234, 0.7299663126301624]
# setting model:  {'CAPEX': 1.3413, 'OPEX': 0.8945, 'AceticAcidWt': 0.06518598600984651, 'SplitRatio': 0.01380670611439842, 'boilup_1': 0.17195920946929527, 'N_stages_1': 8, 'feed_stage_1': 7, 'boilup_2': 1.7965437408936242, 'N_stages_2': 7, 'feed_stage_2': 6, 'boilup_3': 0.38186506413400395, 'N_stages_3': 5, 'feed_stage_3': 1, 'shortcut_time': 0.08186507225036621}
# 10000.0
# Error occurred: <MESHDistillation: acetic_acid_purification> division by zero
# Iteration No: 41 ended. Evaluation done at random point.
# Time taken: 0.1689
# Function value obtained: 10000.0000
# Current minimum: 1.8833
# Iteration No: 42 started. Evaluating function at random point.
#  ##### An instance of the 'BlackBox' class  has been initialised!
# [3, 0.565980606773027, 0.1586305829977268, 0.12015263134086164, 0.34184547874973, 280.06852806763504, 0.09414757256973329, 0.3113821680603551]
# capex_error
# Iteration No: 42 ended. Evaluation done at random point.
# Time taken: 0.1144
# Function value obtained: 10000.0000
# Current minimum: 1.8833
# Iteration No: 43 started. Evaluating function at random point.
#  ##### An instance of the 'BlackBox' class  has been initialised!
# [49, 0.17531273686234963, 0.017159385721567066, 0.7632880865616107, 0.8068322857530746, 299.66543272388384, 0.4646273455583176, 0.6497087052744992]
# capex_error
# Iteration No: 43 ended. Evaluation done at random point.
# Time taken: 0.0764
# Function value obtained: 10000.0000
# Current minimum: 1.8833
# Iteration No: 44 started. Evaluating function at random point.
#  ##### An instance of the 'BlackBox' class  has been initialised!
# [3, 0.949050817018227, 0.886591719259318, 0.26086753397937984, 0.015303009836355715, 344.8745957221202, 0.5009897799268678, 0.5393235106552227]
# capex_error
# Iteration No: 44 ended. Evaluation done at random point.
# Time taken: 0.0864
# Function value obtained: 10000.0000
# Current minimum: 1.8833
# Iteration No: 45 started. Evaluating function at random point.
#  ##### An instance of the 'BlackBox' class  has been initialised!
# [35, 0.615789579273475, 0.9437972154003014, 0.9441571719654551, 0.8671122136616485, 322.00307700334287, 0.8008691997529317, 0.6771006255487435]
# setting base model
# setting model:  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# 10000.0
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# [35, 0.615789579273475, 0.9437972154003014, 0.9441571719654551, 0.8671122136616485, 322.00307700334287, 0.8008691997529317, 0.6771006255487435]
# setting model:  {'CAPEX': 1.5119, 'OPEX': 1.2274, 'AceticAcidWt': 0.5036937860090669, 'SplitRatio': 0.1796745130574824, 'boilup_1': 0.8906374575430682, 'N_stages_1': 7, 'feed_stage_1': 6, 'boilup_2': 9.64157992648952, 'N_stages_2': 11, 'feed_stage_2': 10, 'boilup_3': 0.5045804266746706, 'N_stages_3': 6, 'feed_stage_3': 1, 'shortcut_time': 0.07432794570922852}
# 10000.0
# Error occurred: <MESHDistillation: acetic_acid_purification> division by zero
# Iteration No: 45 ended. Evaluation done at random point.
# Time taken: 0.2578
# Function value obtained: 10000.0000
# Current minimum: 1.8833
# Iteration No: 46 started. Evaluating function at random point.
#  ##### An instance of the 'BlackBox' class  has been initialised!
# [29, 0.12848750319858682, 0.8111230563183296, 0.8205574117963812, 0.6258770761345628, 336.17286697038764, 0.6514196233806023, 0.20666369144075777]
# setting base model
# setting model:  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# 10000.0
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# [29, 0.12848750319858682, 0.8111230563183296, 0.8205574117963812, 0.6258770761345628, 336.17286697038764, 0.6514196233806023, 0.20666369144075777]
# setting model:  {'CAPEX': 2.2053, 'OPEX': 4.9652, 'AceticAcidWt': 0.13632760758402965, 'SplitRatio': 0.01380670611439842, 'boilup_1': 0.16866987311751608, 'N_stages_1': 4, 'feed_stage_1': 3, 'boilup_2': 4.455759152889029, 'N_stages_2': 13, 'feed_stage_2': 11, 'boilup_3': 3.8332859175010117, 'N_stages_3': 3, 'feed_stage_3': 1, 'shortcut_time': 0.15362191200256348}
# 10000.0
# Error occurred: <MESHDistillation: acetic_acid_purification> division by zero
# Iteration No: 46 ended. Evaluation done at random point.
# Time taken: 0.4805
# Function value obtained: 10000.0000
# Current minimum: 1.8833
# Iteration No: 47 started. Evaluating function at random point.
#  ##### An instance of the 'BlackBox' class  has been initialised!
# [14, 0.21456766079640335, 0.37722135731965317, 0.038959235997002614, 0.6181920589494592, 298.91467454643197, 0.6556570631172042, 0.3853580813034686]
# capex_error
# Iteration No: 47 ended. Evaluation done at random point.
# Time taken: 0.0739
# Function value obtained: 10000.0000
# Current minimum: 1.8833
# Iteration No: 48 started. Evaluating function at random point.
#  ##### An instance of the 'BlackBox' class  has been initialised!
# [34, 0.34059050700729365, 0.2606684587830796, 0.49598785054797695, 0.6928210696560703, 299.8219185428962, 0.9365544870405219, 0.0391824080429787]
# setting base model
# setting model:  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# 10000.0
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# [34, 0.34059050700729365, 0.2606684587830796, 0.49598785054797695, 0.6928210696560703, 299.8219185428962, 0.9365544870405219, 0.0391824080429787]
# ...
# 10000.0
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# [41, 0.9177384076722497, 0.8575704870820929, 0.5627012300684813, 0.252043448273069, 297.18657876324903, 0.8737093202206586, 0.43548900902029714]
# setting model:  {'CAPEX': 1.5521, 'OPEX': 2.4344, 'AceticAcidWt': 0.10234055303352824, 'SplitRatio': 0.12498803677244778, 'boilup_1': 3.473034734129678, 'N_stages_1': 8, 'feed_stage_1': 6, 'boilup_2': 1.5028965497335247, 'N_stages_2': 1, 'feed_stage_2': 1, 'boilup_3': 1.3545488101996652, 'N_stages_3': 6, 'feed_stage_3': 1, 'shortcut_time': 0.08639693260192871}
# 10000.0
# acetic_acid:  0.30223741195276427
# lower
# Iteration No: 1054 ended. Search finished for the next optimal point.
# Time taken: 64.4745
# Function value obtained: 4.8824
# Current minimum: 1.8833
# Iteration No: 1055 started. Searching for the next optimal point.
#  ##### An instance of the 'BlackBox' class  has been initialised!
# [29, 0.8460259036127274, 0.5849461176529615, 0.5653265966599791, 0.24901666631269806, 329.9420016678262, 0.4281754309073798, 0.4415284727829636]
# setting base model
# setting model:  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# 10000.0
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# [29, 0.8460259036127274, 0.5849461176529615, 0.5653265966599791, 0.24901666631269806, 329.9420016678262, 0.4281754309073798, 0.4415284727829636]
# setting model:  {'CAPEX': 1.5837, 'OPEX': 2.0277, 'AceticAcidWt': 0.07142423910874159, 'SplitRatio': 0.013806706114398423, 'boilup_1': 3.14615421986027, 'N_stages_1': 11, 'feed_stage_1': 7, 'boilup_2': 1.4184769422170118, 'N_stages_2': 1, 'feed_stage_2': 1, 'boilup_3': 1.2697276253619196, 'N_stages_3': 4, 'feed_stage_3': 1, 'shortcut_time': 0.08989810943603516}
# 10000.0
# acetic_acid:  0.27534427571653847
# lower
# Iteration No: 1055 ended. Search finished for the next optimal point.
# Time taken: 66.2419
# Function value obtained: 5.2135
# Current minimum: 1.8833
# Iteration No: 1056 started. Searching for the next optimal point.
#  ##### An instance of the 'BlackBox' class  has been initialised!
# [50, 0.9048361563147022, 0.4457440979101836, 0.5575733905593193, 0.23995952340910798, 337.2669751825637, 0.6683193449997532, 0.4246556451232339]
# setting base model
# setting model:  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# 10000.0
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# [50, 0.9048361563147022, 0.4457440979101836, 0.5575733905593193, 0.23995952340910798, 337.2669751825637, 0.6683193449997532, 0.4246556451232339]
# setting model:  {'CAPEX': 1.5962, 'OPEX': 2.1417, 'AceticAcidWt': 0.08714944502463443, 'SplitRatio': 0.013806706114398423, 'boilup_1': 5.449572420088693, 'N_stages_1': 11, 'feed_stage_1': 7, 'boilup_2': 1.4337174816395357, 'N_stages_2': 1, 'feed_stage_2': 1, 'boilup_3': 1.386335028223306, 'N_stages_3': 5, 'feed_stage_3': 1, 'shortcut_time': 0.11029386520385742}
# 10000.0
# acetic_acid:  0.41734134845869386
# lower
# Iteration No: 1056 ended. Search finished for the next optimal point.
# Time taken: 64.4217
# Function value obtained: 3.5957
# Current minimum: 1.8833
# Iteration No: 1057 started. Searching for the next optimal point.
#  ##### An instance of the 'BlackBox' class  has been initialised!
# [6, 0.9176044244978839, 0.8584810018926142, 0.5628790487866014, 0.2521202814488445, 324.78230653866297, 0.8104988649410994, 0.43123051507818655]
# setting base model
# setting model:  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# 10000.0
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# [6, 0.9176044244978839, 0.8584810018926142, 0.5628790487866014, 0.2521202814488445, 324.78230653866297, 0.8104988649410994, 0.43123051507818655]
# setting model:  {'CAPEX': 1.5246, 'OPEX': 2.1977, 'AceticAcidWt': 0.11273167164708796, 'SplitRatio': 0.11884455848580164, 'boilup_1': 3.73810066380058, 'N_stages_1': 8, 'feed_stage_1': 6, 'boilup_2': 1.5210373460665856, 'N_stages_2': 1, 'feed_stage_2': 1, 'boilup_3': 1.3673089801674743, 'N_stages_3': 5, 'feed_stage_3': 1, 'shortcut_time': 0.09431076049804688}
# 10000.0
# acetic_acid:  0.30480261642732703
# lower
# Iteration No: 1057 ended. Search finished for the next optimal point.
# Time taken: 62.0790
# Function value obtained: 4.8448
# Current minimum: 1.8833
# Iteration No: 1058 started. Searching for the next optimal point.
#  ##### An instance of the 'BlackBox' class  has been initialised!
# [32, 0.9045015221757998, 0.4459800694216684, 0.5576143495334586, 0.24010905107548375, 287.57830141353935, 0.7655432651697858, 0.42298634700851445]
# setting base model
# setting model:  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# 10000.0
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# [32, 0.9045015221757998, 0.4459800694216684, 0.5576143495334586, 0.24010905107548375, 287.57830141353935, 0.7655432651697858, 0.42298634700851445]
# setting model:  {'CAPEX': 1.6477, 'OPEX': 2.5506, 'AceticAcidWt': 0.07588206087207673, 'SplitRatio': 0.01380670611439842, 'boilup_1': 5.026551579165106, 'N_stages_1': 11, 'feed_stage_1': 7, 'boilup_2': 1.414153985329659, 'N_stages_2': 1, 'feed_stage_2': 1, 'boilup_3': 1.4103678488382394, 'N_stages_3': 5, 'feed_stage_3': 1, 'shortcut_time': 0.0844731330871582}
# 10000.0
# acetic_acid:  0.3881398948484206
# lower
# Iteration No: 1058 ended. Search finished for the next optimal point.
# Time taken: 62.7566
# Function value obtained: 3.9535
# Current minimum: 1.8833
# Iteration No: 1059 started. Searching for the next optimal point.
#  ##### An instance of the 'BlackBox' class  has been initialised!
# [45, 0.7164219735567965, 0.7770301094539576, 0.5604577267764241, 0.2341083502420592, 282.4521911110036, 0.1984026049166785, 0.3524379810474631]
# setting base model
# setting model:  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# 10000.0
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# [45, 0.7164219735567965, 0.7770301094539576, 0.5604577267764241, 0.2341083502420592, 282.4521911110036, 0.1984026049166785, 0.3524379810474631]
# setting model:  {'CAPEX': 1.5481, 'OPEX': 3.2304, 'AceticAcidWt': 0.04260454202677663, 'SplitRatio': 0.013806706114398421, 'boilup_1': 1.3546707106765843, 'N_stages_1': 11, 'feed_stage_1': 8, 'boilup_2': 1.3363088221338564, 'N_stages_2': 1, 'feed_stage_2': 1, 'boilup_3': 1.781839658606332, 'N_stages_3': 2, 'feed_stage_3': 1, 'shortcut_time': 0.0806128978729248}
# 10000.0
# acetic_acid:  0.17349687811807551
# lower
# Iteration No: 1059 ended. Search finished for the next optimal point.
# Time taken: 66.1399
# Function value obtained: 6.6994
# Current minimum: 1.8833
# Iteration No: 1060 started. Searching for the next optimal point.
#  ##### An instance of the 'BlackBox' class  has been initialised!
# [8, 0.7163774315886052, 0.7774731355596795, 0.5604244309932521, 0.2341900429386278, 342.8427900719723, 0.09932738016001344, 0.3515582228604761]
# setting base model
# setting model:  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# 10000.0
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# [8, 0.7163774315886052, 0.7774731355596795, 0.5604244309932521, 0.2341900429386278, 342.8427900719723, 0.09932738016001344, 0.3515582228604761]
# setting model:  {'CAPEX': 1.4638, 'OPEX': 2.515, 'AceticAcidWt': 0.047948717292124014, 'SplitRatio': 0.013806706114398418, 'boilup_1': 1.4706392562700419, 'N_stages_1': 11, 'feed_stage_1': 8, 'boilup_2': 1.343033677262567, 'N_stages_2': 1, 'feed_stage_2': 1, 'boilup_3': 1.782681838421904, 'N_stages_3': 1, 'feed_stage_3': 1, 'shortcut_time': 0.10175514221191406}
# 10000.0
# acetic_acid:  0.17201787451743866
# lower
# Iteration No: 1060 ended. Search finished for the next optimal point.
# Time taken: 64.0351
# Function value obtained: 6.6920
# Current minimum: 1.8833
# Iteration No: 1061 started. Searching for the next optimal point.
#  ##### An instance of the 'BlackBox' class  has been initialised!
# [8, 0.8463892207029812, 0.5856862450980798, 0.5656015665146381, 0.2493970947248049, 322.6598608888875, 0.5947685063728548, 0.43326450255601273]
# setting base model
# setting model:  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# 10000.0
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# [8, 0.8463892207029812, 0.5856862450980798, 0.5656015665146381, 0.2493970947248049, 322.6598608888875, 0.5947685063728548, 0.43326450255601273]
# setting model:  {'CAPEX': 1.6082, 'OPEX': 2.1217, 'AceticAcidWt': 0.07180116138455246, 'SplitRatio': 0.01380670611439842, 'boilup_1': 3.1162385335231044, 'N_stages_1': 11, 'feed_stage_1': 7, 'boilup_2': 1.4214238721090546, 'N_stages_2': 1, 'feed_stage_2': 1, 'boilup_3': 1.330900546843124, 'N_stages_3': 4, 'feed_stage_3': 1, 'shortcut_time': 0.0809788703918457}
# 10000.0
# acetic_acid:  0.2640222597802713
# lower
# Iteration No: 1061 ended. Search finished for the next optimal point.
# Time taken: 64.4991
# Function value obtained: 5.3806
# Current minimum: 1.8833
# Iteration No: 1062 started. Searching for the next optimal point.
#  ##### An instance of the 'BlackBox' class  has been initialised!
# [12, 0.325384069516332, 0.6994747503164767, 0.5495065848362186, 0.2614546389045573, 290.1042514163467, 0.8290839268021082, 0.26231781005811616]
# setting base model
# setting model:  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# 10000.0
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# [12, 0.325384069516332, 0.6994747503164767, 0.5495065848362186, 0.2614546389045573, 290.1042514163467, 0.8290839268021082, 0.26231781005811616]
# setting model:  {'CAPEX': 1.8333, 'OPEX': 4.2827, 'AceticAcidWt': 0.02809695993989017, 'SplitRatio': 0.013806706114398418, 'boilup_1': 0.47332303982028895, 'N_stages_1': 5, 'feed_stage_1': 4, 'boilup_2': 1.2219721958941634, 'N_stages_2': 1, 'feed_stage_2': 1, 'boilup_3': 2.8864654280751227, 'N_stages_3': 5, 'feed_stage_3': 1, 'shortcut_time': 0.10081982612609863}
# 10000.0
# acetic_acid:  0.11793250279375486
# lower
# Iteration No: 1062 ended. Search finished for the next optimal point.
# Time taken: 60.2082
# Function value obtained: 7.5850
# Current minimum: 1.8833
# Iteration No: 1063 started. Searching for the next optimal point.
#  ##### An instance of the 'BlackBox' class  has been initialised!
# [3, 0.7163208381440392, 0.7775769777661489, 0.5604039749651177, 0.23426228785011352, 313.2443717647842, 0.12524664062805424, 0.34922959758000605]
# setting base model
# setting model:  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# 10000.0
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# [3, 0.7163208381440392, 0.7775769777661489, 0.5604039749651177, 0.23426228785011352, 313.2443717647842, 0.12524664062805424, 0.34922959758000605]
# setting model:  {'CAPEX': 1.575, 'OPEX': 2.6782, 'AceticAcidWt': 0.04533627799995224, 'SplitRatio': 0.013806706114398421, 'boilup_1': 1.4054020963346738, 'N_stages_1': 11, 'feed_stage_1': 8, 'boilup_2': 1.3395337357144743, 'N_stages_2': 1, 'feed_stage_2': 1, 'boilup_3': 1.802432691568219, 'N_stages_3': 2, 'feed_stage_3': 1, 'shortcut_time': 0.07553982734680176}
# 10000.0
# acetic_acid:  0.14902427095004697
# lower
# Iteration No: 1063 ended. Search finished for the next optimal point.
# Time taken: 66.1796
# Function value obtained: 7.0781
# Current minimum: 1.8833
# Iteration No: 1064 started. Searching for the next optimal point.
#  ##### An instance of the 'BlackBox' class  has been initialised!
# [15, 0.8872359160291652, 0.5136866692843409, 0.56422359986209, 0.24182530974127556, 327.84730596903563, 0.7830640143176234, 0.4700629730919299]
# setting base model
# setting model:  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# 10000.0
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# [15, 0.8872359160291652, 0.5136866692843409, 0.56422359986209, 0.24182530974127556, 327.84730596903563, 0.7830640143176234, 0.4700629730919299]
# setting model:  {'CAPEX': 1.5125, 'OPEX': 1.9322, 'AceticAcidWt': 0.08464881853507808, 'SplitRatio': 0.013806706114398421, 'boilup_1': 4.358642790075065, 'N_stages_1': 11, 'feed_stage_1': 7, 'boilup_2': 1.4572974387402429, 'N_stages_2': 1, 'feed_stage_2': 1, 'boilup_3': 1.1697537206840156, 'N_stages_3': 5, 'feed_stage_3': 1, 'shortcut_time': 0.08884382247924805}
# 10000.0
# acetic_acid:  0.3496048566875174
# lower
# Iteration No: 1064 ended. Search finished for the next optimal point.
# Time taken: 61.7858
# Function value obtained: 4.2954
# Current minimum: 1.8833
# Iteration No: 1065 started. Searching for the next optimal point.
#  ##### An instance of the 'BlackBox' class  has been initialised!
# [19, 0.7993178856740223, 0.5704826305801588, 0.5572336817160702, 0.24836241859209351, 340.26558491110563, 0.04028079588388192, 0.5681462921036712]
# setting base model
# setting model:  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# 10000.0
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# [19, 0.7993178856740223, 0.5704826305801588, 0.5572336817160702, 0.24836241859209351, 340.26558491110563, 0.04028079588388192, 0.5681462921036712]
# setting model:  {'CAPEX': 1.2689, 'OPEX': 1.3756, 'AceticAcidWt': 0.05689570452929615, 'SplitRatio': 0.013806706114398421, 'boilup_1': 2.595308687649642, 'N_stages_1': 10, 'feed_stage_1': 7, 'boilup_2': 1.3394281179217664, 'N_stages_2': 1, 'feed_stage_2': 1, 'boilup_3': 0.7445411205780527, 'N_stages_3': 1, 'feed_stage_3': 1, 'shortcut_time': 0.0986490249633789}
# 10000.0
# acetic_acid:  0.2404643946749891
# lower
# Iteration No: 1065 ended. Search finished for the next optimal point.
# Time taken: 66.0105
# Function value obtained: 5.6184
# Current minimum: 1.8833
# Iteration No: 1066 started. Searching for the next optimal point.
#  ##### An instance of the 'BlackBox' class  has been initialised!
# [17, 0.7163186819565132, 0.7774216560742071, 0.5603721505001413, 0.23435412420431523, 326.0646352006126, 0.6479570697125071, 0.3462564711225239]
# setting base model
# setting model:  {'SplitRatio': 0.287, 'boilup_1': 4.48, 'N_stages_1': 9, 'feed_stage_1': 7, 'boilup_2': 4.48, 'N_stages_2': 9, 'feed_stage_2': 7, 'boilup_3': 4.48, 'N_stages_3': 9, 'feed_stage_3': 7}
# 10000.0
#  ##### An instance of the 'RigorousDesign' class  has been initialised!
# [17, 0.7163186819565132, 0.7774216560742071, 0.5603721505001413, 0.23435412420431523, 326.0646352006126, 0.6479570697125071, 0.3462564711225239]
# setting model:  {'CAPEX': 1.6998, 'OPEX': 2.7838, 'AceticAcidWt': 0.05053876225836148, 'SplitRatio': 0.013806706114398421, 'boilup_1': 1.443432097306093, 'N_stages_1': 11, 'feed_stage_1': 8, 'boilup_2': 1.3516610518234402, 'N_stages_2': 1, 'feed_stage_2': 1, 'boilup_3': 1.9153250658253074, 'N_stages_3': 4, 'feed_stage_3': 1, 'shortcut_time': 0.13061308860778809}
# 10000.0
# acetic_acid:  0.17678371799546294
# lower

# %%
opt_history
# Out:
# [{'params': {'n1': 42,
#    'Lr1': 0.18341644638717722,
#    'Hr1': 0.7796130311727423,
#    'Lr2': 0.5967904729306924,
#    'Hr2': 0.4457881695783059,
#    'T_hex': 280.6980685179862,
#    'Lr3': 0.4592029670766707,
#    'Hr3': 0.333675240277908},
#   'target': 100},
#  {'params': {'n1': 16,
#    'Lr1': 0.6508233841015582,
#    'Hr1': 0.05640593786919756,
#    'Lr2': 0.7219265723895982,
#    'Hr2': 0.9384588537448488,
#    'T_hex': 273.0599649697581,
#    'Lr3': 0.9921123381352887,
#    'Hr3': 0.6174197614767539},
#   'target': 100},
#  {'params': {'n1': 34,
#    'Lr1': 0.007065598589195436,
#    'Hr1': 0.02306011879891162,
#    'Lr2': 0.5247221827923634,
#    'Hr2': 0.39982098561808405,
#    'T_hex': 276.5932560674484,
#    'Lr3': 0.9736581432895752,
#    'Hr3': 0.23274806329626127},
#   'target': 100},
#  {'params': {'n1': 14,
#    'Lr1': 0.6183241707321541,
#    'Hr1': 0.3824237450680361,
#    'Lr2': 0.9831325627182077,
#    'Hr2': 0.46671621695865523,
#    'T_hex': 339.2154113186967,
#    'Lr3': 0.6802395078339211,
#    'Hr3': 0.45045420204434616},
#   'target': 100},
#  {'params': {'n1': 11,
#    'Lr1': 0.9421075355092845,
#    'Hr1': 0.5632318890237549,
#    'Lr2': 0.38537796088966225,
#    'Hr2': 0.015964655594992178,
#    'T_hex': 290.7788245729055,
#    'Lr3': 0.24100136347940918,
#    'Hr3': 0.6831951924735757},
#   'target': 100},
#  {'params': {'n1': 41,
#    'Lr1': 0.005634196385442997,
#    'Hr1': 0.9973585830067146,
#    'Lr2': 0.04496407436748039,
#    'Hr2': 0.6346271035884969,
#    'T_hex': 344.41172450450085,
#    'Lr3': 0.06536089248141905,
#    'Hr3': 0.9922161706616027},
#   'target': 100},
#  {'params': {'n1': 48,
#    'Lr1': 0.9812503768384662,
#    'Hr1': 0.5343839708792363,
#    'Lr2': 0.008238905503144921,
#    'Hr2': 0.8185223192914005,
#    'T_hex': 349.1837796426955,
#    'Lr3': 0.7667155479342829,
#    'Hr3': 0.023717231817629733},
#   'target': 100},
#  {'params': {'n1': 50,
#    'Lr1': 0.9999,
#    'Hr1': 0.0,
#    'Lr2': 0.9999,
#    'Hr2': 0.0,
#    'T_hex': 273.0,
#    'Lr3': 0.0,
#    'Hr3': 0.9999},
#   'target': 100},
#  {'params': {'n1': 16,
#    'Lr1': 0.08801110239439529,
#    'Hr1': 0.05623627568322174,
#    'Lr2': 0.01944361548385,
#    'Hr2': 0.8842070267929693,
#    'T_hex': 348.64189669270985,
#    'Lr3': 0.009705425148026922,
#    'Hr3': 0.10170200191797474},
#   'target': 100},
#  {'params': {'n1': 10,
#    'Lr1': 0.0,
#    'Hr1': 0.9999,
#    'Lr2': 0.9999,
#    'Hr2': 0.0,
#    'T_hex': 350.0,
#    'Lr3': 0.9999,
#    'Hr3': 0.0},
#   'target': 100},
#  {'params': {'n1': 10,
#    'Lr1': 0.9999,
#    'Hr1': 0.9999,
#    'Lr2': 0.0,
#    'Hr2': 0.9999,
#    'T_hex': 273.0,
#    'Lr3': 0.9999,
#    'Hr3': 0.9999},
#   'target': 100},
#  {'params': {'n1': 50,
#    'Lr1': 0.9317787334200253,
#    'Hr1': 0.817471176229446,
#    'Lr2': 0.959485675624179,
#    'Hr2': 0.01032545606125608,
#    'T_hex': 298.09067944791406,
#    'Lr3': 0.1453355627215147,
#    'Hr3': 0.0012756700178846371},
#   'target': 100},
#  {'params': {'n1': 40,
#    'Lr1': 0.011586985501729784,
#    'Hr1': 0.9806594678114604,
#    'Lr2': 0.9516111544475937,
#    'Hr2': 0.8216845495455631,
#    'T_hex': 347.55013247909136,
#    'Lr3': 0.8929616372472512,
#    'Hr3': 0.9424093297066767},
#   'target': 100},
#  {'params': {'n1': 17,
#    'Lr1': 0.11631874169123416,
#    'Hr1': 0.02104625141078791,
#    'Lr2': 0.1583538313430569,
#    'Hr2': 0.03067983582911806,
#    'T_hex': 282.8577337832368,
#    'Lr3': 0.9976757211367461,
#    'Hr3': 0.9825390863486629},
#   'target': 100},
#  {'params': {'n1': 10,
#    'Lr1': 0.0,
#    'Hr1': 0.9999,
#    'Lr2': 0.9999,
#    'Hr2': 0.9999,
#    'T_hex': 273.0,
#    'Lr3': 0.0,
#    'Hr3': 0.0},
#   'target': 100},
#  {'params': {'n1': 50,
#    'Lr1': 0.9999,
#    'Hr1': 0.9999,
#    'Lr2': 0.0,
#    'Hr2': 0.0,
#    'T_hex': 350.0,
#    'Lr3': 0.9999,
#    'Hr3': 0.0},
#   'target': 100},
#  {'params': {'n1': 14,
#    'Lr1': 0.8840747187148835,
#    'Hr1': 0.42548691193140187,
#    'Lr2': 0.9807917141863308,
#    'Hr2': 0.9118066303226183,
#    'T_hex': 348.96150799605107,
#    'Lr3': 0.005229734144915128,
#    'Hr3': 0.06666578937428305},
#   'target': 100},
#  {'params': {'n1': 49,
#    'Lr1': 0.005061402197552096,
#    'Hr1': 0.021893966226923457,
#    'Lr2': 0.7066829479323202,
#    'Hr2': 0.8205250126313399,
#    'T_hex': 274.9429161954697,
#    'Lr3': 0.3538828959923375,
#    'Hr3': 0.01171700777896054},
#   'target': 100},
#  {'params': {'n1': 10,
#    'Lr1': 0.0,
#    'Hr1': 0.0,
#    'Lr2': 0.0,
#    'Hr2': 0.0,
#    'T_hex': 350.0,
#    'Lr3': 0.0,
#    'Hr3': 0.9999},
#   'target': 100},
#  {'params': {'n1': 49,
#    'Lr1': 0.9775026765791176,
#    'Hr1': 0.0019314883581750897,
#    'Lr2': 0.2777580760278486,
#    'Hr2': 0.8546634602747812,
#    'T_hex': 343.44594099797894,
#    'Lr3': 0.823107464439214,
#    'Hr3': 0.9927733501730976},
#   'target': 100}]
